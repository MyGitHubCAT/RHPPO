# %%
import numpy as np
import pandas as pd
import math
import time
import random
import matplotlib.pyplot as plt

from collections import namedtuple,deque

import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

import torch
import BSS_ENV_shortduration as BE
PYDIR = r'D:\sjtu\EV_DRL\BSS_OPERATION_Emergence'

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
#单一行为以及可拓展的策略
class options:
    def __init__(self,num):
        self.charger_num = num
        self.ev_num = num
        self.bssbatterynum = 2 * num
        self.maxpve = 0
        self.transit_step = 2
        self.ev_average_worksoc = 0.1

        self.inp_dim = 4
        self.memory_count = 1000
        self.GAMMA = 0.99
        self.beta = 0.2
        self.MEMORY_NUM = 2
        self.game_step = 400
        
        self.NUM_EPISODES = 2000

        self.update_gamecount = 4#每进行多少轮游戏更新网络
        
        self.learning_ratio = 0.0001
        self.if_clamp = True
        self.modelpath = r'D:\sjtu\EV_DRL\BSS_OPERATION_Emergence\data\savemodel\policymodel'
        self.dirpath=r'D:\sjtu\EV_DRL\BSS_OPERATION\data'
        self.gru_state = r'D:\sjtu\EV_DRL\BSS_OPERATION\data\savemodel\gru.pth'
        #self.price_data = r'D:\sjtu\xdd\paper\data\price\time_series_60min_singleindex.csv'
        self.price_datafile = r'D:\sjtu\EV_DRL\BSS_OPERATION_Emergence\data\pricedata\time_series_60min_singleindex.csv'
        self.price_data = self.pricedata()

        #模型的初始化格式
        self.pit = {'avg':0,'ban':1,'all':2}#等概率考虑pv，不使用pv，最大化使用pv

    def pricedata(self):
        price_data_path = self.price_datafile
        pd_frame = pd.read_csv(price_data_path)

        DK_1_price = pd_frame['DK_1_price_day_ahead']
        DK_1_price.fillna(0,inplace=True)

        DK_1_price_nparray =np.array([max(0,i) for i in DK_1_price.tolist()])
        return DK_1_price_nparray

def GetNewGame(opts:options):
    gmpricedata = opts.price_data
    gamemanager = BE.GameManager(opts,ps_eprice_ds=gmpricedata)
    #randomprice = [10 for _ in range(opts.MAX_TIME+1)] #[random.randint(1,20) for _ in range(opts.MAX_TIME+1)]
    return gamemanager       

OPTIONS = options(10)
GM = GetNewGame(OPTIONS)

# %%
fig, ax = plt.subplots(figsize = (12,4))
ax.plot(np.arange(1000), OPTIONS.price_data[0:1000], linewidth=1)
plt.show()

# %%
def StateTensor(gm:BE.GameManager):
    bt1_num,bt2_num,b_num,energy_cost,carbon,bssevqueue_length,wasted_reserve,ctime,is_done = gm.EnvState()
    ctime = ctime/10 #0-96的数值太大，这里减少一下数值大小
    statetensor = torch.tensor([bt1_num,bt2_num,bssevqueue_length,ctime],dtype= torch.float32).to(device)
    costtensor = torch.tensor([energy_cost,bssevqueue_length,wasted_reserve],dtype= torch.float32).to(device)
    return statetensor.unsqueeze(0),costtensor.unsqueeze(0) #1*4 ,1*3

cfactor_t1 = 0.05
qfactor_t1 = 1
wfactor_t1 = 0.5
def rewardtype1(cost_T,opts:options):#正常运营状态下的奖励信息，车辆排队数量+超出的预约数+充电费用

    charging_cost = cfactor_t1* cost_T[:,0]/120#120为电池容量，这里电费最好按照SOC的比例计算，因此除掉了电池容量

    emergenceqfactor = 1 if opts.ev_num/cost_T[:,1]>1.5 else 3
    evqueuetimein_bss = qfactor_t1*(cost_T[:,1])*emergenceqfactor

    wast_request = wfactor_t1*cost_T[:,2]
       
    #print(evqueuetimein_bss, wast_request,charging_cost)
    bss_reward = -(evqueuetimein_bss+ wast_request+charging_cost)/opts.ev_num
    #print(torch.ones(1),bss_reward)
    bss_reward = bss_reward.unsqueeze(0) #奖励值输入形状为1*
    return bss_reward


def rewardtype1_detail(cost_T,opts:options):#正常运营状态下的奖励信息，车辆排队数量+超出的预约数+充电费用

    charging_cost = cfactor_t1* cost_T[:,0]/120#120为电池容量，这里电费最好按照SOC的比例计算，因此除掉了电池容量

    emergenceqfactor = 1 if opts.ev_num/cost_T[:,1]>1.5 else 3
    evqueuetimein_bss = qfactor_t1*(cost_T[:,1])*emergenceqfactor

    wast_request = wfactor_t1*cost_T[:,2]
       
    #print(evqueuetimein_bss, wast_request,charging_cost)
    bss_reward = -(evqueuetimein_bss+ wast_request+charging_cost)/opts.ev_num
    #print(torch.ones(1),bss_reward)
    bss_reward = bss_reward.unsqueeze(0) #奖励值输入形状为1*
    return bss_reward,-charging_cost,-evqueuetimein_bss,-wast_request

# %%
workingtimes= range(400)
timereturn = 48
worktimefactor =   [1 * math.cos(i*math.pi/timereturn) + 1  + random.random()*0.1 for i in workingtimes] 
fig = plt.figure(figsize = (12,4))
plt.plot(workingtimes,worktimefactor)
plt.show()

# %%
evqueuelengths = []
for i in range(200):#OPTIONS.game_step):
    reserve = int(OPTIONS.charger_num/2)
    chargeplan = 1
    GM.Update(reserve,chargeplan) 
    cstate,ccost = StateTensor(GM)
    evqueuelengths.append(ccost[:,1].cpu().item())
    #print(i,cstate,ccost)
    r = rewardtype1(ccost,OPTIONS)
    #print(r)
    #GM.Message()

fig = plt.figure(figsize = (12,4))
plt.plot(range(200),evqueuelengths)
plt.show()

# %%
class PPONetwork(torch.nn.Module):
    def __init__(self,inpdim,reserve_dim=5,init_cpratio_id = 1):
        super(PPONetwork,self).__init__()
        self.inputlayer = torch.nn.Linear(inpdim,64).to(device)
        self.linear1 = torch.nn.Linear(64,128).to(device)

        #self.norm = torch.nn.BatchNorm1d(4).to(device)
        #self.relu = torch.nn.LeakyReLU().to(device)

        self.linear2 = torch.nn.Linear(128,64).to(device)

        self.out1 = torch.nn.Linear(64,reserve_dim).to(device)
        #self.out2 = torch.nn.Linear(64,chargeplan_dim).to(device)
        self.out3 = torch.nn.Linear(64,1).to(device)
        self.softmax = torch.nn.Softmax(dim=-1)
        
        
    def forward(self,inp):
        x = inp.to(device)
        inp1 = self.inputlayer(x)
        tanh1 = torch.nn.Tanh()(inp1)
        line1 = self.linear1(tanh1)
        line2 = self.linear2(line1)#(reshape_128)
        tanh2 = torch.nn.Tanh()(line2)
        #print(tanh2)
        out_1 = self.out1(tanh2)
        
        out_3 = self.out3(tanh2)
        res1 = self.softmax(out_1)

        #print(out_3)
        res3 = out_3
        return res1,res3 #bs*reservedim+1,bs*2,bs*1

# %%
BSSTransition = namedtuple('BSSTransition',('state_pool','value_pool','act_pool','old_prob_pool','reward_pool','done_pool'))#收集连续动作
class BSSMemory(object):#策略梯度采样，每次保存一次策略的数据，采样一次策略的数据、
    def __init__(self,capacity):
        self.memory = deque([],maxlen = capacity)
    def push(self,*args):
        self.memory.append(BSSTransition(*args))
    def sample(self):
        batch = list(self.memory)
        return zip(*batch)
    def __len__(self):
        return len(self.memory)
    def clear(self):
        self.memory.clear()


class BSS_DRL(object):#er_dim=5*5+1默认单位电量20，5个100kwh充电桩对应的维度选择为25+1
    def __init__(self,opt):#ifstep 通过冻结网络的部分层操作实现分段训练):
        self.options =  opt
        self.lr = opt.learning_ratio
        
        self.bss_agent = PPONetwork(opt.inp_dim,reserve_dim=opt.charger_num +1,init_cpratio_id= 0).to(device)
        
        self.bss_agent_target = PPONetwork(opt.inp_dim,reserve_dim=opt.charger_num +1,init_cpratio_id=0).to(device)
        self.bss_agent_target.load_state_dict(self.bss_agent.state_dict())  
        self.bss_agent_target.eval()

        self.bss_agent_optimizer = torch.optim.Adam(self.bss_agent.parameters(),lr = self.lr)
        #self.bss_a2c_target_optimizer = torch.optim.Adam(self.evrp_critic.parameters(),lr = self.lr)
        self.if_clamp = opt.if_clamp
        self.bssmemory_num = opt.MEMORY_NUM
        self.bssmemorys = [] 
        for i in range(4):
            self.bssmemorys.append(BSSMemory(2500))
        
    #根据当前状态 选择车辆充电行为， 首先根据车辆策略模型给出期望充电行为， 再依据充电商策略模型给出确定动作   
    def select_action(self,bssstate,if_train=False):#state_s的格式为bs*ev_num*(state_n)
        prob1,state_value = self.bss_agent(bssstate)
        prob1_target,state_value_target = self.bss_agent_target(bssstate)
        
        reserve_dist = torch.distributions.categorical.Categorical(prob1)
   
        reserve_dist_target = torch.distributions.categorical.Categorical(prob1_target)
        
        
        reserve_act = reserve_dist.sample()

        reserve_act_target = reserve_dist_target.sample()
        
        
        if if_train:
            return reserve_act_target,reserve_dist_target,reserve_dist,state_value_target
                
        return reserve_act,prob1
    
    
    def cliprange(self,prob,prob_target,segma=0.2):
        policy_ratio = prob/prob_target
        max_clip = 1+segma
        min_clip = 1-segma
        clipres = torch.clamp(policy_ratio,min = min_clip,max = max_clip)
        return clipres
    
    def compute_returns(self,next_value, rewards, masks, gamma=0.99):
        value = next_value.detach()#return 不计入梯度计算，这里使用detach() 1*1
        rewards = (rewards - rewards.mean())/rewards.std()
       
        returns = torch.zeros_like(rewards)    #使用numpy操作可能更快？但是需要注意tensor和numpy数据的转换
        for act_i in reversed(range(len(rewards))):
            #print(rewards[act_i],gamma , value , masks[act_i])
            value = rewards[act_i] + gamma * value * (1-masks[act_i])
            returns[act_i] = value
        return returns #pool_size*1*1

    def update_bss(self,bssmemorys,nstate_s_list):
        #print(0.001*entropy)
        mmnum = len(bssmemorys)
        totallossvalue = 0
        inpoches = 6#每轮数据更新次数（正常情况下为每轮数据更新至梯度几乎消失 也就是过小后，不进行更新，或者过大的梯度跳过更新，随后才使用下一轮采集的数据）
        for _ in range(inpoches): #注意这里外循环为轮次，内循环为轨迹，这样可以每轮更新使用所有轨迹数据，避免单挑轨迹主导更新、
            losses = 0
            for i in range(self.bssmemory_num):
                'state_pool','value_pool','act_pool','old_prob_pool','reward_pool','done_pool'
                #tate_pool, value_pool, policy_ratio_pool, clipres_pool, reward_pool, done_pool = bssmemorys[i].sample()
                state_pool, value_pool, act_pool,old_prob_pool, reward_pool, done_pool = bssmemorys[i].sample()
                #在bs维度进行合并
                state_poolstack =torch.concat(state_pool,dim=0).to(device).detach()#pool_length*evnum*evdim #这里由于采样了一条轨迹的所有信息 所以一个轨迹的数据被合并到了bs维度
                old_value_poolstack = torch.concat(value_pool,dim=0).to(device).detach()#pool_length*1#记录的为整体的Q基于行为的平均状态价值
                act_poolstack = torch.concat(act_pool,dim=0).to(device).detach()#pool_length*evnum*1
                old_prob_poolstack = torch.concat(old_prob_pool,dim=0).to(device).detach()#pool_length*evnum*1
                #print(value_poolstack)
                reward_poolstack = torch.concat(reward_pool,dim=0).to(device)#pool_length*1 #整体的平均奖励
                #print(reward_poolstack)
                done_poolstack = torch.concat(done_pool,dim=0).to(device)#pool_length*1
                #print(done_poolstack)
                # print(state_poolstack.shape, old_value_poolstack.shape,\
                #         policy_ratio_poolstack.shape, clipres_poolstack.shape,\
                #             reward_poolstack.shape, done_poolstack.shape)
                

                current_prob_poolstack, current_bssqstatevalue  =self.bss_agent(state_poolstack)#bs*evnum*evactnum
                current_dist_poolstack = torch.distributions.categorical.Categorical(current_prob_poolstack)
                current_entropy = current_dist_poolstack.entropy().mean()
                              
                current_actprob_poolstack = torch.gather(current_prob_poolstack,dim=-1,index = act_poolstack)

                policy_ratio_poolstack = current_actprob_poolstack/old_prob_poolstack
                eps_clip = 0.2#clip范围值
                policy_clipres_poolstack = torch.clamp(policy_ratio_poolstack, 1-eps_clip, 1+eps_clip) #限制PPO 决策概率比值范围

                #1 1 1
                _,next_value = self.bss_agent_target(nstate_s_list[i])#bs*1
            
                #记录累加奖励（该采样与DQN不同，采样中每次仅记录一个策略动作序列）
                returns = self.compute_returns(next_value.squeeze(0),reward_poolstack,done_poolstack,gamma = self.options.GAMMA)
                advantages = returns - old_value_poolstack
                with torch.no_grad():#actor的梯度不需要考虑advantage内的梯度计算，因此这里归一化计算，且不计算梯度信息
                    adv_t = (advantages - advantages.mean()) / advantages.std().clamp_min(1e-6)

                _,current_value = self.bss_agent(state_poolstack)
                #print(current_value.shape,returns.shape)
                current_advantage = returns - current_value
  
                clip_advantages =  adv_t.detach() * policy_clipres_poolstack
                policy_ratio_advantages = advantages * policy_ratio_poolstack
                # print(clip_advantages)
                # print(policy_ratio_advantages)
                stack_advantages = torch.cat((clip_advantages,policy_ratio_advantages),dim=-1)
                ppo_advantages = stack_advantages.min(dim=-1)[0].unsqueeze(-1)
                
                #print( ppo_advantages)
                #print(advantages)
                #print(log_prob_poolstack)
                #print(advantages)
                
                actor_loss = -ppo_advantages.mean() # (-log_prob_poolstack * advantages).mean()
                critic_loss = 0.5 * current_advantage.pow(2).mean()
                # print('bss动作损失：{}'.format(actor_loss))
                # print('bss策略损失：{}'.format(critic_loss))
                total_loss = 10* actor_loss + critic_loss - 0.0001* current_entropy
                losses+= total_loss
            
            mmloss = losses/mmnum
            lossvalue = mmloss.cpu().detach().item()
            totallossvalue += lossvalue
           
            #print('动作熵值：{}'.format(log_prob_poolstack))            
            self.bss_agent_optimizer.zero_grad()      
            mmloss.backward()
            for name, param in self.bss_agent.named_parameters():
                #print(name,param.grad)
                if param.grad is not None:
                    param.grad.clamp_(-1,1)
            #for param in self.evrp_critic.parameters():           
            # print(param.grad)
            self.bss_agent_optimizer.step()    
        return totallossvalue/inpoches

    def update_bss_for_grad(self,nstate_s_list,entropys):
        #print(0.001*entropy)
        mmnum = self.bssmemory_num
        losses = []
        for i in range(self.bssmemory_num):
            state_pool,value_pool,policy_ratio_pool,clipres_pool,log_prob_pool,reward_pool,done_pool= self.bssmemorys[i].sample()

            state_poolstack =torch.stack(state_pool).to(device)
            old_value_poolstack = torch.stack(value_pool).to(device)#pool_length*bs*valuedim
            policy_ratio_poolstack = torch.stack(policy_ratio_pool).to(device) #pool_length*bs*valuedim
            clipres_poolstack = torch.stack(clipres_pool).to(device) #pool_length*bs*valuedim
            #print(value_poolstack)
            log_prob_poolstack = torch.stack(log_prob_pool).to(device) #pool_length*bs*valuedim
            #print(log_prob_poolstack)
            reward_poolstack = torch.stack(reward_pool).to(device)#pool_length*bs*valuedim
            #print(reward_poolstack)
            done_poolstack = torch.stack(done_pool).to(device)#pool_length*bs*valuedim
            #print(done_poolstack)
       
            #1 1 1
            _,next_value = self.bss_agent_target(nstate_s_list[i])#bs*1
        
            #记录累加奖励（该采样与DQN不同，采样中每次仅记录一个策略动作序列）
            returns = self.compute_returns(next_value.squeeze(0),reward_poolstack,done_poolstack,gamma = self.options.GAMMA)
            advantages = returns - old_value_poolstack

            _,current_value = self.bss_agent(state_poolstack)
            #print(current_value.shape,returns.shape)
            current_advantage = returns - current_value
            
            #print(advantages.shape)
            # print('clip'+str(clipres_poolstack))
            # print('policy' +str( policy_ratio_poolstack))
            clip_advantages = advantages * clipres_poolstack
            policy_ratio_advantages = advantages * policy_ratio_poolstack
            # print(clip_advantages)
            # print(policy_ratio_advantages)
            stack_advantages = torch.cat((clip_advantages,policy_ratio_advantages),dim=-1)
            ppo_advantages = stack_advantages.min(dim=-1)[0].unsqueeze(-1)
            
            #print( ppo_advantages)
            #print(advantages)
            #print(log_prob_poolstack)
            #print(advantages)
            
            actor_loss = -ppo_advantages.mean() # (-log_prob_poolstack * advantages).mean()
            critic_loss = 0.5 * current_advantage.pow(2).mean()
            # print('bss动作损失：{}'.format(actor_loss))
            # print('bss策略损失：{}'.format(critic_loss))
            total_loss = 10* actor_loss + critic_loss - 0.0001*entropys[i]
            losses.append(total_loss)
        
        mmloss = losses[0]
        for i in range( mmnum-1):
            mmloss = mmloss + losses[i+1]
        mmloss = mmloss/mmnum
        grads = torch.autograd.grad(mmloss,self.bss_agent.parameters(),create_graph= True)
        return grads
            #print('动作熵值：{}'.format(log_prob_poolstack))            
        # self.bss_agent_optimizer.zero_grad()      
        # mmloss.backward()
        # if self.if_clamp:
        #     for param in self.bss_agent.parameters():           
        #         #print(param.grad)
        #         if param.grad is not None:
        #             param.grad.data.clamp(-20,20)
        # #for param in self.evrp_critic.parameters():           
        #    # print(param.grad)
        # self.bss_agent_optimizer.step()    
        
    def freshtargetmodel(self):
        self.bss_agent_target.load_state_dict(self.bss_agent.state_dict())   

    def savemodel(self,dicpath,addname):
        torch.save(self.bss_agent.state_dict(),os.path.join(dicpath,addname+'.pth'))

# %%
reward = rewardtype1

bss_ep_valrewards = []
bss_ep_valrewards_avgemgf = []
bss_ep_updaterewards = []
meta_drl =  BSS_DRL(OPTIONS)
metaevshistdata_dir = os.path.join(PYDIR,r'data\savemodel\metamodeltraingingdata')


# emergencefactors = [0.25,0.5,0.75,1,1.25,1.5]
# subtaskid = [0,1,2,3,4,5]
#sample_subtasknum = 6
emergencefactors = [0.5,1,1.5,2]
subtaskid = [0,1,2,3]


sample_subtasknum = 4#元学习的采样任务次数
testsubtasknum = 4#元模型测试任务数
bss_mmnum = 4 #PPO每次更新的轨迹采样次数

subbss_memorys = []
for _ in range(sample_subtasknum ):
    bss_memorys = [] 
    for i in range(bss_mmnum ):
        bss_memorys .append(BSSMemory(2500))
    'current_state','action','reward','next_state','is_done'
    subbss_memorys.append(bss_memorys)


#不同于特定任务的模型需要学习到累计奖励收敛到最大值， 元模型需要考虑的是元模型是否适应到合适位置来描述不同的任务，实现快速的任务更新。
#因此 通过记录meta模型梯度的前后变化来确定是否需要继续更新。如果meta的梯度连续多次接近（使用范数计算多维度的梯度信息），则考虑meta模型以及到合适的位置（当然还可以使用其他的判定方案）
meta_static_K = 3 #连续稳定次数，则考虑已经学习到合适的meta 模型
stable_count = 0 #稳定次数

sampleupdata_avgreturns = []

# %%
#bss_drl.bss_agent.load_state_dict(torch.load(os.path.join(OPTIONS.modelpath,'PPO_emgfactor1_SCALE10.pth')))

# %%
#这里我们通过连续计算历史meta_G的变化情况，包括均值与标准差来确定是否需要停止，同时也作为元模型更新的指标进行记录
mintraining_ep = 200#避免过早停止
meta_G_length = 30
hist_meta_G = deque(maxlen=meta_G_length)
last_meta_G_AVG = 9999
last_meta_G_VAR = 9999
eps_abs = 1e-12
eps_cv = 0.3
hist_meta_G_avg = 9999
hist_meta_G_std = 9999
hist_meta_G_cv =9999
meta_G_avgs = []
meta_G_std = []
meta_G_cv = []
sample_subbssagents = [BSS_DRL(OPTIONS) for _ in range(sample_subtasknum)]#加载参数表示新模型，避免每个ep创建新的，导致计算开销增加

for ep in range(2000):
    epstart = time.time()#记录每个episode训练时间  
    #sample_shifttasks = np.random.choice(tempshiftdatas[0],size = subtasknum,replace=False)
    sample_taskids = np.random.choice(subtaskid,size = sample_subtasknum ,replace=False)
    sample_emergencefactors = [emergencefactors[taskid] for taskid in sample_taskids]

    #sample_subevagents = [EV_PPO(options) for _ in range(subtasknum)]
    
    for subagent in sample_subbssagents:#子任务的梯度继承来自于实时的元模型
        subagent.bss_agent.load_state_dict(meta_drl.bss_agent.state_dict())
        subagent.bss_agent_target.load_state_dict(meta_drl.bss_agent.state_dict())
    
    meta_param_sd = meta_drl.bss_agent.state_dict()
    meta_param_sd_base = {k: v.detach().clone() for k, v in meta_param_sd .items()}#这里是因为state_dict()给出的是引用，因此最好使用复制，来表示参数信息，避免因为引用导致数据混乱

    eposide_param_sd_diff = []#记录子任务模型与meta模型的参数差值
    sampleupdaterewards = [] #记录一下每次更新meta模型更新时的累计奖励信息

    for i in range(sample_subtasknum):# 子任务依次 用于更新元模型：步骤是 先基于元模型参数更新一次子任务，再在更新后的子任务模型基础上再次记录轨迹并计算梯度。 随后基于所有子任务的梯度平均值更新元模型
        current_subtaskmodel = sample_subbssagents[i]
        current_emergencefactor = sample_emergencefactors[i]
        sampleupdatereward = 0. #奖励信息记录
        sd_diff = {}#记录单次子任务与meta模型的参数差值
        bss_last_state_s =[]
        
        for bss_mmnum_k1 in range(bss_mmnum): #submodel 先更新一次
            GM = GetNewGame(OPTIONS) 
                    
            for reqstage_k in range(OPTIONS.game_step):

                cstate,ccoststate = StateTensor(GM)
                
                #BSSs决策过程
                reserve_act_target,reserve_dist_target,reserve_dist,state_value_target = current_subtaskmodel.select_action(cstate,True)

                reserve_act_target = reserve_act_target.unsqueeze(-1)
                bss_probs_target = reserve_dist_target.probs#1*evnum*evactnum
                bss_actprob_target =torch.gather(bss_probs_target,dim=-1,index=reserve_act_target)#1*evnum*1

                        #根据动作更新环境
                charge_request = reserve_act_target.cpu().item()

                GM.Update(charge_request,0,current_emergencefactor)

                nstate,ncoststate = StateTensor(GM)

                bss_reward = reward(ncoststate,OPTIONS) #1,1
                bss_reward = bss_reward.detach()

                bss_nstate = nstate.detach()#同时需要添加到replaybuffer里面           
               
                'state_pool','value_pool','act_pool','old_prob_pool','reward_pool','done_pool'
                #1*bssnum*bssdim
                bss_cstate = cstate.detach()
                bss_cstatevalue = state_value_target.detach()
                bss_act_target =  reserve_act_target.detach()
                bss_act_prov = bss_actprob_target.detach()
                bss_rew = bss_reward

                isdone = torch.zeros(1,1).detach()#不考虑结束状态
                subbss_memorys[i][bss_mmnum_k1].push(\
                    bss_cstate,bss_cstatevalue,bss_act_target,\
                        bss_act_prov,bss_rew,isdone)
                
                sampleupdatereward += bss_reward.item()

            nev_P = bss_nstate #只记录最后时刻
            bss_last_state_s.append(nev_P)

        #更新子任务模型 并重置参数信息
        bsslossvalue = current_subtaskmodel.update_bss(subbss_memorys[i],bss_last_state_s)
        for bssmm in subbss_memorys[i]:
            bssmm.clear() 
        #ep_trans_losses.append(translossvalue)
        #与OFF LINE不同， 每次大更新都需要更新PPO的old模型（代码中记为target模型）
        current_subtaskmodel.freshtargetmodel()
       
        #计算子任务模型与meta模型的差值并记录
        current_subtaskmodel_sd = current_subtaskmodel.bss_agent.state_dict()
        for paramkeys in meta_param_sd_base.keys():
            if not torch.is_floating_point(meta_param_sd_base[paramkeys]):#更新过程只考虑浮点参数信息
                continue
            sd_diff[paramkeys] = (current_subtaskmodel_sd[paramkeys]-meta_param_sd_base[paramkeys]).detach().clone()#clone也是避免创造任何引用的出现
        eposide_param_sd_diff.append(sd_diff)

        #记录采样训练信息（用于训练数据记录）
        sampleupdatereward = sampleupdatereward/bss_mmnum
        sampleupdaterewards.append(sampleupdatereward)#meta更新的累计奖励信息记录

    #基于采集的参数位移计算均值
    avg_sd_diff = {}
    for param_key in meta_param_sd_base.keys():
        if not torch.is_floating_point(meta_param_sd_base[param_key]):
            continue
        # 收集所有子任务中的差值
        diffs = [sd[param_key] for sd in eposide_param_sd_diff]
        avg_sd_diff[param_key] = torch.stack(diffs, dim=0).mean(dim=0)#这里也可用直接求和sum的方式再求平均，但是隐性问题在于求和过程可能会出现数据的广播 导致原本存在错误shape的数据 自动调整为正确的形状，难以发现错误

    #对均值位移做标准化的缩放
    with torch.no_grad():#这里做了一个缩放对梯度
        total_sq = 0.0
        for v in avg_sd_diff.values():
            total_sq += v.pow(2).sum().item()
        delta_norm = total_sq ** 0.5
        max_delta_norm = 1.0
        scale = min(1.0, max_delta_norm / (delta_norm + 1e-12))
        for k in avg_sd_diff:
            avg_sd_diff[k].mul_(scale)

    meta_G = delta_norm * scale  # 计算位移范数 （缩放后），meta_G是一个梯度范数，记录梯度的大小

    hist_meta_G.append(meta_G)#

    #基于缩放后的位移更新元模型
    # new_sd = {}
    # with torch.no_grad():
    #     for param_key in meta_param_sd_base.keys():
    #         if param_key in avg_sd_diff:
    #             new_sd[param_key] = meta_param_sd_base[param_key] + options.meta_lr * avg_sd_diff[param_key] 
    #         else:
    #             new_sd[param_key] = meta_param_sd_base[param_key]

    # metaevagent.evagent.load_state_dict(new_sd)  
    # metaevagent.evagent_target.load_state_dict(new_sd)  

    meta_drl.bss_agent_optimizer.zero_grad()
    with torch.no_grad():
        for name, p in meta_drl.bss_agent.named_parameters():
            if name not in avg_sd_diff:
                continue
            # pseudo-grad: 用位移方向
            g = avg_sd_diff[name]
            # 前面的位移差值是子模型-meta模型，因此更新方向为加上avg_sd_diff
            # 因为 optimizer 默认是 θ -= lr * grad 而
            p.grad = (-g).detach().clone()
            #p.grad.clamp_(-1,1)#已经在meta_G处做了位移大小的标准化，再次使用clip可能导致更新过小
    meta_drl.bss_agent_optimizer.step()
    
    meta_drl.bss_agent_target.load_state_dict(meta_drl.bss_agent.state_dict())
    
    if (ep%200==0) and (ep > 0):
        savepath = os.path.join(metaevshistdata_dir,'PPOforBSS_metamodel_training_histparam_ep'+str(ep)+'.pth') 
        torch.save(meta_drl.bss_agent.state_dict(),savepath)
    #基于元模型位移范数的变化情况确定是否停止更新 
    #region 但是在随机采样的环境下 好像不太实用，目前已停止
    # if_updateend = False
    # metaupdate_change = 9999#首次赋值为无限大
    # if prev_G is not None:
    #     metaupdate_change = abs(meta_G-prev_G)/(prev_G + 1e-12)
    #     if metaupdate_change < metachange_eps:
    #         stable_count +=1
    #     else:#注意需要范数的连续变化较小才表明模型更新完毕，而不是累计变化
    #         stable_count = 0
        
    #     if stable_count >= meta_static_K:#当连续更新的梯度变化较小时，则可以停止更新模型??由于采样影响 所以不能以每步的收敛情况确定
    #         if_updateend = True
    # prev_G =  meta_G
    #endregion

    #基于历史meta_G均值标准差的记录
    if_updateend = False

    if len(hist_meta_G)>=meta_G_length and ep>= mintraining_ep:#大于最小训练步数且满足梯度位移范数在一定范围内变化
        hist_meta_G_tensor = torch.tensor(hist_meta_G,dtype=torch.float32)
        hist_meta_G_avg = hist_meta_G_tensor.mean().item()#更新大小
        hist_meta_G_std = hist_meta_G_tensor.std(unbiased=False).item()#unbiased=False：这是总体标准差，更适合滑动窗口
        hist_meta_G_cv = hist_meta_G_std/(hist_meta_G_avg + 1e-12)#更新是否足够稳定
        meta_G_avgs.append(hist_meta_G_avg)
        meta_G_std.append(hist_meta_G_std)
        meta_G_cv.append(hist_meta_G_cv)
        #中位数用于动态更新mean阈值（由于mean来自meta模型的梯度位移范数，
        #其大小受多种因素影响，其数值大小范围偏差在不同任务下较大，使用动态的阈值设定可以避免均值大小与固定阈值差别过大的情况出现）
        hist_meta_G_median = hist_meta_G_tensor.median().item()
        eps_abs = 0.3 * hist_meta_G_median

        if hist_meta_G_avg<eps_abs and hist_meta_G_cv<eps_cv:#当meta更新足够小，且稳定时，停止更新
            stable_count+=1
        else :
            stable_count=0

        if stable_count >= meta_static_K:#当连续更新的梯度变化较小时，则可以停止更新模型??由于采样影响 所以不能以每步的收敛情况确定
            if_updateend = True
    

    # #基于子任务平均值更新元模型
    # metaevagent.ev_ppo_optimizer.zero_grad()

    sampleupdata_stage_avgreturn = sum(sampleupdaterewards)/sample_subtasknum
    sampleupdata_avgreturns.append(sampleupdata_stage_avgreturn)
    #metachanges.append(metaupdate_change)
    # print('第{0}轮meta更新用时{1:.3f}秒,采样环境平均累计奖励:{2:.3f},meta模型的更新梯度范数 大小,变化，阈值次数 分别为:{3:.3f},{4:.3f}，{5}.是否需要停止更新{6}'.format(\
    #          ep,time.time()-epstart,sampleupdata_stage_avgreturn, meta_G, metaupdate_change,stable_count,if_updateend))
    print('第{0}轮meta更新用时{1:.3f}秒,采样环境平均累计奖励:{2:.3f},meta模型的更新梯度范数为{3:.3f},历史更新梯度大小的累计均值,标准差和CV范数分别为:{4:.3f}，{5:.3f}.{6:.3f}，更新阈值次数{7}，是否需要停止更新{8}'.format(\
             ep,time.time()-epstart,sampleupdata_stage_avgreturn, meta_G, hist_meta_G_avg, hist_meta_G_std,hist_meta_G_cv, stable_count,if_updateend))
    if if_updateend:
        break
# Out:
# 第0轮meta更新用时10.182秒,采样环境平均累计奖励:-313.500,meta模型的更新梯度范数为0.042,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第1轮meta更新用时10.590秒,采样环境平均累计奖励:-303.795,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第2轮meta更新用时10.804秒,采样环境平均累计奖励:-306.119,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第3轮meta更新用时10.561秒,采样环境平均累计奖励:-310.858,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第4轮meta更新用时10.599秒,采样环境平均累计奖励:-303.015,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第5轮meta更新用时10.392秒,采样环境平均累计奖励:-307.761,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第6轮meta更新用时10.403秒,采样环境平均累计奖励:-313.020,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第7轮meta更新用时10.516秒,采样环境平均累计奖励:-308.027,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第8轮meta更新用时11.199秒,采样环境平均累计奖励:-312.403,meta模型的更新梯度范数为0.039,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第9轮meta更新用时10.690秒,采样环境平均累计奖励:-308.538,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第10轮meta更新用时10.508秒,采样环境平均累计奖励:-304.476,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第11轮meta更新用时10.454秒,采样环境平均累计奖励:-306.805,meta模型的更新梯度范数为0.033,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第12轮meta更新用时10.587秒,采样环境平均累计奖励:-309.182,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第13轮meta更新用时10.514秒,采样环境平均累计奖励:-306.412,meta模型的更新梯度范数为0.033,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第14轮meta更新用时10.387秒,采样环境平均累计奖励:-304.586,meta模型的更新梯度范数为0.033,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第15轮meta更新用时10.656秒,采样环境平均累计奖励:-301.574,meta模型的更新梯度范数为0.033,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第16轮meta更新用时10.881秒,采样环境平均累计奖励:-301.914,meta模型的更新梯度范数为0.032,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第17轮meta更新用时10.636秒,采样环境平均累计奖励:-304.539,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第18轮meta更新用时10.367秒,采样环境平均累计奖励:-301.890,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第19轮meta更新用时10.463秒,采样环境平均累计奖励:-301.934,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第20轮meta更新用时10.323秒,采样环境平均累计奖励:-304.314,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第21轮meta更新用时10.698秒,采样环境平均累计奖励:-303.845,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第22轮meta更新用时10.532秒,采样环境平均累计奖励:-297.247,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第23轮meta更新用时10.629秒,采样环境平均累计奖励:-299.286,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第24轮meta更新用时10.654秒,采样环境平均累计奖励:-300.337,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第25轮meta更新用时10.434秒,采样环境平均累计奖励:-302.999,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第26轮meta更新用时10.522秒,采样环境平均累计奖励:-301.105,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第27轮meta更新用时10.533秒,采样环境平均累计奖励:-304.473,meta模型的更新梯度范数为0.032,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第28轮meta更新用时10.418秒,采样环境平均累计奖励:-301.713,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第29轮meta更新用时10.409秒,采样环境平均累计奖励:-299.132,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第30轮meta更新用时10.257秒,采样环境平均累计奖励:-301.078,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第31轮meta更新用时10.314秒,采样环境平均累计奖励:-299.549,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第32轮meta更新用时10.292秒,采样环境平均累计奖励:-297.622,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第33轮meta更新用时10.586秒,采样环境平均累计奖励:-300.640,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第34轮meta更新用时10.665秒,采样环境平均累计奖励:-295.232,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第35轮meta更新用时10.627秒,采样环境平均累计奖励:-303.409,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第36轮meta更新用时10.617秒,采样环境平均累计奖励:-295.738,meta模型的更新梯度范数为0.033,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第37轮meta更新用时10.546秒,采样环境平均累计奖励:-297.536,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第38轮meta更新用时10.655秒,采样环境平均累计奖励:-297.036,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第39轮meta更新用时10.796秒,采样环境平均累计奖励:-297.274,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第40轮meta更新用时10.571秒,采样环境平均累计奖励:-301.372,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第41轮meta更新用时10.394秒,采样环境平均累计奖励:-294.751,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第42轮meta更新用时10.360秒,采样环境平均累计奖励:-293.961,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第43轮meta更新用时10.412秒,采样环境平均累计奖励:-291.247,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第44轮meta更新用时10.745秒,采样环境平均累计奖励:-296.279,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第45轮meta更新用时11.236秒,采样环境平均累计奖励:-292.673,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第46轮meta更新用时11.103秒,采样环境平均累计奖励:-289.711,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第47轮meta更新用时11.155秒,采样环境平均累计奖励:-297.759,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第48轮meta更新用时10.718秒,采样环境平均累计奖励:-295.932,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第49轮meta更新用时10.683秒,采样环境平均累计奖励:-291.301,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第50轮meta更新用时11.157秒,采样环境平均累计奖励:-295.652,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第51轮meta更新用时10.916秒,采样环境平均累计奖励:-293.705,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第52轮meta更新用时10.735秒,采样环境平均累计奖励:-293.430,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第53轮meta更新用时10.565秒,采样环境平均累计奖励:-293.087,meta模型的更新梯度范数为0.042,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第54轮meta更新用时10.325秒,采样环境平均累计奖励:-296.450,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第55轮meta更新用时10.496秒,采样环境平均累计奖励:-296.659,meta模型的更新梯度范数为0.039,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第56轮meta更新用时10.691秒,采样环境平均累计奖励:-297.196,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第57轮meta更新用时10.460秒,采样环境平均累计奖励:-297.444,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第58轮meta更新用时10.822秒,采样环境平均累计奖励:-292.662,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第59轮meta更新用时10.747秒,采样环境平均累计奖励:-292.181,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第60轮meta更新用时11.197秒,采样环境平均累计奖励:-297.310,meta模型的更新梯度范数为0.033,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第61轮meta更新用时10.943秒,采样环境平均累计奖励:-291.741,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第62轮meta更新用时10.430秒,采样环境平均累计奖励:-294.078,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第63轮meta更新用时10.693秒,采样环境平均累计奖励:-292.851,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第64轮meta更新用时10.551秒,采样环境平均累计奖励:-291.670,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第65轮meta更新用时10.478秒,采样环境平均累计奖励:-296.195,meta模型的更新梯度范数为0.033,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第66轮meta更新用时10.758秒,采样环境平均累计奖励:-293.227,meta模型的更新梯度范数为0.032,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第67轮meta更新用时10.481秒,采样环境平均累计奖励:-286.170,meta模型的更新梯度范数为0.032,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第68轮meta更新用时10.821秒,采样环境平均累计奖励:-287.956,meta模型的更新梯度范数为0.032,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第69轮meta更新用时10.871秒,采样环境平均累计奖励:-283.458,meta模型的更新梯度范数为0.033,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第70轮meta更新用时10.540秒,采样环境平均累计奖励:-295.355,meta模型的更新梯度范数为0.033,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第71轮meta更新用时10.789秒,采样环境平均累计奖励:-290.394,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第72轮meta更新用时11.041秒,采样环境平均累计奖励:-289.251,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第73轮meta更新用时10.748秒,采样环境平均累计奖励:-290.653,meta模型的更新梯度范数为0.033,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第74轮meta更新用时10.730秒,采样环境平均累计奖励:-293.912,meta模型的更新梯度范数为0.032,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第75轮meta更新用时10.747秒,采样环境平均累计奖励:-289.764,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第76轮meta更新用时10.771秒,采样环境平均累计奖励:-288.860,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第77轮meta更新用时10.557秒,采样环境平均累计奖励:-295.128,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第78轮meta更新用时11.158秒,采样环境平均累计奖励:-285.707,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第79轮meta更新用时10.641秒,采样环境平均累计奖励:-287.408,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第80轮meta更新用时10.569秒,采样环境平均累计奖励:-288.367,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第81轮meta更新用时10.368秒,采样环境平均累计奖励:-281.890,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第82轮meta更新用时10.350秒,采样环境平均累计奖励:-288.129,meta模型的更新梯度范数为0.033,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第83轮meta更新用时10.419秒,采样环境平均累计奖励:-286.732,meta模型的更新梯度范数为0.033,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第84轮meta更新用时10.433秒,采样环境平均累计奖励:-284.792,meta模型的更新梯度范数为0.033,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第85轮meta更新用时10.365秒,采样环境平均累计奖励:-283.672,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第86轮meta更新用时10.503秒,采样环境平均累计奖励:-285.005,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第87轮meta更新用时10.579秒,采样环境平均累计奖励:-283.436,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第88轮meta更新用时10.487秒,采样环境平均累计奖励:-284.935,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第89轮meta更新用时10.374秒,采样环境平均累计奖励:-278.648,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第90轮meta更新用时10.459秒,采样环境平均累计奖励:-286.299,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第91轮meta更新用时10.341秒,采样环境平均累计奖励:-289.030,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第92轮meta更新用时10.334秒,采样环境平均累计奖励:-288.478,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第93轮meta更新用时10.215秒,采样环境平均累计奖励:-284.219,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第94轮meta更新用时10.221秒,采样环境平均累计奖励:-284.388,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第95轮meta更新用时10.382秒,采样环境平均累计奖励:-285.619,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第96轮meta更新用时10.242秒,采样环境平均累计奖励:-283.463,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第97轮meta更新用时10.458秒,采样环境平均累计奖励:-280.850,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第98轮meta更新用时10.474秒,采样环境平均累计奖励:-286.673,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第99轮meta更新用时10.397秒,采样环境平均累计奖励:-281.270,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第100轮meta更新用时10.643秒,采样环境平均累计奖励:-280.967,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第101轮meta更新用时10.444秒,采样环境平均累计奖励:-282.123,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第102轮meta更新用时10.448秒,采样环境平均累计奖励:-282.200,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第103轮meta更新用时10.578秒,采样环境平均累计奖励:-281.440,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第104轮meta更新用时10.411秒,采样环境平均累计奖励:-283.481,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第105轮meta更新用时10.518秒,采样环境平均累计奖励:-280.282,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第106轮meta更新用时10.876秒,采样环境平均累计奖励:-287.951,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第107轮meta更新用时10.753秒,采样环境平均累计奖励:-283.601,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第108轮meta更新用时10.531秒,采样环境平均累计奖励:-279.836,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第109轮meta更新用时10.693秒,采样环境平均累计奖励:-279.367,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第110轮meta更新用时10.425秒,采样环境平均累计奖励:-282.359,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第111轮meta更新用时10.464秒,采样环境平均累计奖励:-275.902,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第112轮meta更新用时11.102秒,采样环境平均累计奖励:-281.046,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第113轮meta更新用时10.698秒,采样环境平均累计奖励:-279.788,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第114轮meta更新用时9.562秒,采样环境平均累计奖励:-279.610,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第115轮meta更新用时10.228秒,采样环境平均累计奖励:-277.603,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第116轮meta更新用时10.321秒,采样环境平均累计奖励:-280.883,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第117轮meta更新用时10.625秒,采样环境平均累计奖励:-276.585,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第118轮meta更新用时10.360秒,采样环境平均累计奖励:-282.674,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第119轮meta更新用时10.427秒,采样环境平均累计奖励:-276.712,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第120轮meta更新用时10.813秒,采样环境平均累计奖励:-280.589,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第121轮meta更新用时10.570秒,采样环境平均累计奖励:-274.515,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第122轮meta更新用时10.402秒,采样环境平均累计奖励:-279.638,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第123轮meta更新用时10.214秒,采样环境平均累计奖励:-278.056,meta模型的更新梯度范数为0.039,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第124轮meta更新用时10.589秒,采样环境平均累计奖励:-278.835,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第125轮meta更新用时10.687秒,采样环境平均累计奖励:-278.494,meta模型的更新梯度范数为0.039,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第126轮meta更新用时10.394秒,采样环境平均累计奖励:-276.335,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第127轮meta更新用时10.398秒,采样环境平均累计奖励:-279.773,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第128轮meta更新用时10.321秒,采样环境平均累计奖励:-279.465,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第129轮meta更新用时10.541秒,采样环境平均累计奖励:-280.435,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第130轮meta更新用时10.713秒,采样环境平均累计奖励:-278.699,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第131轮meta更新用时10.513秒,采样环境平均累计奖励:-280.569,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第132轮meta更新用时10.510秒,采样环境平均累计奖励:-279.852,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第133轮meta更新用时10.728秒,采样环境平均累计奖励:-283.194,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第134轮meta更新用时10.715秒,采样环境平均累计奖励:-279.864,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第135轮meta更新用时10.313秒,采样环境平均累计奖励:-283.592,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第136轮meta更新用时10.879秒,采样环境平均累计奖励:-276.530,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第137轮meta更新用时10.741秒,采样环境平均累计奖励:-280.997,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第138轮meta更新用时10.512秒,采样环境平均累计奖励:-278.683,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第139轮meta更新用时10.750秒,采样环境平均累计奖励:-278.230,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第140轮meta更新用时10.315秒,采样环境平均累计奖励:-279.504,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第141轮meta更新用时10.652秒,采样环境平均累计奖励:-274.187,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第142轮meta更新用时10.487秒,采样环境平均累计奖励:-278.005,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第143轮meta更新用时10.410秒,采样环境平均累计奖励:-279.581,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第144轮meta更新用时10.407秒,采样环境平均累计奖励:-279.049,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第145轮meta更新用时10.293秒,采样环境平均累计奖励:-276.989,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第146轮meta更新用时10.181秒,采样环境平均累计奖励:-284.310,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第147轮meta更新用时10.235秒,采样环境平均累计奖励:-280.789,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第148轮meta更新用时10.229秒,采样环境平均累计奖励:-285.149,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第149轮meta更新用时10.590秒,采样环境平均累计奖励:-283.906,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第150轮meta更新用时10.555秒,采样环境平均累计奖励:-276.558,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第151轮meta更新用时10.396秒,采样环境平均累计奖励:-281.541,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第152轮meta更新用时10.357秒,采样环境平均累计奖励:-274.377,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第153轮meta更新用时10.499秒,采样环境平均累计奖励:-280.832,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第154轮meta更新用时10.678秒,采样环境平均累计奖励:-277.494,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第155轮meta更新用时10.710秒,采样环境平均累计奖励:-275.629,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第156轮meta更新用时10.200秒,采样环境平均累计奖励:-278.177,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第157轮meta更新用时10.639秒,采样环境平均累计奖励:-279.788,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第158轮meta更新用时10.660秒,采样环境平均累计奖励:-275.079,meta模型的更新梯度范数为0.033,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第159轮meta更新用时10.616秒,采样环境平均累计奖励:-280.295,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第160轮meta更新用时10.821秒,采样环境平均累计奖励:-277.199,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第161轮meta更新用时11.009秒,采样环境平均累计奖励:-278.117,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第162轮meta更新用时10.906秒,采样环境平均累计奖励:-279.574,meta模型的更新梯度范数为0.039,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第163轮meta更新用时10.665秒,采样环境平均累计奖励:-278.185,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第164轮meta更新用时10.778秒,采样环境平均累计奖励:-276.331,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第165轮meta更新用时10.618秒,采样环境平均累计奖励:-275.385,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第166轮meta更新用时10.225秒,采样环境平均累计奖励:-279.272,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第167轮meta更新用时10.443秒,采样环境平均累计奖励:-271.800,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第168轮meta更新用时10.424秒,采样环境平均累计奖励:-279.635,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第169轮meta更新用时10.509秒,采样环境平均累计奖励:-275.560,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第170轮meta更新用时10.301秒,采样环境平均累计奖励:-277.399,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第171轮meta更新用时10.366秒,采样环境平均累计奖励:-280.343,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第172轮meta更新用时10.366秒,采样环境平均累计奖励:-275.634,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第173轮meta更新用时10.160秒,采样环境平均累计奖励:-272.988,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第174轮meta更新用时10.400秒,采样环境平均累计奖励:-274.245,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第175轮meta更新用时10.555秒,采样环境平均累计奖励:-279.650,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第176轮meta更新用时10.586秒,采样环境平均累计奖励:-274.697,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第177轮meta更新用时10.230秒,采样环境平均累计奖励:-278.795,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第178轮meta更新用时10.349秒,采样环境平均累计奖励:-273.785,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第179轮meta更新用时10.466秒,采样环境平均累计奖励:-276.029,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第180轮meta更新用时10.474秒,采样环境平均累计奖励:-275.962,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第181轮meta更新用时10.450秒,采样环境平均累计奖励:-275.151,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第182轮meta更新用时10.374秒,采样环境平均累计奖励:-275.372,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第183轮meta更新用时10.451秒,采样环境平均累计奖励:-278.778,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第184轮meta更新用时10.277秒,采样环境平均累计奖励:-276.779,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第185轮meta更新用时10.553秒,采样环境平均累计奖励:-278.157,meta模型的更新梯度范数为0.033,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第186轮meta更新用时10.479秒,采样环境平均累计奖励:-271.773,meta模型的更新梯度范数为0.033,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第187轮meta更新用时10.605秒,采样环境平均累计奖励:-273.909,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第188轮meta更新用时10.732秒,采样环境平均累计奖励:-276.520,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第189轮meta更新用时10.675秒,采样环境平均累计奖励:-274.461,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第190轮meta更新用时10.603秒,采样环境平均累计奖励:-277.069,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第191轮meta更新用时10.291秒,采样环境平均累计奖励:-270.038,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第192轮meta更新用时10.624秒,采样环境平均累计奖励:-275.235,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第193轮meta更新用时10.390秒,采样环境平均累计奖励:-277.501,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第194轮meta更新用时11.019秒,采样环境平均累计奖励:-277.776,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第195轮meta更新用时10.445秒,采样环境平均累计奖励:-277.314,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第196轮meta更新用时10.163秒,采样环境平均累计奖励:-277.255,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第197轮meta更新用时10.399秒,采样环境平均累计奖励:-274.940,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第198轮meta更新用时10.375秒,采样环境平均累计奖励:-276.297,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第199轮meta更新用时10.459秒,采样环境平均累计奖励:-279.784,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:9999.000，9999.000.9999.000，更新阈值次数0，是否需要停止更新False
# 第200轮meta更新用时10.333秒,采样环境平均累计奖励:-277.731,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.029，更新阈值次数0，是否需要停止更新False
# 第201轮meta更新用时10.492秒,采样环境平均累计奖励:-277.232,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.027，更新阈值次数0，是否需要停止更新False
# 第202轮meta更新用时10.563秒,采样环境平均累计奖励:-272.089,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.035，0.001.0.027，更新阈值次数0，是否需要停止更新False
# 第203轮meta更新用时10.417秒,采样环境平均累计奖励:-278.097,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.035，0.001.0.027，更新阈值次数0，是否需要停止更新False
# 第204轮meta更新用时10.433秒,采样环境平均累计奖励:-276.842,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.035，0.001.0.027，更新阈值次数0，是否需要停止更新False
# 第205轮meta更新用时10.333秒,采样环境平均累计奖励:-277.763,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.035，0.001.0.027，更新阈值次数0，是否需要停止更新False
# 第206轮meta更新用时10.320秒,采样环境平均累计奖励:-274.785,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.035，0.001.0.026，更新阈值次数0，是否需要停止更新False
# 第207轮meta更新用时10.500秒,采样环境平均累计奖励:-280.449,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.035，0.001.0.027，更新阈值次数0，是否需要停止更新False
# 第208轮meta更新用时10.527秒,采样环境平均累计奖励:-274.771,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.030，更新阈值次数0，是否需要停止更新False
# 第209轮meta更新用时10.662秒,采样环境平均累计奖励:-276.028,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.031，更新阈值次数0，是否需要停止更新False
# 第210轮meta更新用时10.425秒,采样环境平均累计奖励:-275.687,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.032，更新阈值次数0，是否需要停止更新False
# 第211轮meta更新用时10.390秒,采样环境平均累计奖励:-275.468,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.033，更新阈值次数0，是否需要停止更新False
# 第212轮meta更新用时10.249秒,采样环境平均累计奖励:-278.718,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.033，更新阈值次数0，是否需要停止更新False
# 第213轮meta更新用时10.476秒,采样环境平均累计奖励:-279.013,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.034，更新阈值次数0，是否需要停止更新False
# 第214轮meta更新用时10.790秒,采样环境平均累计奖励:-280.209,meta模型的更新梯度范数为0.033,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.036，更新阈值次数0，是否需要停止更新False
# 第215轮meta更新用时10.430秒,采样环境平均累计奖励:-277.774,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.035，更新阈值次数0，是否需要停止更新False
# 第216轮meta更新用时10.420秒,采样环境平均累计奖励:-275.597,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.033，更新阈值次数0，是否需要停止更新False
# 第217轮meta更新用时10.296秒,采样环境平均累计奖励:-279.110,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.033，更新阈值次数0，是否需要停止更新False
# 第218轮meta更新用时10.312秒,采样环境平均累计奖励:-275.297,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.033，更新阈值次数0，是否需要停止更新False
# 第219轮meta更新用时10.635秒,采样环境平均累计奖励:-278.664,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.033，更新阈值次数0，是否需要停止更新False
# 第220轮meta更新用时10.244秒,采样环境平均累计奖励:-274.357,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.033，更新阈值次数0，是否需要停止更新False
# 第221轮meta更新用时10.570秒,采样环境平均累计奖励:-279.067,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.033，更新阈值次数0，是否需要停止更新False
# 第222轮meta更新用时10.456秒,采样环境平均累计奖励:-277.208,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.032，更新阈值次数0，是否需要停止更新False
# 第223轮meta更新用时10.476秒,采样环境平均累计奖励:-280.517,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.031，更新阈值次数0，是否需要停止更新False
# 第224轮meta更新用时10.176秒,采样环境平均累计奖励:-277.974,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.031，更新阈值次数0，是否需要停止更新False
# 第225轮meta更新用时10.165秒,采样环境平均累计奖励:-275.877,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.031，更新阈值次数0，是否需要停止更新False
# 第226轮meta更新用时10.362秒,采样环境平均累计奖励:-278.485,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.031，更新阈值次数0，是否需要停止更新False
# 第227轮meta更新用时10.618秒,采样环境平均累计奖励:-280.626,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.031，更新阈值次数0，是否需要停止更新False
# 第228轮meta更新用时10.491秒,采样环境平均累计奖励:-282.907,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.031，更新阈值次数0，是否需要停止更新False
# 第229轮meta更新用时10.617秒,采样环境平均累计奖励:-275.056,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.031，更新阈值次数0，是否需要停止更新False
# 第230轮meta更新用时10.237秒,采样环境平均累计奖励:-273.558,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.032，更新阈值次数0，是否需要停止更新False
# 第231轮meta更新用时10.732秒,采样环境平均累计奖励:-273.115,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.032，更新阈值次数0，是否需要停止更新False
# 第232轮meta更新用时10.620秒,采样环境平均累计奖励:-275.834,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.032，更新阈值次数0，是否需要停止更新False
# 第233轮meta更新用时10.163秒,采样环境平均累计奖励:-277.473,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.032，更新阈值次数0，是否需要停止更新False
# 第234轮meta更新用时10.492秒,采样环境平均累计奖励:-273.763,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.032，更新阈值次数0，是否需要停止更新False
# 第235轮meta更新用时10.335秒,采样环境平均累计奖励:-283.831,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.032，更新阈值次数0，是否需要停止更新False
# 第236轮meta更新用时10.343秒,采样环境平均累计奖励:-282.147,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.032，更新阈值次数0，是否需要停止更新False
# 第237轮meta更新用时10.281秒,采样环境平均累计奖励:-277.521,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.032，更新阈值次数0，是否需要停止更新False
# 第238轮meta更新用时10.426秒,采样环境平均累计奖励:-277.002,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.035，0.001.0.030，更新阈值次数0，是否需要停止更新False
# 第239轮meta更新用时10.454秒,采样环境平均累计奖励:-280.417,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.035，0.001.0.028，更新阈值次数0，是否需要停止更新False
# 第240轮meta更新用时10.371秒,采样环境平均累计奖励:-277.641,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.035，0.001.0.027，更新阈值次数0，是否需要停止更新False
# 第241轮meta更新用时10.802秒,采样环境平均累计奖励:-283.800,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.035，0.001.0.025，更新阈值次数0，是否需要停止更新False
# 第242轮meta更新用时10.514秒,采样环境平均累计奖励:-274.172,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.035，0.001.0.026，更新阈值次数0，是否需要停止更新False
# 第243轮meta更新用时10.131秒,采样环境平均累计奖励:-272.345,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.035，0.001.0.024，更新阈值次数0，是否需要停止更新False
# 第244轮meta更新用时10.364秒,采样环境平均累计奖励:-273.437,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.035，0.001.0.022，更新阈值次数0，是否需要停止更新False
# 第245轮meta更新用时10.340秒,采样环境平均累计奖励:-274.026,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.035，0.001.0.022，更新阈值次数0，是否需要停止更新False
# 第246轮meta更新用时10.410秒,采样环境平均累计奖励:-272.389,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.024，更新阈值次数0，是否需要停止更新False
# 第247轮meta更新用时10.437秒,采样环境平均累计奖励:-274.699,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.024，更新阈值次数0，是否需要停止更新False
# 第248轮meta更新用时10.237秒,采样环境平均累计奖励:-276.025,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.024，更新阈值次数0，是否需要停止更新False
# 第249轮meta更新用时10.059秒,采样环境平均累计奖励:-278.566,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.024，更新阈值次数0，是否需要停止更新False
# 第250轮meta更新用时10.319秒,采样环境平均累计奖励:-277.437,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.035，0.001.0.024，更新阈值次数0，是否需要停止更新False
# 第251轮meta更新用时10.422秒,采样环境平均累计奖励:-277.572,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.035，0.001.0.024，更新阈值次数0，是否需要停止更新False
# 第252轮meta更新用时10.260秒,采样环境平均累计奖励:-277.544,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.035，0.001.0.025，更新阈值次数0，是否需要停止更新False
# 第253轮meta更新用时10.415秒,采样环境平均累计奖励:-279.831,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.027，更新阈值次数0，是否需要停止更新False
# 第254轮meta更新用时10.497秒,采样环境平均累计奖励:-274.733,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.027，更新阈值次数0，是否需要停止更新False
# 第255轮meta更新用时10.522秒,采样环境平均累计奖励:-278.575,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.027，更新阈值次数0，是否需要停止更新False
# 第256轮meta更新用时10.735秒,采样环境平均累计奖励:-276.806,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.027，更新阈值次数0，是否需要停止更新False
# 第257轮meta更新用时10.487秒,采样环境平均累计奖励:-280.040,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.035，0.001.0.027，更新阈值次数0，是否需要停止更新False
# 第258轮meta更新用时10.645秒,采样环境平均累计奖励:-275.264,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.035，0.001.0.028，更新阈值次数0，是否需要停止更新False
# 第259轮meta更新用时10.766秒,采样环境平均累计奖励:-275.654,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.030，更新阈值次数0，是否需要停止更新False
# 第260轮meta更新用时10.554秒,采样环境平均累计奖励:-279.216,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.030，更新阈值次数0，是否需要停止更新False
# 第261轮meta更新用时10.626秒,采样环境平均累计奖励:-276.852,meta模型的更新梯度范数为0.039,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.032，更新阈值次数0，是否需要停止更新False
# 第262轮meta更新用时10.439秒,采样环境平均累计奖励:-281.930,meta模型的更新梯度范数为0.040,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.039，更新阈值次数0，是否需要停止更新False
# 第263轮meta更新用时11.185秒,采样环境平均累计奖励:-275.232,meta模型的更新梯度范数为0.039,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.001.0.040，更新阈值次数0，是否需要停止更新False
# 第264轮meta更新用时10.840秒,采样环境平均累计奖励:-277.483,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.002.0.041，更新阈值次数0，是否需要停止更新False
# 第265轮meta更新用时10.675秒,采样环境平均累计奖励:-273.678,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.002.0.041，更新阈值次数0，是否需要停止更新False
# 第266轮meta更新用时10.792秒,采样环境平均累计奖励:-283.460,meta模型的更新梯度范数为0.039,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.002.0.043，更新阈值次数0，是否需要停止更新False
# 第267轮meta更新用时11.108秒,采样环境平均累计奖励:-278.916,meta模型的更新梯度范数为0.039,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.036，0.002.0.044，更新阈值次数0，是否需要停止更新False
# 第268轮meta更新用时10.448秒,采样环境平均累计奖励:-281.159,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.042，更新阈值次数0，是否需要停止更新False
# 第269轮meta更新用时10.952秒,采样环境平均累计奖励:-275.297,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.042，更新阈值次数0，是否需要停止更新False
# 第270轮meta更新用时10.750秒,采样环境平均累计奖励:-273.819,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.042，更新阈值次数0，是否需要停止更新False
# 第271轮meta更新用时10.671秒,采样环境平均累计奖励:-277.430,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.041，更新阈值次数0，是否需要停止更新False
# 第272轮meta更新用时10.610秒,采样环境平均累计奖励:-279.728,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.040，更新阈值次数0，是否需要停止更新False
# 第273轮meta更新用时10.259秒,采样环境平均累计奖励:-274.583,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.038，更新阈值次数0，是否需要停止更新False
# 第274轮meta更新用时10.983秒,采样环境平均累计奖励:-278.886,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.038，更新阈值次数0，是否需要停止更新False
# 第275轮meta更新用时10.664秒,采样环境平均累计奖励:-282.949,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.039，更新阈值次数0，是否需要停止更新False
# 第276轮meta更新用时10.531秒,采样环境平均累计奖励:-277.616,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.040，更新阈值次数0，是否需要停止更新False
# 第277轮meta更新用时10.358秒,采样环境平均累计奖励:-272.720,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.040，更新阈值次数0，是否需要停止更新False
# 第278轮meta更新用时10.419秒,采样环境平均累计奖励:-276.780,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.039，更新阈值次数0，是否需要停止更新False
# 第279轮meta更新用时10.295秒,采样环境平均累计奖励:-273.339,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.037，更新阈值次数0，是否需要停止更新False
# 第280轮meta更新用时10.229秒,采样环境平均累计奖励:-269.893,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.036，更新阈值次数0，是否需要停止更新False
# 第281轮meta更新用时10.671秒,采样环境平均累计奖励:-276.452,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.036，更新阈值次数0，是否需要停止更新False
# 第282轮meta更新用时10.414秒,采样环境平均累计奖励:-276.347,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.036，更新阈值次数0，是否需要停止更新False
# 第283轮meta更新用时10.423秒,采样环境平均累计奖励:-276.673,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.037，更新阈值次数0，是否需要停止更新False
# 第284轮meta更新用时10.439秒,采样环境平均累计奖励:-275.461,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.037，更新阈值次数0，是否需要停止更新False
# 第285轮meta更新用时10.646秒,采样环境平均累计奖励:-273.051,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.037，更新阈值次数0，是否需要停止更新False
# 第286轮meta更新用时10.267秒,采样环境平均累计奖励:-278.538,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.036，更新阈值次数0，是否需要停止更新False
# 第287轮meta更新用时10.440秒,采样环境平均累计奖励:-274.117,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.034，更新阈值次数0，是否需要停止更新False
# 第288轮meta更新用时10.427秒,采样环境平均累计奖励:-272.222,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.034，更新阈值次数0，是否需要停止更新False
# 第289轮meta更新用时10.555秒,采样环境平均累计奖励:-276.170,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.035，更新阈值次数0，是否需要停止更新False
# 第290轮meta更新用时10.351秒,采样环境平均累计奖励:-272.066,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.035，更新阈值次数0，是否需要停止更新False
# 第291轮meta更新用时10.517秒,采样环境平均累计奖励:-278.212,meta模型的更新梯度范数为0.040,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.037，更新阈值次数0，是否需要停止更新False
# 第292轮meta更新用时10.241秒,采样环境平均累计奖励:-274.573,meta模型的更新梯度范数为0.039,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.034，更新阈值次数0，是否需要停止更新False
# 第293轮meta更新用时10.519秒,采样环境平均累计奖励:-270.884,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.034，更新阈值次数0，是否需要停止更新False
# 第294轮meta更新用时10.348秒,采样环境平均累计奖励:-276.677,meta模型的更新梯度范数为0.039,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.035，更新阈值次数0，是否需要停止更新False
# 第295轮meta更新用时10.485秒,采样环境平均累计奖励:-275.391,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.035，更新阈值次数0，是否需要停止更新False
# 第296轮meta更新用时10.316秒,采样环境平均累计奖励:-275.354,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.034，更新阈值次数0，是否需要停止更新False
# 第297轮meta更新用时10.353秒,采样环境平均累计奖励:-274.804,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.032，更新阈值次数0，是否需要停止更新False
# 第298轮meta更新用时10.369秒,采样环境平均累计奖励:-277.256,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.033，更新阈值次数0，是否需要停止更新False
# 第299轮meta更新用时10.442秒,采样环境平均累计奖励:-271.877,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.033，更新阈值次数0，是否需要停止更新False
# 第300轮meta更新用时10.456秒,采样环境平均累计奖励:-275.822,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.033，更新阈值次数0，是否需要停止更新False
# 第301轮meta更新用时10.288秒,采样环境平均累计奖励:-273.693,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.033，更新阈值次数0，是否需要停止更新False
# 第302轮meta更新用时10.215秒,采样环境平均累计奖励:-270.953,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.033，更新阈值次数0，是否需要停止更新False
# 第303轮meta更新用时10.422秒,采样环境平均累计奖励:-275.818,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.033，更新阈值次数0，是否需要停止更新False
# 第304轮meta更新用时10.149秒,采样环境平均累计奖励:-274.086,meta模型的更新梯度范数为0.039,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.034，更新阈值次数0，是否需要停止更新False
# 第305轮meta更新用时10.507秒,采样环境平均累计奖励:-274.700,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.033，更新阈值次数0，是否需要停止更新False
# 第306轮meta更新用时10.347秒,采样环境平均累计奖励:-274.306,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.031，更新阈值次数0，是否需要停止更新False
# 第307轮meta更新用时10.290秒,采样环境平均累计奖励:-278.581,meta模型的更新梯度范数为0.039,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.032，更新阈值次数0，是否需要停止更新False
# 第308轮meta更新用时10.359秒,采样环境平均累计奖励:-273.094,meta模型的更新梯度范数为0.039,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.033，更新阈值次数0，是否需要停止更新False
# 第309轮meta更新用时10.832秒,采样环境平均累计奖励:-277.536,meta模型的更新梯度范数为0.039,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.034，更新阈值次数0，是否需要停止更新False
# 第310轮meta更新用时10.818秒,采样环境平均累计奖励:-275.310,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.038，0.001.0.032，更新阈值次数0，是否需要停止更新False
# 第311轮meta更新用时10.704秒,采样环境平均累计奖励:-272.306,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.038，0.001.0.032，更新阈值次数0，是否需要停止更新False
# 第312轮meta更新用时10.425秒,采样环境平均累计奖励:-276.954,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.038，0.001.0.032，更新阈值次数0，是否需要停止更新False
# 第313轮meta更新用时10.167秒,采样环境平均累计奖励:-276.938,meta模型的更新梯度范数为0.041,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.038，0.001.0.033，更新阈值次数0，是否需要停止更新False
# 第314轮meta更新用时10.416秒,采样环境平均累计奖励:-274.861,meta模型的更新梯度范数为0.041,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.038，0.001.0.034，更新阈值次数0，是否需要停止更新False
# 第315轮meta更新用时10.704秒,采样环境平均累计奖励:-273.926,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.038，0.001.0.033，更新阈值次数0，是否需要停止更新False
# 第316轮meta更新用时10.524秒,采样环境平均累计奖励:-276.757,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.038，0.001.0.033，更新阈值次数0，是否需要停止更新False
# 第317轮meta更新用时9.590秒,采样环境平均累计奖励:-272.990,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.038，0.001.0.034，更新阈值次数0，是否需要停止更新False
# 第318轮meta更新用时10.516秒,采样环境平均累计奖励:-273.782,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.038，0.001.0.035，更新阈值次数0，是否需要停止更新False
# 第319轮meta更新用时10.360秒,采样环境平均累计奖励:-274.311,meta模型的更新梯度范数为0.034,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.038，0.001.0.039，更新阈值次数0，是否需要停止更新False
# 第320轮meta更新用时10.559秒,采样环境平均累计奖励:-277.561,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.038，0.002.0.040，更新阈值次数0，是否需要停止更新False
# 第321轮meta更新用时10.441秒,采样环境平均累计奖励:-276.944,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.038，0.002.0.040，更新阈值次数0，是否需要停止更新False
# 第322轮meta更新用时10.507秒,采样环境平均累计奖励:-274.101,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.038，0.002.0.041，更新阈值次数0，是否需要停止更新False
# 第323轮meta更新用时14.610秒,采样环境平均累计奖励:-274.319,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.038，0.002.0.041，更新阈值次数0，是否需要停止更新False
# 第324轮meta更新用时13.456秒,采样环境平均累计奖励:-273.136,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.042，更新阈值次数0，是否需要停止更新False
# 第325轮meta更新用时10.221秒,采样环境平均累计奖励:-275.914,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.042，更新阈值次数0，是否需要停止更新False
# 第326轮meta更新用时10.630秒,采样环境平均累计奖励:-269.953,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.043，更新阈值次数0，是否需要停止更新False
# 第327轮meta更新用时14.335秒,采样环境平均累计奖励:-273.189,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.042，更新阈值次数0，是否需要停止更新False
# 第328轮meta更新用时15.253秒,采样环境平均累计奖励:-276.602,meta模型的更新梯度范数为0.040,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.044，更新阈值次数0，是否需要停止更新False
# 第329轮meta更新用时15.224秒,采样环境平均累计奖励:-278.370,meta模型的更新梯度范数为0.041,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.038，0.002.0.047，更新阈值次数0，是否需要停止更新False
# 第330轮meta更新用时15.253秒,采样环境平均累计奖励:-277.941,meta模型的更新梯度范数为0.040,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.038，0.002.0.048，更新阈值次数0，是否需要停止更新False
# 第331轮meta更新用时15.317秒,采样环境平均累计奖励:-274.136,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.038，0.002.0.047，更新阈值次数0，是否需要停止更新False
# 第332轮meta更新用时10.961秒,采样环境平均累计奖励:-271.752,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.038，0.002.0.049，更新阈值次数0，是否需要停止更新False
# 第333轮meta更新用时13.350秒,采样环境平均累计奖励:-276.639,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.050，更新阈值次数0，是否需要停止更新False
# 第334轮meta更新用时12.798秒,采样环境平均累计奖励:-274.918,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.050，更新阈值次数0，是否需要停止更新False
# 第335轮meta更新用时9.943秒,采样环境平均累计奖励:-278.849,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.050，更新阈值次数0，是否需要停止更新False
# 第336轮meta更新用时10.473秒,采样环境平均累计奖励:-274.833,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.050，更新阈值次数0，是否需要停止更新False
# 第337轮meta更新用时11.699秒,采样环境平均累计奖励:-273.680,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.050，更新阈值次数0，是否需要停止更新False
# 第338轮meta更新用时12.136秒,采样环境平均累计奖励:-274.682,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.049，更新阈值次数0，是否需要停止更新False
# 第339轮meta更新用时10.127秒,采样环境平均累计奖励:-275.917,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.049，更新阈值次数0，是否需要停止更新False
# 第340轮meta更新用时10.459秒,采样环境平均累计奖励:-276.711,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.048，更新阈值次数0，是否需要停止更新False
# 第341轮meta更新用时10.554秒,采样环境平均累计奖励:-274.817,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.049，更新阈值次数0，是否需要停止更新False
# 第342轮meta更新用时10.657秒,采样环境平均累计奖励:-271.404,meta模型的更新梯度范数为0.041,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.051，更新阈值次数0，是否需要停止更新False
# 第343轮meta更新用时10.336秒,采样环境平均累计奖励:-273.971,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.049，更新阈值次数0，是否需要停止更新False
# 第344轮meta更新用时10.400秒,采样环境平均累计奖励:-274.908,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.046，更新阈值次数0，是否需要停止更新False
# 第345轮meta更新用时10.491秒,采样环境平均累计奖励:-269.548,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.045，更新阈值次数0，是否需要停止更新False
# 第346轮meta更新用时10.513秒,采样环境平均累计奖励:-271.278,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.045，更新阈值次数0，是否需要停止更新False
# 第347轮meta更新用时10.566秒,采样环境平均累计奖励:-271.335,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.046，更新阈值次数0，是否需要停止更新False
# 第348轮meta更新用时10.803秒,采样环境平均累计奖励:-279.699,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.046，更新阈值次数0，是否需要停止更新False
# 第349轮meta更新用时10.479秒,采样环境平均累计奖励:-274.761,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.043，更新阈值次数0，是否需要停止更新False
# 第350轮meta更新用时10.466秒,采样环境平均累计奖励:-273.182,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.042，更新阈值次数0，是否需要停止更新False
# 第351轮meta更新用时10.431秒,采样环境平均累计奖励:-272.388,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.042，更新阈值次数0，是否需要停止更新False
# 第352轮meta更新用时10.392秒,采样环境平均累计奖励:-274.614,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.042，更新阈值次数0，是否需要停止更新False
# 第353轮meta更新用时10.379秒,采样环境平均累计奖励:-271.325,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.042，更新阈值次数0，是否需要停止更新False
# 第354轮meta更新用时10.321秒,采样环境平均累计奖励:-272.219,meta模型的更新梯度范数为0.038,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.042，更新阈值次数0，是否需要停止更新False
# 第355轮meta更新用时10.514秒,采样环境平均累计奖励:-273.455,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.042，更新阈值次数0，是否需要停止更新False
# 第356轮meta更新用时10.495秒,采样环境平均累计奖励:-272.059,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.041，更新阈值次数0，是否需要停止更新False
# 第357轮meta更新用时10.580秒,采样环境平均累计奖励:-273.316,meta模型的更新梯度范数为0.036,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.002.0.041，更新阈值次数0，是否需要停止更新False
# 第358轮meta更新用时10.438秒,采样环境平均累计奖励:-274.959,meta模型的更新梯度范数为0.037,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.039，更新阈值次数0，是否需要停止更新False
# 第359轮meta更新用时10.543秒,采样环境平均累计奖励:-271.657,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.034，更新阈值次数0，是否需要停止更新False
# 第360轮meta更新用时10.748秒,采样环境平均累计奖励:-272.856,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.031，更新阈值次数0，是否需要停止更新False
# 第361轮meta更新用时10.502秒,采样环境平均累计奖励:-272.569,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.032，更新阈值次数0，是否需要停止更新False
# 第362轮meta更新用时10.662秒,采样环境平均累计奖励:-272.493,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.032，更新阈值次数0，是否需要停止更新False
# 第363轮meta更新用时10.520秒,采样环境平均累计奖励:-273.982,meta模型的更新梯度范数为0.035,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.037，0.001.0.032，更新阈值次数0，是否需要停止更新False
# ...
# 第1875轮meta更新用时10.034秒,采样环境平均累计奖励:-218.438,meta模型的更新梯度范数为0.018,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.002.0.148，更新阈值次数0，是否需要停止更新False
# 第1876轮meta更新用时10.063秒,采样环境平均累计奖励:-219.275,meta模型的更新梯度范数为0.013,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.002.0.150，更新阈值次数0，是否需要停止更新False
# 第1877轮meta更新用时9.954秒,采样环境平均累计奖励:-217.388,meta模型的更新梯度范数为0.014,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.002.0.153，更新阈值次数0，是否需要停止更新False
# 第1878轮meta更新用时9.928秒,采样环境平均累计奖励:-220.097,meta模型的更新梯度范数为0.017,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.002.0.149，更新阈值次数0，是否需要停止更新False
# 第1879轮meta更新用时9.894秒,采样环境平均累计奖励:-218.411,meta模型的更新梯度范数为0.017,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.002.0.143，更新阈值次数0，是否需要停止更新False
# 第1880轮meta更新用时10.168秒,采样环境平均累计奖励:-217.477,meta模型的更新梯度范数为0.016,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.002.0.143，更新阈值次数0，是否需要停止更新False
# 第1881轮meta更新用时9.882秒,采样环境平均累计奖励:-218.761,meta模型的更新梯度范数为0.012,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.002.0.149，更新阈值次数0，是否需要停止更新False
# 第1882轮meta更新用时10.144秒,采样环境平均累计奖励:-216.001,meta模型的更新梯度范数为0.018,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.002.0.149，更新阈值次数0，是否需要停止更新False
# 第1883轮meta更新用时10.067秒,采样环境平均累计奖励:-218.947,meta模型的更新梯度范数为0.023,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.167，更新阈值次数0，是否需要停止更新False
# 第1884轮meta更新用时10.141秒,采样环境平均累计奖励:-221.692,meta模型的更新梯度范数为0.018,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.168，更新阈值次数0，是否需要停止更新False
# 第1885轮meta更新用时10.000秒,采样环境平均累计奖励:-217.760,meta模型的更新梯度范数为0.015,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.168，更新阈值次数0，是否需要停止更新False
# 第1886轮meta更新用时10.005秒,采样环境平均累计奖励:-215.961,meta模型的更新梯度范数为0.017,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.168，更新阈值次数0，是否需要停止更新False
# 第1887轮meta更新用时9.959秒,采样环境平均累计奖励:-213.553,meta模型的更新梯度范数为0.017,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.167，更新阈值次数0，是否需要停止更新False
# 第1888轮meta更新用时10.045秒,采样环境平均累计奖励:-223.459,meta模型的更新梯度范数为0.014,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.168，更新阈值次数0，是否需要停止更新False
# 第1889轮meta更新用时9.940秒,采样环境平均累计奖励:-217.836,meta模型的更新梯度范数为0.019,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.164，更新阈值次数0，是否需要停止更新False
# 第1890轮meta更新用时9.951秒,采样环境平均累计奖励:-220.419,meta模型的更新梯度范数为0.012,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.171，更新阈值次数0，是否需要停止更新False
# 第1891轮meta更新用时9.948秒,采样环境平均累计奖励:-218.495,meta模型的更新梯度范数为0.016,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.171，更新阈值次数0，是否需要停止更新False
# 第1892轮meta更新用时10.062秒,采样环境平均累计奖励:-220.402,meta模型的更新梯度范数为0.020,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.174，更新阈值次数0，是否需要停止更新False
# 第1893轮meta更新用时10.121秒,采样环境平均累计奖励:-218.265,meta模型的更新梯度范数为0.016,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.172，更新阈值次数0，是否需要停止更新False
# 第1894轮meta更新用时10.025秒,采样环境平均累计奖励:-221.287,meta模型的更新梯度范数为0.014,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.174，更新阈值次数0，是否需要停止更新False
# 第1895轮meta更新用时10.106秒,采样环境平均累计奖励:-219.414,meta模型的更新梯度范数为0.015,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.174，更新阈值次数0，是否需要停止更新False
# 第1896轮meta更新用时9.836秒,采样环境平均累计奖励:-220.192,meta模型的更新梯度范数为0.017,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.168，更新阈值次数0，是否需要停止更新False
# 第1897轮meta更新用时9.999秒,采样环境平均累计奖励:-220.782,meta模型的更新梯度范数为0.011,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.178，更新阈值次数0，是否需要停止更新False
# 第1898轮meta更新用时10.037秒,采样环境平均累计奖励:-216.868,meta模型的更新梯度范数为0.012,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.182，更新阈值次数0，是否需要停止更新False
# 第1899轮meta更新用时10.016秒,采样环境平均累计奖励:-220.849,meta模型的更新梯度范数为0.016,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.181，更新阈值次数0，是否需要停止更新False
# 第1900轮meta更新用时9.936秒,采样环境平均累计奖励:-220.973,meta模型的更新梯度范数为0.018,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.182，更新阈值次数0，是否需要停止更新False
# 第1901轮meta更新用时10.052秒,采样环境平均累计奖励:-215.410,meta模型的更新梯度范数为0.015,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.182，更新阈值次数0，是否需要停止更新False
# 第1902轮meta更新用时10.015秒,采样环境平均累计奖励:-219.742,meta模型的更新梯度范数为0.014,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.180，更新阈值次数0，是否需要停止更新False
# 第1903轮meta更新用时10.061秒,采样环境平均累计奖励:-218.380,meta模型的更新梯度范数为0.013,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.183，更新阈值次数0，是否需要停止更新False
# 第1904轮meta更新用时10.160秒,采样环境平均累计奖励:-221.196,meta模型的更新梯度范数为0.014,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.164，更新阈值次数0，是否需要停止更新False
# 第1905轮meta更新用时10.096秒,采样环境平均累计奖励:-216.507,meta模型的更新梯度范数为0.014,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.165，更新阈值次数0，是否需要停止更新False
# 第1906轮meta更新用时9.991秒,采样环境平均累计奖励:-215.634,meta模型的更新梯度范数为0.017,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.160，更新阈值次数0，是否需要停止更新False
# 第1907轮meta更新用时10.087秒,采样环境平均累计奖励:-218.618,meta模型的更新梯度范数为0.018,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.160，更新阈值次数0，是否需要停止更新False
# 第1908轮meta更新用时9.963秒,采样环境平均累计奖励:-218.106,meta模型的更新梯度范数为0.017,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.160，更新阈值次数0，是否需要停止更新False
# 第1909轮meta更新用时10.001秒,采样环境平均累计奖励:-216.320,meta模型的更新梯度范数为0.015,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.160，更新阈值次数0，是否需要停止更新False
# 第1910轮meta更新用时9.939秒,采样环境平均累计奖励:-220.475,meta模型的更新梯度范数为0.018,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.161，更新阈值次数0，是否需要停止更新False
# 第1911轮meta更新用时10.138秒,采样环境平均累计奖励:-220.126,meta模型的更新梯度范数为0.013,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.160，更新阈值次数0，是否需要停止更新False
# 第1912轮meta更新用时10.054秒,采样环境平均累计奖励:-219.591,meta模型的更新梯度范数为0.012,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.166，更新阈值次数0，是否需要停止更新False
# 第1913轮meta更新用时10.002秒,采样环境平均累计奖励:-217.519,meta模型的更新梯度范数为0.016,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.015，0.002.0.146，更新阈值次数0，是否需要停止更新False
# 第1914轮meta更新用时10.084秒,采样环境平均累计奖励:-217.249,meta模型的更新梯度范数为0.016,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.015，0.002.0.143，更新阈值次数0，是否需要停止更新False
# 第1915轮meta更新用时9.991秒,采样环境平均累计奖励:-218.540,meta模型的更新梯度范数为0.016,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.015，0.002.0.143，更新阈值次数0，是否需要停止更新False
# 第1916轮meta更新用时9.986秒,采样环境平均累计奖励:-218.235,meta模型的更新梯度范数为0.026,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.184，更新阈值次数0，是否需要停止更新False
# 第1917轮meta更新用时10.133秒,采样环境平均累计奖励:-217.550,meta模型的更新梯度范数为0.023,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.201，更新阈值次数0，是否需要停止更新False
# 第1918轮meta更新用时10.071秒,采样环境平均累计奖励:-217.553,meta模型的更新梯度范数为0.016,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.199，更新阈值次数0，是否需要停止更新False
# 第1919轮meta更新用时9.996秒,采样环境平均累计奖励:-217.271,meta模型的更新梯度范数为0.014,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.199，更新阈值次数0，是否需要停止更新False
# 第1920轮meta更新用时10.123秒,采样环境平均累计奖励:-224.167,meta模型的更新梯度范数为0.016,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.193，更新阈值次数0，是否需要停止更新False
# 第1921轮meta更新用时9.933秒,采样环境平均累计奖励:-225.783,meta模型的更新梯度范数为0.014,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.195，更新阈值次数0，是否需要停止更新False
# 第1922轮meta更新用时9.968秒,采样环境平均累计奖励:-217.076,meta模型的更新梯度范数为0.016,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.190，更新阈值次数0，是否需要停止更新False
# 第1923轮meta更新用时10.160秒,采样环境平均累计奖励:-218.293,meta模型的更新梯度范数为0.012,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.195，更新阈值次数0，是否需要停止更新False
# 第1924轮meta更新用时9.909秒,采样环境平均累计奖励:-217.801,meta模型的更新梯度范数为0.017,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.194，更新阈值次数0，是否需要停止更新False
# 第1925轮meta更新用时9.977秒,采样环境平均累计奖励:-221.388,meta模型的更新梯度范数为0.017,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.193，更新阈值次数0，是否需要停止更新False
# 第1926轮meta更新用时9.987秒,采样环境平均累计奖励:-218.350,meta模型的更新梯度范数为0.015,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.194，更新阈值次数0，是否需要停止更新False
# 第1927轮meta更新用时10.025秒,采样环境平均累计奖励:-215.665,meta模型的更新梯度范数为0.013,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.188，更新阈值次数0，是否需要停止更新False
# 第1928轮meta更新用时9.926秒,采样环境平均累计奖励:-214.849,meta模型的更新梯度范数为0.018,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.182，更新阈值次数0，是否需要停止更新False
# 第1929轮meta更新用时9.971秒,采样环境平均累计奖励:-215.788,meta模型的更新梯度范数为0.019,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.184，更新阈值次数0，是否需要停止更新False
# 第1930轮meta更新用时9.888秒,采样环境平均累计奖励:-217.022,meta模型的更新梯度范数为0.016,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.183，更新阈值次数0，是否需要停止更新False
# 第1931轮meta更新用时10.168秒,采样环境平均累计奖励:-218.285,meta模型的更新梯度范数为0.018,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.183，更新阈值次数0，是否需要停止更新False
# 第1932轮meta更新用时9.969秒,采样环境平均累计奖励:-221.691,meta模型的更新梯度范数为0.019,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.181，更新阈值次数0，是否需要停止更新False
# 第1933轮meta更新用时9.867秒,采样环境平均累计奖励:-221.439,meta模型的更新梯度范数为0.013,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.182，更新阈值次数0，是否需要停止更新False
# 第1934轮meta更新用时10.034秒,采样环境平均累计奖励:-219.615,meta模型的更新梯度范数为0.018,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.179，更新阈值次数0，是否需要停止更新False
# 第1935轮meta更新用时10.055秒,采样环境平均累计奖励:-220.489,meta模型的更新梯度范数为0.026,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.003.0.200，更新阈值次数0，是否需要停止更新False
# 第1936轮meta更新用时9.874秒,采样环境平均累计奖励:-220.887,meta模型的更新梯度范数为0.025,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.004.0.215，更新阈值次数0，是否需要停止更新False
# 第1937轮meta更新用时10.125秒,采样环境平均累计奖励:-215.927,meta模型的更新梯度范数为0.018,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.004.0.215，更新阈值次数0，是否需要停止更新False
# 第1938轮meta更新用时10.074秒,采样环境平均累计奖励:-216.724,meta模型的更新梯度范数为0.019,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.004.0.215，更新阈值次数0，是否需要停止更新False
# 第1939轮meta更新用时10.127秒,采样环境平均累计奖励:-216.826,meta模型的更新梯度范数为0.015,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.004.0.216，更新阈值次数0，是否需要停止更新False
# 第1940轮meta更新用时9.887秒,采样环境平均累计奖励:-216.670,meta模型的更新梯度范数为0.018,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.004.0.216，更新阈值次数0，是否需要停止更新False
# 第1941轮meta更新用时10.057秒,采样环境平均累计奖励:-219.394,meta模型的更新梯度范数为0.017,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.004.0.209，更新阈值次数0，是否需要停止更新False
# 第1942轮meta更新用时10.065秒,采样环境平均累计奖励:-212.542,meta模型的更新梯度范数为0.016,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.003.0.200，更新阈值次数0，是否需要停止更新False
# 第1943轮meta更新用时9.939秒,采样环境平均累计奖励:-216.610,meta模型的更新梯度范数为0.014,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.004.0.205，更新阈值次数0，是否需要停止更新False
# 第1944轮meta更新用时9.869秒,采样环境平均累计奖励:-218.232,meta模型的更新梯度范数为0.014,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.004.0.208，更新阈值次数0，是否需要停止更新False
# 第1945轮meta更新用时9.923秒,采样环境平均累计奖励:-220.133,meta模型的更新梯度范数为0.013,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.004.0.213，更新阈值次数0，是否需要停止更新False
# 第1946轮meta更新用时9.902秒,采样环境平均累计奖励:-219.954,meta模型的更新梯度范数为0.015,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.003.0.196，更新阈值次数0，是否需要停止更新False
# 第1947轮meta更新用时10.049秒,采样环境平均累计奖励:-216.450,meta模型的更新梯度范数为0.017,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.003.0.185，更新阈值次数0，是否需要停止更新False
# 第1948轮meta更新用时9.934秒,采样环境平均累计奖励:-216.324,meta模型的更新梯度范数为0.019,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.003.0.185，更新阈值次数0，是否需要停止更新False
# 第1949轮meta更新用时9.986秒,采样环境平均累计奖励:-218.626,meta模型的更新梯度范数为0.017,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.003.0.181，更新阈值次数0，是否需要停止更新False
# 第1950轮meta更新用时9.991秒,采样环境平均累计奖励:-218.137,meta模型的更新梯度范数为0.013,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.003.0.187，更新阈值次数0，是否需要停止更新False
# 第1951轮meta更新用时10.143秒,采样环境平均累计奖励:-220.366,meta模型的更新梯度范数为0.012,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.003.0.194，更新阈值次数0，是否需要停止更新False
# 第1952轮meta更新用时9.943秒,采样环境平均累计奖励:-217.991,meta模型的更新梯度范数为0.015,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.003.0.195，更新阈值次数0，是否需要停止更新False
# 第1953轮meta更新用时9.926秒,采样环境平均累计奖励:-214.286,meta模型的更新梯度范数为0.015,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.003.0.189，更新阈值次数0，是否需要停止更新False
# 第1954轮meta更新用时10.127秒,采样环境平均累计奖励:-218.161,meta模型的更新梯度范数为0.015,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.003.0.190，更新阈值次数0，是否需要停止更新False
# 第1955轮meta更新用时9.956秒,采样环境平均累计奖励:-219.351,meta模型的更新梯度范数为0.020,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.003.0.193，更新阈值次数0，是否需要停止更新False
# 第1956轮meta更新用时9.816秒,采样环境平均累计奖励:-217.737,meta模型的更新梯度范数为0.019,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.003.0.192，更新阈值次数0，是否需要停止更新False
# 第1957轮meta更新用时9.890秒,采样环境平均累计奖励:-215.993,meta模型的更新梯度范数为0.015,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.003.0.188，更新阈值次数0，是否需要停止更新False
# 第1958轮meta更新用时10.144秒,采样环境平均累计奖励:-217.523,meta模型的更新梯度范数为0.013,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.003.0.193，更新阈值次数0，是否需要停止更新False
# 第1959轮meta更新用时9.923秒,采样环境平均累计奖励:-220.695,meta模型的更新梯度范数为0.014,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.003.0.195，更新阈值次数0，是否需要停止更新False
# 第1960轮meta更新用时9.887秒,采样环境平均累计奖励:-215.110,meta模型的更新梯度范数为0.018,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.003.0.195，更新阈值次数0，是否需要停止更新False
# 第1961轮meta更新用时9.974秒,采样环境平均累计奖励:-219.304,meta模型的更新梯度范数为0.019,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.003.0.195，更新阈值次数0，是否需要停止更新False
# 第1962轮meta更新用时9.919秒,采样环境平均累计奖励:-219.375,meta模型的更新梯度范数为0.015,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.003.0.195，更新阈值次数0，是否需要停止更新False
# 第1963轮meta更新用时10.039秒,采样环境平均累计奖励:-218.506,meta模型的更新梯度范数为0.015,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.003.0.191，更新阈值次数0，是否需要停止更新False
# 第1964轮meta更新用时10.032秒,采样环境平均累计奖励:-216.635,meta模型的更新梯度范数为0.013,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.003.0.196，更新阈值次数0，是否需要停止更新False
# 第1965轮meta更新用时10.012秒,采样环境平均累计奖励:-219.666,meta模型的更新梯度范数为0.014,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.169，更新阈值次数0，是否需要停止更新False
# 第1966轮meta更新用时9.990秒,采样环境平均累计奖励:-215.217,meta模型的更新梯度范数为0.019,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.002.0.141，更新阈值次数0，是否需要停止更新False
# 第1967轮meta更新用时9.814秒,采样环境平均累计奖励:-220.386,meta模型的更新梯度范数为0.022,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.156，更新阈值次数0，是否需要停止更新False
# 第1968轮meta更新用时9.801秒,采样环境平均累计奖励:-217.196,meta模型的更新梯度范数为0.021,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.162，更新阈值次数0，是否需要停止更新False
# 第1969轮meta更新用时9.898秒,采样环境平均累计奖励:-212.903,meta模型的更新梯度范数为0.016,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.161，更新阈值次数0，是否需要停止更新False
# 第1970轮meta更新用时9.940秒,采样环境平均累计奖励:-215.160,meta模型的更新梯度范数为0.013,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.164，更新阈值次数0，是否需要停止更新False
# 第1971轮meta更新用时10.081秒,采样环境平均累计奖励:-216.957,meta模型的更新梯度范数为0.013,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.168，更新阈值次数0，是否需要停止更新False
# 第1972轮meta更新用时9.877秒,采样环境平均累计奖励:-219.497,meta模型的更新梯度范数为0.013,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.173，更新阈值次数0，是否需要停止更新False
# 第1973轮meta更新用时10.069秒,采样环境平均累计奖励:-217.652,meta模型的更新梯度范数为0.017,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.171，更新阈值次数0，是否需要停止更新False
# 第1974轮meta更新用时9.969秒,采样环境平均累计奖励:-219.544,meta模型的更新梯度范数为0.014,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.170，更新阈值次数0，是否需要停止更新False
# 第1975轮meta更新用时10.020秒,采样环境平均累计奖励:-215.186,meta模型的更新梯度范数为0.016,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.167，更新阈值次数0，是否需要停止更新False
# 第1976轮meta更新用时10.104秒,采样环境平均累计奖励:-220.808,meta模型的更新梯度范数为0.011,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.176，更新阈值次数0，是否需要停止更新False
# 第1977轮meta更新用时9.956秒,采样环境平均累计奖励:-218.096,meta模型的更新梯度范数为0.012,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.183，更新阈值次数0，是否需要停止更新False
# 第1978轮meta更新用时10.050秒,采样环境平均累计奖励:-218.028,meta模型的更新梯度范数为0.016,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.003.0.181，更新阈值次数0，是否需要停止更新False
# 第1979轮meta更新用时10.026秒,采样环境平均累计奖励:-218.412,meta模型的更新梯度范数为0.011,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.015，0.003.0.191，更新阈值次数0，是否需要停止更新False
# 第1980轮meta更新用时10.017秒,采样环境平均累计奖励:-217.290,meta模型的更新梯度范数为0.027,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.004.0.222，更新阈值次数0，是否需要停止更新False
# 第1981轮meta更新用时10.111秒,采样环境平均累计奖励:-216.659,meta模型的更新梯度范数为0.021,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.004.0.220，更新阈值次数0，是否需要停止更新False
# 第1982轮meta更新用时10.022秒,采样环境平均累计奖励:-217.723,meta模型的更新梯度范数为0.015,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.004.0.221，更新阈值次数0，是否需要停止更新False
# 第1983轮meta更新用时10.027秒,采样环境平均累计奖励:-215.166,meta模型的更新梯度范数为0.015,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.004.0.221，更新阈值次数0，是否需要停止更新False
# 第1984轮meta更新用时10.122秒,采样环境平均累计奖励:-219.533,meta模型的更新梯度范数为0.020,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.004.0.222，更新阈值次数0，是否需要停止更新False
# 第1985轮meta更新用时10.007秒,采样环境平均累计奖励:-214.926,meta模型的更新梯度范数为0.028,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.004.0.249，更新阈值次数0，是否需要停止更新False
# 第1986轮meta更新用时9.949秒,采样环境平均累计奖励:-220.692,meta模型的更新梯度范数为0.024,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.004.0.257，更新阈值次数0，是否需要停止更新False
# 第1987轮meta更新用时9.914秒,采样环境平均累计奖励:-217.423,meta模型的更新梯度范数为0.019,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.004.0.256，更新阈值次数0，是否需要停止更新False
# 第1988轮meta更新用时10.079秒,采样环境平均累计奖励:-213.372,meta模型的更新梯度范数为0.015,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.004.0.254，更新阈值次数0，是否需要停止更新False
# 第1989轮meta更新用时9.843秒,采样环境平均累计奖励:-215.996,meta模型的更新梯度范数为0.015,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.004.0.252，更新阈值次数0，是否需要停止更新False
# 第1990轮meta更新用时10.002秒,采样环境平均累计奖励:-217.932,meta模型的更新梯度范数为0.017,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.004.0.252，更新阈值次数0，是否需要停止更新False
# 第1991轮meta更新用时9.993秒,采样环境平均累计奖励:-218.800,meta模型的更新梯度范数为0.022,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.004.0.256，更新阈值次数0，是否需要停止更新False
# 第1992轮meta更新用时10.065秒,采样环境平均累计奖励:-215.340,meta模型的更新梯度范数为0.020,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.004.0.255，更新阈值次数0，是否需要停止更新False
# 第1993轮meta更新用时10.177秒,采样环境平均累计奖励:-211.574,meta模型的更新梯度范数为0.018,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.004.0.253，更新阈值次数0，是否需要停止更新False
# 第1994轮meta更新用时9.977秒,采样环境平均累计奖励:-217.859,meta模型的更新梯度范数为0.017,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.004.0.248，更新阈值次数0，是否需要停止更新False
# 第1995轮meta更新用时10.069秒,采样环境平均累计奖励:-218.723,meta模型的更新梯度范数为0.013,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.004.0.252，更新阈值次数0，是否需要停止更新False
# 第1996轮meta更新用时10.159秒,采样环境平均累计奖励:-216.378,meta模型的更新梯度范数为0.011,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.004.0.263，更新阈值次数0，是否需要停止更新False
# 第1997轮meta更新用时10.101秒,采样环境平均累计奖励:-223.539,meta模型的更新梯度范数为0.011,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.017，0.004.0.268，更新阈值次数0，是否需要停止更新False
# 第1998轮meta更新用时10.116秒,采样环境平均累计奖励:-215.919,meta模型的更新梯度范数为0.013,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.004.0.270，更新阈值次数0，是否需要停止更新False
# 第1999轮meta更新用时10.033秒,采样环境平均累计奖励:-215.526,meta模型的更新梯度范数为0.018,历史更新梯度大小的累计均值,标准差和CV范数分别为:0.016，0.004.0.269，更新阈值次数0，是否需要停止更新False

# %%
fig = plt.figure(figsize = (12,6))
x = range(len(sampleupdata_avgreturns))
ep_rewards_arr = sampleupdata_avgreturns
plt.plot(x,ep_rewards_arr) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 fig = plt.figure(figsize = (12,6))
#       2 x = range(len(sampleupdata_avgreturns))
#       3 ep_rewards_arr = sampleupdata_avgreturns
#
# NameError: name 'plt' is not defined

# %%
torch.save(meta_drl.bss_agent.state_dict(),f=r'D:\sjtu\EV_DRL\BSS_OPERATION_Emergence\data\savemodel\policymodel\PPO_SCALE10_singleact_metamodelREPTILE20250414.pth')

# %%
ep_rewards_pd = pd.DataFrame(bss_ep_updaterewards)
pdpath = r'D:\sjtu\EV_DRL\BSS_OPERATION_Emergence\data\实验数据\训练数据\PPO_SCALE10_singleact_metamodeltype4_trainreturn0707.csv'
ep_rewards_pd.to_csv(pdpath,header=['return'],index=None)

# %%
def test(step,gamemanager:BE.GameManager,rewardF,opt, model=None,showmessage = True,savepic = False):
    gamemanager.Initial( reinitial= True)
    print('仿真开始')
    #gamemanager.Message()
    request_reserve_list = []
    request_engs= []
    request_Gengs = []
    request_PVengs= []
    cplan_list = []
    
    wait_nums = []
    ava_bs = []
    gprices = []
    
    rew_list = []
    rcosts = []
    rqueues = []
    rwasts = []



    cplan_probs = []



    readybT1s =[]
    readybT2s = []
    cplans = []

    rewards = 0
    gamestep = 0
    for i in range(step):
        gamestep += 1
        csta,ccost = StateTensor(gamemanager)

        #BSS决策过程
        reserve_act,prob1 = opt.charger_num / 2,  None
        if  model != None:
            reserve_act,prob1 =  model.select_action(csta)
            #energy_req = energy_act.cpu().item()*er_factor if type_e else int(energy_act.cpu().item())
            reserve_act = prob1.argmax().cpu().item()
            #pv_rat = pv_act.cpu().item()
            
        # print(csta)
        # print(prob1)
        # print(prob2)
        # print(reserve_act,cplan_act)


        
        gamemanager.Update(reserve_act,0,emergencefactor,showmessage)
        request_engs.append(gamemanager.stage_used_energy)
        
        nsta,ncost = StateTensor(gamemanager)

        print(ncost)

        rew,rcost,rqueue,rwast =rewardF(ncost,opt)

        wait_num = gamemanager.bss_queuelength
        wait_nums.append(wait_num)

        gprices.append(gamemanager.ps.price)
        

        avab = gamemanager.ava_bnum#可获得的电池数
        ava_bs.append(avab)

        request_reserve_list.append(reserve_act)

        rew_list.append(rew.cpu().item())
        rcosts.append(rcost.cpu().item())
        rqueues.append(rqueue.cpu().item())
        rwasts.append(rwast.cpu().item())



        rewards += rew

        readybT1s.append(gamemanager.bss.BT1_readdy_num)
        readybT2s.append(gamemanager.bss.BT2_readdy_num)


        if showmessage:
            gamemanager.Message()

    #print(request_energy_list)

    def plotax(axsi,x,y,names):
        lines = []
        for i in y:
            li, = axsi.plot(x, i)
            lines.append(li)
        axsi.legend(lines,names)

    fig,axs = plt.subplots(6,1,figsize=(12,3*6))

    x = range(gamestep)
    plotax(axs[0],x,[request_reserve_list],['request_reserve'])
    # axs[0].plot(x,request_energy_list)
    # axs[0].plot(x,pvenergies)
    plotax(axs[1],x,[wait_nums,ava_bs],['wait_nums','ava_bs'])
    # axs[1].plot(x,wait_nums)
    # axs[1].plot(x,ava_bs)

    plotax(axs[2],x,[gprices],['gprices'])
    # axs[2].plot(x,gprices)
    # axs[2].plot(x,pvprices)

    plotax(axs[3],x,[request_engs],['eng','Geng','pveng'])
    #axs[3].plot(x, [min(i,200) for i in pveng])
    

    #axs[4].plot(x, maxpvs)#pv_probs)#pv_list)

    plotax(axs[4],x,[readybT1s,readybT2s],['readybT1s','readybT2s'])
    # axs[5].plot(x, readybT1s)#pv_probs)#pv_list)
    # axs[5].plot(x, readybT2s)#pv_probs)#pv_list)
    # axs[5].plot(x, cplans)
    
    #plotax(axs[6],x,[rew_list],['rew_list'])
    plotax(axs[5],x,[rcosts,rqueues,rwasts],['rcost','rqueue','rwast'])
    axs[5].plot(x,rew_list)
        
    if savepic:
        path = os.path.join(opt.dirpath,'a2csimulation'+opt.t1+'.png')
        plt.savefig(path)

    plt.show()
    return rew_list

# %%
emergencefactor = 0.5

# %%
rews =test(400,gamemanager=GM,rewardF=rewardtype1_detail,opt= OPTIONS,
                     model=meta_drl,showmessage=True,savepic=False)
sum(rews)

# %%
torch.save(bss_drl.bss_agent.state_dict(),f=r'D:\sjtu\EV_DRL\BSS_OPERATION_Emergence\data\savemodel\policymodel\PPO_emgfactor050v1_SCALE10_singleact.pth')
