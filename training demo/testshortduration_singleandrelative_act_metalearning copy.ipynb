# %%
import numpy as np
import pandas as pd
import math
import time
import random
import matplotlib.pyplot as plt

from collections import namedtuple,deque

import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

import torch
import BSS_ENV_shortduration as BE

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
#单一行为以及可拓展的策略
class options:
    def __init__(self,num):
        self.charger_num = num
        self.ev_num = num
        self.bssbatterynum = 2 * num
        self.maxpve = 0
        self.transit_step = 2
        self.ev_average_worksoc = 0.1

        self.inp_dim = 4
        self.memory_count = 1000
        self.GAMMA = 0.99
        self.beta = 0.2
        self.MEMORY_NUM = 2
        self.game_step = 400
        
        self.NUM_EPISODES = 8000

        self.update_gamecount = 4#每进行多少轮游戏更新网络

        self.learning_ratio = 0.001
        self.if_clamp = True
        self.modelpath = r'D:\sjtu\EV_DRL\BSS_OPERATION_Emergence\data\savemodel\policymodel'
        self.dirpath=r'D:\sjtu\EV_DRL\BSS_OPERATION\data'
        self.gru_state = r'D:\sjtu\EV_DRL\BSS_OPERATION\data\savemodel\gru.pth'
        #self.price_data = r'D:\sjtu\xdd\paper\data\price\time_series_60min_singleindex.csv'
        self.price_data = r'D:\sjtu\EV_DRL\BSS_OPERATION_Emergence\data\pricedata\time_series_60min_singleindex.csv'
        #模型的初始化格式
        self.pit = {'avg':0,'ban':1,'all':2}#等概率考虑pv，不使用pv，最大化使用pv
        

OPTIONS = options(10)

# %%
price_data_path = OPTIONS.price_data
pd_frame = pd.read_csv(price_data_path)

DK_1_price = pd_frame['DK_1_price_day_ahead']
DK_1_price.fillna(0,inplace=True)

DK_1_price_nparray =np.array([max(0,i) for i in DK_1_price.tolist()])

fig, ax = plt.subplots(figsize = (12,4))
ax.plot(np.arange(1000), DK_1_price_nparray[0:1000], linewidth=1)
plt.show()

# %%
GM = BE.GameManager(OPTIONS,ps_eprice_ds=DK_1_price_nparray)
def StateTensor(gm:BE.GameManager):
    bt1_num,bt2_num,b_num,energy_cost,carbon,bssevqueue_length,wasted_reserve,ctime,is_done = gm.EnvState()
    ctime = ctime/10 #0-96的数值太大，这里减少一下数值大小
    statetensor = torch.tensor([bt1_num,bt2_num,bssevqueue_length,ctime],dtype= torch.float32).to(device)
    costtensor = torch.tensor([energy_cost,bssevqueue_length,wasted_reserve],dtype= torch.float32).to(device)
    return statetensor.unsqueeze(0),costtensor.unsqueeze(0) #1*4 ,1*3

cfactor_t1 = 0.05
qfactor_t1 = 1
wfactor_t1 = 0.5
def rewardtype1(cost_T,opts:options):#正常运营状态下的奖励信息，车辆排队数量+超出的预约数+充电费用

    charging_cost = cfactor_t1* cost_T[:,0]/120#120为电池容量，这里电费最好按照SOC的比例计算，因此除掉了电池容量

    emergenceqfactor = 1 if opts.ev_num/cost_T[:,1]>1.5 else 3
    evqueuetimein_bss = qfactor_t1*(cost_T[:,1])*emergenceqfactor

    wast_request = wfactor_t1*cost_T[:,2]
       
    #print(evqueuetimein_bss, wast_request,charging_cost)
    bss_reward = -(evqueuetimein_bss+ wast_request+charging_cost)/opts.ev_num
    #print(torch.ones(1),bss_reward)
    bss_reward = bss_reward.unsqueeze(0) #奖励值输入形状为1*
    return bss_reward


def rewardtype1_detail(cost_T,opts:options):#正常运营状态下的奖励信息，车辆排队数量+超出的预约数+充电费用

    charging_cost = cfactor_t1* cost_T[:,0]/120#120为电池容量，这里电费最好按照SOC的比例计算，因此除掉了电池容量

    emergenceqfactor = 1 if opts.ev_num/cost_T[:,1]>1.5 else 3
    evqueuetimein_bss = qfactor_t1*(cost_T[:,1])*emergenceqfactor

    wast_request = wfactor_t1*cost_T[:,2]
       
    #print(evqueuetimein_bss, wast_request,charging_cost)
    bss_reward = -(evqueuetimein_bss+ wast_request+charging_cost)/opts.ev_num
    #print(torch.ones(1),bss_reward)
    bss_reward = bss_reward.unsqueeze(0) #奖励值输入形状为1*
    return bss_reward,-charging_cost,-evqueuetimein_bss,-wast_request

# %%
workingtimes= range(400)
timereturn = 48
worktimefactor =   [1 * math.cos(i*math.pi/timereturn) + 1  + random.random()*0.1 for i in workingtimes] 
fig = plt.figure(figsize = (12,4))
plt.plot(workingtimes,worktimefactor)
plt.show()

# %%
evqueuelengths = []
for i in range(200):#OPTIONS.game_step):
    reserve = int(OPTIONS.charger_num/2)
    chargeplan = 1
    GM.Update(reserve,chargeplan) 
    cstate,ccost = StateTensor(GM)
    evqueuelengths.append(ccost[:,1].cpu().item())
    #print(i,cstate,ccost)
    r = rewardtype1(ccost,OPTIONS)
    #print(r)
    #GM.Message()

fig = plt.figure(figsize = (12,8))
plt.plot(range(200),evqueuelengths)
plt.show()

# %%
class PPONetwork(torch.nn.Module):
    def __init__(self,inpdim,reserve_dim=5,init_cpratio_id = 1):
        super(PPONetwork,self).__init__()
        self.inputlayer = torch.nn.Linear(inpdim,64).to(device)
        self.linear1 = torch.nn.Linear(64,128).to(device)

        #self.norm = torch.nn.BatchNorm1d(4).to(device)
        #self.relu = torch.nn.LeakyReLU().to(device)

        self.linear2 = torch.nn.Linear(128,64).to(device)

        self.out1 = torch.nn.Linear(64,reserve_dim).to(device)
        #self.out2 = torch.nn.Linear(64,chargeplan_dim).to(device)
        self.out3 = torch.nn.Linear(64,1).to(device)
        self.softmax = torch.nn.Softmax(dim=-1)
        
        
    def forward(self,inp):
        x = inp.to(device)
        inp1 = self.inputlayer(x)
        tanh1 = torch.nn.Tanh()(inp1)
        line1 = self.linear1(tanh1)
        line2 = self.linear2(line1)#(reshape_128)
        tanh2 = torch.nn.Tanh()(line2)
        #print(tanh2)
        out_1 = self.out1(tanh2)
        
        out_3 = self.out3(tanh2)
        res1 = self.softmax(out_1)

        #print(out_3)
        res3 = out_3
        return res1,res3 #bs*reservedim+1,bs*2,bs*1

# %%
BSSTransition = namedtuple('BSSTransition',('state_pool','value_pool','policy_ratio_pool','clipres_pool','log_prob_pool','reward_pool','done_pool'))#收集连续动作
class BSSMemory(object):#策略梯度采样，每次保存一次策略的数据，采样一次策略的数据、
    def __init__(self,capacity):
        self.memory = deque([],maxlen = capacity)
    def push(self,*args):
        self.memory.append(BSSTransition(*args))
    def sample(self):
        batch = list(self.memory)
        return zip(*batch)
    def __len__(self):
        return len(self.memory)
    def clear(self):
        self.memory.clear()


class BSS_DRL(object):#er_dim=5*5+1默认单位电量20，5个100kwh充电桩对应的维度选择为25+1
    def __init__(self,opt):#ifstep 通过冻结网络的部分层操作实现分段训练):
        self.options =  opt
        self.lr = opt.learning_ratio
        
        self.bss_agent = PPONetwork(opt.inp_dim,reserve_dim=opt.charger_num +1,init_cpratio_id= 0).to(device)
        
        self.bss_agent_target = PPONetwork(opt.inp_dim,reserve_dim=opt.charger_num +1,init_cpratio_id=0).to(device)
        self.bss_agent_target.load_state_dict(self.bss_agent.state_dict())  
        self.bss_agent_target.eval()

        self.bss_agent_optimizer = torch.optim.Adam(self.bss_agent.parameters(),lr = self.lr)
        #self.bss_a2c_target_optimizer = torch.optim.Adam(self.evrp_critic.parameters(),lr = self.lr)
        self.if_clamp = opt.if_clamp
        self.bssmemory_num = opt.MEMORY_NUM
        self.bssmemorys = [] 
        for i in range(4):
            self.bssmemorys.append(BSSMemory(2500))
        
    #根据当前状态 选择车辆充电行为， 首先根据车辆策略模型给出期望充电行为， 再依据充电商策略模型给出确定动作   
    def select_action(self,bssstate,if_train=False):#state_s的格式为bs*ev_num*(state_n)
        prob1,state_value = self.bss_agent(bssstate)
        prob1_target,state_value_target = self.bss_agent_target(bssstate)
        
        reserve_dist = torch.distributions.categorical.Categorical(prob1)
   
        reserve_dist_target = torch.distributions.categorical.Categorical(prob1_target)
        
        
        reserve_act = reserve_dist.sample()

        reserve_act_target = reserve_dist_target.sample()
        
        
        if if_train:
            return reserve_act_target,reserve_dist_target,reserve_dist,state_value_target
                
        return reserve_act,prob1
    
    
    def cliprange(self,prob,prob_target,segma=0.2):
        policy_ratio = prob/prob_target
        max_clip = 1+segma
        min_clip = 1-segma
        clipres = torch.clamp(policy_ratio,min = min_clip,max = max_clip)
        return clipres
    
    def compute_returns(self,next_value, rewards, masks, gamma=0.99):
        value = next_value.detach()#return 不计入梯度计算，这里使用detach() 1*1
        rewards = (rewards - rewards.mean())/rewards.std()
       
        returns = torch.zeros_like(rewards)    #使用numpy操作可能更快？但是需要注意tensor和numpy数据的转换
        for act_i in reversed(range(len(rewards))):
            #print(rewards[act_i],gamma , value , masks[act_i])
            value = rewards[act_i] + gamma * value * (1-masks[act_i])
            returns[act_i] = value
        return returns #pool_size*1*1

    def update_bss(self,nstate_s_list,entropys):
        #print(0.001*entropy)
        mmnum = self.bssmemory_num
        losses = []
        for i in range(self.bssmemory_num):
            state_pool,value_pool,policy_ratio_pool,clipres_pool,log_prob_pool,reward_pool,done_pool= self.bssmemorys[i].sample()

            state_poolstack =torch.stack(state_pool).to(device)
            old_value_poolstack = torch.stack(value_pool).to(device)#pool_length*bs*valuedim
            policy_ratio_poolstack = torch.stack(policy_ratio_pool).to(device) #pool_length*bs*valuedim
            clipres_poolstack = torch.stack(clipres_pool).to(device) #pool_length*bs*valuedim
            #print(value_poolstack)
            log_prob_poolstack = torch.stack(log_prob_pool).to(device) #pool_length*bs*valuedim
            #print(log_prob_poolstack)
            reward_poolstack = torch.stack(reward_pool).to(device)#pool_length*bs*valuedim
            #print(reward_poolstack)
            done_poolstack = torch.stack(done_pool).to(device)#pool_length*bs*valuedim
            #print(done_poolstack)
       
            #1 1 1
            _,next_value = self.bss_agent_target(nstate_s_list[i])#bs*1
        
            #记录累加奖励（该采样与DQN不同，采样中每次仅记录一个策略动作序列）
            returns = self.compute_returns(next_value.squeeze(0),reward_poolstack,done_poolstack,gamma = self.options.GAMMA)
            advantages = returns - old_value_poolstack

            _,current_value = self.bss_agent(state_poolstack)
            #print(current_value.shape,returns.shape)
            current_advantage = returns - current_value
            
            #print(advantages.shape)
            # print('clip'+str(clipres_poolstack))
            # print('policy' +str( policy_ratio_poolstack))
            clip_advantages = advantages * clipres_poolstack
            policy_ratio_advantages = advantages * policy_ratio_poolstack
            # print(clip_advantages)
            # print(policy_ratio_advantages)
            stack_advantages = torch.cat((clip_advantages,policy_ratio_advantages),dim=-1)
            ppo_advantages = stack_advantages.min(dim=-1)[0].unsqueeze(-1)
            
            #print( ppo_advantages)
            #print(advantages)
            #print(log_prob_poolstack)
            #print(advantages)
            
            actor_loss = -ppo_advantages.mean() # (-log_prob_poolstack * advantages).mean()
            critic_loss = 0.5 * current_advantage.pow(2).mean()
            # print('bss动作损失：{}'.format(actor_loss))
            # print('bss策略损失：{}'.format(critic_loss))
            total_loss = 10* actor_loss + critic_loss - 0.0001*entropys[i]
            losses.append(total_loss)
        
        mmloss = losses[0]
        for i in range( mmnum-1):
            mmloss = mmloss + losses[i+1]
        mmloss = mmloss/mmnum
        #print('动作熵值：{}'.format(log_prob_poolstack))            
        self.bss_agent_optimizer.zero_grad()      
        mmloss.backward()
        if self.if_clamp:
            for param in self.bss_agent.parameters():           
                #print(param.grad)
                if param.grad is not None:
                    param.grad.data.clamp(-20,20)
        #for param in self.evrp_critic.parameters():           
           # print(param.grad)
        self.bss_agent_optimizer.step()    


    def update_bss_for_grad(self,nstate_s_list,entropys):
        #print(0.001*entropy)
        mmnum = self.bssmemory_num
        losses = []
        for i in range(self.bssmemory_num):
            state_pool,value_pool,policy_ratio_pool,clipres_pool,log_prob_pool,reward_pool,done_pool= self.bssmemorys[i].sample()

            state_poolstack =torch.stack(state_pool).to(device)
            old_value_poolstack = torch.stack(value_pool).to(device)#pool_length*bs*valuedim
            policy_ratio_poolstack = torch.stack(policy_ratio_pool).to(device) #pool_length*bs*valuedim
            clipres_poolstack = torch.stack(clipres_pool).to(device) #pool_length*bs*valuedim
            #print(value_poolstack)
            log_prob_poolstack = torch.stack(log_prob_pool).to(device) #pool_length*bs*valuedim
            #print(log_prob_poolstack)
            reward_poolstack = torch.stack(reward_pool).to(device)#pool_length*bs*valuedim
            #print(reward_poolstack)
            done_poolstack = torch.stack(done_pool).to(device)#pool_length*bs*valuedim
            #print(done_poolstack)
       
            #1 1 1
            _,next_value = self.bss_agent_target(nstate_s_list[i])#bs*1
        
            #记录累加奖励（该采样与DQN不同，采样中每次仅记录一个策略动作序列）
            returns = self.compute_returns(next_value.squeeze(0),reward_poolstack,done_poolstack,gamma = self.options.GAMMA)
            advantages = returns - old_value_poolstack

            _,current_value = self.bss_agent(state_poolstack)
            #print(current_value.shape,returns.shape)
            current_advantage = returns - current_value
            
            #print(advantages.shape)
            # print('clip'+str(clipres_poolstack))
            # print('policy' +str( policy_ratio_poolstack))
            clip_advantages = advantages * clipres_poolstack
            policy_ratio_advantages = advantages * policy_ratio_poolstack
            # print(clip_advantages)
            # print(policy_ratio_advantages)
            stack_advantages = torch.cat((clip_advantages,policy_ratio_advantages),dim=-1)
            ppo_advantages = stack_advantages.min(dim=-1)[0].unsqueeze(-1)
            
            #print( ppo_advantages)
            #print(advantages)
            #print(log_prob_poolstack)
            #print(advantages)
            
            actor_loss = -ppo_advantages.mean() # (-log_prob_poolstack * advantages).mean()
            critic_loss = 0.5 * current_advantage.pow(2).mean()
            # print('bss动作损失：{}'.format(actor_loss))
            # print('bss策略损失：{}'.format(critic_loss))
            total_loss = 10* actor_loss + critic_loss - 0.0001*entropys[i]
            losses.append(total_loss)
        
        mmloss = losses[0]
        for i in range( mmnum-1):
            mmloss = mmloss + losses[i+1]
        mmloss = mmloss/mmnum
        grads = torch.autograd.grad(mmloss,self.bss_agent.parameters(),create_graph= True)
        return grads
            #print('动作熵值：{}'.format(log_prob_poolstack))            
        # self.bss_agent_optimizer.zero_grad()      
        # mmloss.backward()
        # if self.if_clamp:
        #     for param in self.bss_agent.parameters():           
        #         #print(param.grad)
        #         if param.grad is not None:
        #             param.grad.data.clamp(-20,20)
        # #for param in self.evrp_critic.parameters():           
        #    # print(param.grad)
        # self.bss_agent_optimizer.step()    
        
        
    def savemodel(self,dicpath,addname):
        torch.save(self.bss_agent.state_dict(),os.path.join(dicpath,addname+'.pth'))

# %%
reward = rewardtype1

bss_ep_valrewards = []
bss_ep_valrewards_avgemgf = []
bss_ep_updaterewards = []
meta_drl =  BSS_DRL(OPTIONS)
# emergencefactors = [0.25,0.5,0.75,1,1.25,1.5]
# subtaskid = [0,1,2,3,4,5]
#sample_subtasknum = 6
emergencefactors = [0.5,1,1.5,2]
subtaskid = [0,1,2,3]
sample_subtasknum = 4

# %%
#bss_drl.bss_agent.load_state_dict(torch.load(os.path.join(OPTIONS.modelpath,'PPO_emgfactor1_SCALE10.pth')))

# %%
max_sampleupdate_reward = -99999

for ep in range(3000):# (OPTIONS.NUM_EPISODES+1000): # 
    start = time.time()#记录每个episode训练时间       
       
    samplesampletask = random.sample(emergencefactors,k = sample_subtasknum)
    samplesampletask#
    
    subtask_emgfactor = samplesampletask
    sampleupdate_reward = 0
    for i in range(sample_subtasknum):
        current_subtaskmode = BSS_DRL(OPTIONS)
        current_subtaskmode.bss_agent.load_state_dict(meta_drl.bss_agent.state_dict())
        current_subtaskmode.bss_agent_target.load_state_dict(meta_drl.bss_agent_target.state_dict())
        current_task_emgfactor = subtask_emgfactor[i]
        bss_ep_entropys = [] 
        bss_last_state_s=[]

    #submodel 先更新一次
        for k1 in range(OPTIONS.MEMORY_NUM):#每次采样四局仿真#为4个记忆槽分别采样4次行为       
            GM.Initial(reinitial= True)
            cstate,ccoststate = StateTensor(GM)
            ep_bss_entropy = 0
            
            for j1 in range(OPTIONS.game_step):            
                
                #1*1,1*1*15 ,1*1*1 
                reserve_act_target,reserve_dist_target,reserve_dist,state_value_target = current_subtaskmode.select_action(cstate,True)
                
                state_value = state_value_target #1*1
                #由于模型中考虑了batch因素，所以state_value结构为bs*ev_num,单个取值时bs为1，由于采样后，使用了stack堆积，需要把把第一维度去掉
                    
                #计算采样动作的熵值1*1

                log_prob = reserve_dist.log_prob(reserve_act_target) #+ pvratio_dist.log_prob(pv_act_target) #,1
                log_prob = log_prob.unsqueeze(0) #1*1
                bss_entropy = reserve_dist.entropy().mean()# + pvratio_dist.entropy().mean()#策略动作概率熵值

                rsr_act_prob_target = reserve_dist_target.probs[:,reserve_act_target]
                
                # print(energy_dist_target.probs[:,energy_act_target] )
                # print(energy_dist.probs[:,energy_act_target])
                prob_target = (rsr_act_prob_target).detach() # rsr_act_prob_target.detach()# 
                
                rsr_act_prob = reserve_dist.probs[:,reserve_act_target]
                
                prob = rsr_act_prob
                
                policy_ratio = prob/prob_target
                
                clipres = current_subtaskmode.cliprange(prob,prob_target)
                
                #根据动作更新环境
                charge_request = reserve_act_target.cpu().item()
                
                #print(energy_request,pv_ratio)
                
                GM.Update(charge_request,0,current_task_emgfactor)
                
                #记录下一状态和动作奖励与是否完成目标
                nstate,ncoststate = StateTensor(GM)
                
                #shape 1
                r = reward(ncoststate,OPTIONS) #1,1
                r = r.detach()

                isdone = torch.ones_like(r) * 0
                
                #记录了结束状态
                
                
                #依次记录本次策略动作数据，并放入对应局数的记忆中
                current_subtaskmode.bssmemorys[k1].push(cstate,state_value,policy_ratio,clipres,log_prob,r,isdone)
                        
            
                #将下一阶段状态标记为当前状态，并记录累积策略熵
                cstate = nstate 
                ccoststate = ncoststate
                
                ep_bss_entropy += bss_entropy 
               
        
            
            #达到目标或进入摆烂状态都强行结束环境，避免模型收敛到摆烂状态
                # if isdone :#当完成营收目标时，环境工作完毕，结束环境   
                #     break; 
                    
            bss_last_state_s.append(cstate)
            bss_ep_entropys.append(ep_bss_entropy)  
        
        current_subtaskmode.update_bss(bss_last_state_s,bss_ep_entropys)#策略更新时，使用动作序列更新
        
        for mm in current_subtaskmode.bssmemorys:
            mm.clear()#更新后需要清楚本次的动作序列

        bss_ep_upreward = 0
        bss_ep_entropys = [] 
        bss_last_state_s=[]
    #submodel 更新后再次记录，但不继续更新，仅记录loss
        for k2 in range(OPTIONS.MEMORY_NUM):#每次采样四局仿真#为4个记忆槽分别采样4次行为       
            GM.Initial(reinitial= True)
            cstate,ccoststate = StateTensor(GM)
            ep_bss_entropy = 0
            
            for j2 in range(OPTIONS.game_step):            
                
                #1*1,1*1*15 ,1*1*1 
                reserve_act_target,reserve_dist_target,reserve_dist,state_value_target = current_subtaskmode.select_action(cstate,True)
                
                state_value = state_value_target #1*1
                #由于模型中考虑了batch因素，所以state_value结构为bs*ev_num,单个取值时bs为1，由于采样后，使用了stack堆积，需要把把第一维度去掉
                    
                #计算采样动作的熵值1*1

                log_prob = reserve_dist.log_prob(reserve_act_target) #+ pvratio_dist.log_prob(pv_act_target) #,1
                log_prob = log_prob.unsqueeze(0) #1*1
                bss_entropy = reserve_dist.entropy().mean()# + pvratio_dist.entropy().mean()#策略动作概率熵值

                rsr_act_prob_target = reserve_dist_target.probs[:,reserve_act_target]
                
                # print(energy_dist_target.probs[:,energy_act_target] )
                # print(energy_dist.probs[:,energy_act_target])
                prob_target = (rsr_act_prob_target).detach() # rsr_act_prob_target.detach()# 
                
                rsr_act_prob = reserve_dist.probs[:,reserve_act_target]
                
                prob = rsr_act_prob
                
                policy_ratio = prob/prob_target
                
                clipres = current_subtaskmode.cliprange(prob,prob_target)
                
                #根据动作更新环境
                charge_request = reserve_act_target.cpu().item()
                
                #print(energy_request,pv_ratio)
                
                GM.Update(charge_request,0,current_task_emgfactor)
                
                #记录下一状态和动作奖励与是否完成目标
                nstate,ncoststate = StateTensor(GM)
                
                #shape 1
                r = reward(ncoststate,OPTIONS) #1,1
                r = r.detach()
                bss_ep_upreward += float(r.cpu())
                isdone = torch.ones_like(r) * 0
                
                #记录了结束状态
                
                
                #依次记录本次策略动作数据，并放入对应局数的记忆中
                current_subtaskmode.bssmemorys[k2].push(cstate,state_value,policy_ratio,clipres,log_prob,r,isdone)
                        
            
                #将下一阶段状态标记为当前状态，并记录累积策略熵
                cstate = nstate 
                ccoststate = ncoststate
                
                ep_bss_entropy += bss_entropy 
               
        
            
            #达到目标或进入摆烂状态都强行结束环境，避免模型收敛到摆烂状态
                # if isdone :#当完成营收目标时，环境工作完毕，结束环境   
                #     break; 
                    
            bss_last_state_s.append(cstate)
            bss_ep_entropys.append(ep_bss_entropy)  
        
        bss_ep_upreward = bss_ep_upreward/OPTIONS.MEMORY_NUM
        sampleupdate_reward += bss_ep_upreward

        current_subgrads = current_subtaskmode.update_bss_for_grad(bss_last_state_s,bss_ep_entropys)#策略更新时，使用动作序列更新
        # print('------------------------------------------------------------------')       
        # print('------------------------------------------------------------------')      
        # print('------------------------------------------------------------------')     
        # for param in meta_drl.bss_agent.parameters():           
        #     print(param.grad)
        # print('------------------------------------------------------------------')       
        # print('------------------------------------------------------------------')      
        # print('------------------------------------------------------------------')           
        # for g in current_subgrads:           
        #     print(g)
        with torch.no_grad():
            for p,subg in zip(meta_drl.bss_agent.parameters(),current_subgrads):
                if p.grad is None:
                    p.grad = subg.clone()
                else:
                    p.grad += subg
        current_subtaskmode.bss_agent_optimizer.zero_grad()
        # print('------------------------------------------------------------------')         
        # for param in meta_drl.bss_agent.parameters():           
        #     print(param.grad)
        
        for mm in current_subtaskmode.bssmemorys:
            mm.clear()#更新后需要清楚本次的动作序列


    meta_drl.bss_agent_optimizer.step()
    meta_drl.bss_agent_optimizer.zero_grad()
    
    sampleupdate_reward = sampleupdate_reward/sample_subtasknum
    bss_ep_updaterewards.append(sampleupdate_reward)

    # randomemgfactor = random.sample(emergencefactors,k=1)[0]
    # bss_ep_valreward = 0
    # #这里对meta_model 进行一次测试
    # for j in range(OPTIONS.game_step):            
                
    #     #1*1,1*1*15 ,1*1*1 
    #     reserve_act,actprob = meta_drl.select_action(cstate)
          
    #     #根据动作更新环境
    #     charge_request = reserve_act.cpu().item()
        
    #     #print(energy_request,pv_ratio)
        
    #     GM.Update(charge_request,0,randomemgfactor)
        
    #     #记录下一状态和动作奖励与是否完成目标
    #     nstate,ncoststate = StateTensor(GM)
        
    #     #shape 1
    #     r = reward(ncoststate,OPTIONS) #1,1
    #     r = r.detach()

    #     bss_ep_valreward += float(r)     
   
    # bss_ep_valrewards.append(bss_ep_valreward)    
    # bss_ep_valrewards_avgemgf.append(bss_ep_valreward/randomemgfactor)            
    if ep%2==0:
        print('更新old网络')
        meta_drl.bss_agent_target.load_state_dict(meta_drl.bss_agent.state_dict())
    #print(sampleupdate_reward)
    print ('第{}轮训练用时{:.3f}秒，平均累积奖励为{:.3f}'.format(
        ep + 1, time.time()-start,sampleupdate_reward))  
    if sampleupdate_reward > max_sampleupdate_reward:
        max_sampleupdate_reward = sampleupdate_reward
        print('最大期望奖励更新为{:.3f}，保存一次模型'.format(max_sampleupdate_reward))
        torch.save(meta_drl.bss_agent.state_dict(),f=r'D:\sjtu\EV_DRL\BSS_OPERATION_Emergence\data\savemodel\policymodel\PPO_SCALE10_singleact_metamodel_besttrain.pth')
    # print ('第{}轮训练用时{:.3f}秒，平均累积奖励为{:.3f}'.format(
    #     ep + 1, time.time()-start,bss_ep_valreward/randomemgfactor))



    #valicationmessage(24)
#('current_state','goal_action','ev_prob','reward','next_state'))
# Out:
# 更新old网络
# 第1轮训练用时14.584秒，平均累积奖励为-307.408
# 最大期望奖励更新为-307.408，保存一次模型
# 第2轮训练用时13.216秒，平均累积奖励为-299.613
# 最大期望奖励更新为-299.613，保存一次模型
# 更新old网络
# 第3轮训练用时12.883秒，平均累积奖励为-293.701
# 最大期望奖励更新为-293.701，保存一次模型
# 第4轮训练用时12.904秒，平均累积奖励为-288.722
# 最大期望奖励更新为-288.722，保存一次模型
# 更新old网络
# 第5轮训练用时13.007秒，平均累积奖励为-293.188
# 第6轮训练用时12.912秒，平均累积奖励为-286.079
# 最大期望奖励更新为-286.079，保存一次模型
# 更新old网络
# 第7轮训练用时12.959秒，平均累积奖励为-284.225
# 最大期望奖励更新为-284.225，保存一次模型
# 第8轮训练用时12.858秒，平均累积奖励为-292.883
# 更新old网络
# 第9轮训练用时12.928秒，平均累积奖励为-287.008
# 第10轮训练用时12.884秒，平均累积奖励为-284.960
# 更新old网络
# 第11轮训练用时12.863秒，平均累积奖励为-290.601
# 第12轮训练用时12.915秒，平均累积奖励为-281.483
# 最大期望奖励更新为-281.483，保存一次模型
# 更新old网络
# 第13轮训练用时12.850秒，平均累积奖励为-287.612
# 第14轮训练用时12.817秒，平均累积奖励为-287.266
# 更新old网络
# 第15轮训练用时12.913秒，平均累积奖励为-278.859
# 最大期望奖励更新为-278.859，保存一次模型
# 第16轮训练用时12.842秒，平均累积奖励为-277.346
# 最大期望奖励更新为-277.346，保存一次模型
# 更新old网络
# 第17轮训练用时12.919秒，平均累积奖励为-281.387
# 第18轮训练用时12.878秒，平均累积奖励为-277.926
# 更新old网络
# 第19轮训练用时12.774秒，平均累积奖励为-278.511
# 第20轮训练用时12.739秒，平均累积奖励为-281.383
# 更新old网络
# 第21轮训练用时12.888秒，平均累积奖励为-275.753
# 最大期望奖励更新为-275.753，保存一次模型
# 第22轮训练用时12.926秒，平均累积奖励为-269.495
# 最大期望奖励更新为-269.495，保存一次模型
# 更新old网络
# 第23轮训练用时12.870秒，平均累积奖励为-279.346
# 第24轮训练用时12.749秒，平均累积奖励为-280.523
# 更新old网络
# 第25轮训练用时12.769秒，平均累积奖励为-273.522
# 第26轮训练用时12.835秒，平均累积奖励为-272.945
# 更新old网络
# 第27轮训练用时12.859秒，平均累积奖励为-275.649
# 第28轮训练用时12.698秒，平均累积奖励为-272.175
# 更新old网络
# 第29轮训练用时12.750秒，平均累积奖励为-280.290
# 第30轮训练用时12.865秒，平均累积奖励为-273.326
# 更新old网络
# 第31轮训练用时12.801秒，平均累积奖励为-278.920
# 第32轮训练用时12.795秒，平均累积奖励为-281.406
# 更新old网络
# 第33轮训练用时12.764秒，平均累积奖励为-276.679
# 第34轮训练用时12.853秒，平均累积奖励为-282.476
# 更新old网络
# 第35轮训练用时12.843秒，平均累积奖励为-271.572
# 第36轮训练用时12.883秒，平均累积奖励为-275.769
# 更新old网络
# 第37轮训练用时12.805秒，平均累积奖励为-276.707
# 第38轮训练用时12.872秒，平均累积奖励为-274.621
# 更新old网络
# 第39轮训练用时12.737秒，平均累积奖励为-277.502
# 第40轮训练用时12.848秒，平均累积奖励为-271.958
# 更新old网络
# 第41轮训练用时12.871秒，平均累积奖励为-271.003
# 第42轮训练用时12.877秒，平均累积奖励为-274.910
# 更新old网络
# 第43轮训练用时12.940秒，平均累积奖励为-277.876
# 第44轮训练用时12.904秒，平均累积奖励为-282.656
# 更新old网络
# 第45轮训练用时12.896秒，平均累积奖励为-279.099
# 第46轮训练用时12.882秒，平均累积奖励为-277.765
# 更新old网络
# 第47轮训练用时12.919秒，平均累积奖励为-280.782
# 第48轮训练用时12.970秒，平均累积奖励为-275.534
# 更新old网络
# 第49轮训练用时12.968秒，平均累积奖励为-271.721
# 第50轮训练用时12.917秒，平均累积奖励为-275.450
# 更新old网络
# 第51轮训练用时12.928秒，平均累积奖励为-277.798
# 第52轮训练用时12.975秒，平均累积奖励为-274.095
# 更新old网络
# 第53轮训练用时12.880秒，平均累积奖励为-269.142
# 最大期望奖励更新为-269.142，保存一次模型
# 第54轮训练用时12.945秒，平均累积奖励为-265.041
# 最大期望奖励更新为-265.041，保存一次模型
# 更新old网络
# 第55轮训练用时12.894秒，平均累积奖励为-267.054
# 第56轮训练用时12.895秒，平均累积奖励为-270.771
# 更新old网络
# 第57轮训练用时12.945秒，平均累积奖励为-269.447
# 第58轮训练用时12.895秒，平均累积奖励为-273.096
# 更新old网络
# 第59轮训练用时12.887秒，平均累积奖励为-267.493
# 第60轮训练用时12.871秒，平均累积奖励为-267.218
# 更新old网络
# 第61轮训练用时12.907秒，平均累积奖励为-269.334
# 第62轮训练用时12.829秒，平均累积奖励为-267.706
# 更新old网络
# 第63轮训练用时12.897秒，平均累积奖励为-258.328
# 最大期望奖励更新为-258.328，保存一次模型
# 第64轮训练用时12.799秒，平均累积奖励为-258.411
# 更新old网络
# 第65轮训练用时12.931秒，平均累积奖励为-258.263
# 最大期望奖励更新为-258.263，保存一次模型
# 第66轮训练用时12.834秒，平均累积奖励为-258.590
# 更新old网络
# 第67轮训练用时12.831秒，平均累积奖励为-265.337
# 第68轮训练用时12.831秒，平均累积奖励为-259.893
# 更新old网络
# 第69轮训练用时13.017秒，平均累积奖励为-257.789
# 最大期望奖励更新为-257.789，保存一次模型
# 第70轮训练用时12.899秒，平均累积奖励为-261.165
# 更新old网络
# 第71轮训练用时12.804秒，平均累积奖励为-260.032
# 第72轮训练用时12.751秒，平均累积奖励为-258.511
# 更新old网络
# 第73轮训练用时12.946秒，平均累积奖励为-257.391
# 最大期望奖励更新为-257.391，保存一次模型
# 第74轮训练用时12.814秒，平均累积奖励为-262.718
# 更新old网络
# 第75轮训练用时12.932秒，平均累积奖励为-259.415
# 第76轮训练用时12.725秒，平均累积奖励为-255.333
# 最大期望奖励更新为-255.333，保存一次模型
# 更新old网络
# 第77轮训练用时12.957秒，平均累积奖励为-255.112
# 最大期望奖励更新为-255.112，保存一次模型
# 第78轮训练用时12.847秒，平均累积奖励为-259.018
# 更新old网络
# 第79轮训练用时12.792秒，平均累积奖励为-251.195
# 最大期望奖励更新为-251.195，保存一次模型
# 第80轮训练用时12.920秒，平均累积奖励为-255.298
# 更新old网络
# 第81轮训练用时12.914秒，平均累积奖励为-259.828
# 第82轮训练用时12.870秒，平均累积奖励为-246.039
# 最大期望奖励更新为-246.039，保存一次模型
# 更新old网络
# 第83轮训练用时12.824秒，平均累积奖励为-262.227
# 第84轮训练用时13.101秒，平均累积奖励为-251.735
# 更新old网络
# 第85轮训练用时13.069秒，平均累积奖励为-251.188
# 第86轮训练用时12.928秒，平均累积奖励为-248.290
# 更新old网络
# 第87轮训练用时12.840秒，平均累积奖励为-256.309
# 第88轮训练用时12.928秒，平均累积奖励为-245.817
# 最大期望奖励更新为-245.817，保存一次模型
# 更新old网络
# 第89轮训练用时12.902秒，平均累积奖励为-258.040
# 第90轮训练用时12.934秒，平均累积奖励为-246.675
# 更新old网络
# 第91轮训练用时13.011秒，平均累积奖励为-260.030
# 第92轮训练用时12.853秒，平均累积奖励为-247.012
# 更新old网络
# 第93轮训练用时12.961秒，平均累积奖励为-252.003
# 第94轮训练用时13.010秒，平均累积奖励为-244.793
# 最大期望奖励更新为-244.793，保存一次模型
# 更新old网络
# 第95轮训练用时12.894秒，平均累积奖励为-254.096
# 第96轮训练用时12.752秒，平均累积奖励为-246.328
# 更新old网络
# 第97轮训练用时12.809秒，平均累积奖励为-249.051
# 第98轮训练用时12.933秒，平均累积奖励为-242.301
# 最大期望奖励更新为-242.301，保存一次模型
# 更新old网络
# 第99轮训练用时12.924秒，平均累积奖励为-244.498
# 第100轮训练用时12.865秒，平均累积奖励为-238.512
# 最大期望奖励更新为-238.512，保存一次模型
# 更新old网络
# 第101轮训练用时12.857秒，平均累积奖励为-242.725
# 第102轮训练用时12.932秒，平均累积奖励为-238.921
# 更新old网络
# 第103轮训练用时12.876秒，平均累积奖励为-246.514
# 第104轮训练用时13.019秒，平均累积奖励为-243.095
# 更新old网络
# 第105轮训练用时12.772秒，平均累积奖励为-246.451
# 第106轮训练用时12.868秒，平均累积奖励为-238.960
# 更新old网络
# 第107轮训练用时12.876秒，平均累积奖励为-241.485
# 第108轮训练用时12.837秒，平均累积奖励为-232.044
# 最大期望奖励更新为-232.044，保存一次模型
# 更新old网络
# 第109轮训练用时12.963秒，平均累积奖励为-237.165
# 第110轮训练用时13.056秒，平均累积奖励为-234.773
# 更新old网络
# 第111轮训练用时13.008秒，平均累积奖励为-238.432
# 第112轮训练用时12.979秒，平均累积奖励为-239.078
# 更新old网络
# 第113轮训练用时13.020秒，平均累积奖励为-235.259
# 第114轮训练用时12.943秒，平均累积奖励为-233.422
# 更新old网络
# 第115轮训练用时12.917秒，平均累积奖励为-233.997
# 第116轮训练用时13.061秒，平均累积奖励为-239.237
# 更新old网络
# 第117轮训练用时12.891秒，平均累积奖励为-237.163
# 第118轮训练用时13.063秒，平均累积奖励为-234.891
# 更新old网络
# 第119轮训练用时12.891秒，平均累积奖励为-230.340
# 最大期望奖励更新为-230.340，保存一次模型
# 第120轮训练用时12.999秒，平均累积奖励为-234.544
# 更新old网络
# 第121轮训练用时12.919秒，平均累积奖励为-237.185
# 第122轮训练用时12.908秒，平均累积奖励为-236.133
# 更新old网络
# 第123轮训练用时12.902秒，平均累积奖励为-235.747
# 第124轮训练用时12.927秒，平均累积奖励为-234.682
# 更新old网络
# 第125轮训练用时12.797秒，平均累积奖励为-233.807
# 第126轮训练用时12.989秒，平均累积奖励为-231.084
# 更新old网络
# 第127轮训练用时12.889秒，平均累积奖励为-232.423
# 第128轮训练用时12.871秒，平均累积奖励为-234.010
# 更新old网络
# 第129轮训练用时12.986秒，平均累积奖励为-236.321
# 第130轮训练用时12.967秒，平均累积奖励为-232.791
# 更新old网络
# 第131轮训练用时12.866秒，平均累积奖励为-232.615
# 第132轮训练用时12.968秒，平均累积奖励为-230.267
# 最大期望奖励更新为-230.267，保存一次模型
# 更新old网络
# 第133轮训练用时12.905秒，平均累积奖励为-234.725
# 第134轮训练用时12.915秒，平均累积奖励为-234.757
# 更新old网络
# 第135轮训练用时12.968秒，平均累积奖励为-234.674
# 第136轮训练用时12.850秒，平均累积奖励为-232.239
# 更新old网络
# 第137轮训练用时12.976秒，平均累积奖励为-228.120
# 最大期望奖励更新为-228.120，保存一次模型
# 第138轮训练用时12.839秒，平均累积奖励为-232.946
# 更新old网络
# 第139轮训练用时12.995秒，平均累积奖励为-230.167
# 第140轮训练用时12.916秒，平均累积奖励为-235.149
# 更新old网络
# 第141轮训练用时12.815秒，平均累积奖励为-234.018
# 第142轮训练用时12.833秒，平均累积奖励为-232.573
# 更新old网络
# 第143轮训练用时12.939秒，平均累积奖励为-233.421
# 第144轮训练用时12.975秒，平均累积奖励为-232.284
# 更新old网络
# 第145轮训练用时12.972秒，平均累积奖励为-229.279
# 第146轮训练用时12.989秒，平均累积奖励为-231.078
# 更新old网络
# 第147轮训练用时12.928秒，平均累积奖励为-228.359
# 第148轮训练用时12.923秒，平均累积奖励为-229.536
# 更新old网络
# 第149轮训练用时12.838秒，平均累积奖励为-234.189
# 第150轮训练用时12.770秒，平均累积奖励为-230.523
# 更新old网络
# 第151轮训练用时12.968秒，平均累积奖励为-237.199
# 第152轮训练用时12.886秒，平均累积奖励为-232.075
# 更新old网络
# 第153轮训练用时13.123秒，平均累积奖励为-233.105
# 第154轮训练用时12.895秒，平均累积奖励为-236.565
# 更新old网络
# 第155轮训练用时12.983秒，平均累积奖励为-232.138
# 第156轮训练用时12.974秒，平均累积奖励为-231.528
# 更新old网络
# 第157轮训练用时12.907秒，平均累积奖励为-230.466
# 第158轮训练用时12.898秒，平均累积奖励为-232.693
# 更新old网络
# 第159轮训练用时12.809秒，平均累积奖励为-231.613
# 第160轮训练用时12.907秒，平均累积奖励为-231.347
# 更新old网络
# 第161轮训练用时12.900秒，平均累积奖励为-232.561
# 第162轮训练用时12.827秒，平均累积奖励为-229.714
# 更新old网络
# 第163轮训练用时13.039秒，平均累积奖励为-231.430
# 第164轮训练用时12.842秒，平均累积奖励为-226.382
# 最大期望奖励更新为-226.382，保存一次模型
# 更新old网络
# 第165轮训练用时12.910秒，平均累积奖励为-230.199
# 第166轮训练用时12.906秒，平均累积奖励为-228.222
# 更新old网络
# 第167轮训练用时12.958秒，平均累积奖励为-230.963
# 第168轮训练用时12.934秒，平均累积奖励为-230.410
# 更新old网络
# 第169轮训练用时12.880秒，平均累积奖励为-232.650
# 第170轮训练用时12.967秒，平均累积奖励为-233.665
# 更新old网络
# 第171轮训练用时12.898秒，平均累积奖励为-234.960
# 第172轮训练用时12.911秒，平均累积奖励为-231.575
# 更新old网络
# 第173轮训练用时12.940秒，平均累积奖励为-234.229
# 第174轮训练用时12.995秒，平均累积奖励为-234.188
# 更新old网络
# 第175轮训练用时12.999秒，平均累积奖励为-238.756
# 第176轮训练用时12.835秒，平均累积奖励为-233.092
# 更新old网络
# 第177轮训练用时12.811秒，平均累积奖励为-230.566
# 第178轮训练用时12.860秒，平均累积奖励为-231.719
# 更新old网络
# 第179轮训练用时12.925秒，平均累积奖励为-230.341
# 第180轮训练用时12.835秒，平均累积奖励为-227.574
# 更新old网络
# 第181轮训练用时12.798秒，平均累积奖励为-237.784
# 第182轮训练用时12.921秒，平均累积奖励为-230.894
# 更新old网络
# 第183轮训练用时12.942秒，平均累积奖励为-234.652
# 第184轮训练用时12.982秒，平均累积奖励为-233.233
# 更新old网络
# 第185轮训练用时12.875秒，平均累积奖励为-237.511
# 第186轮训练用时12.841秒，平均累积奖励为-233.953
# 更新old网络
# 第187轮训练用时12.964秒，平均累积奖励为-236.399
# 第188轮训练用时12.928秒，平均累积奖励为-230.830
# 更新old网络
# 第189轮训练用时12.918秒，平均累积奖励为-231.630
# 第190轮训练用时12.929秒，平均累积奖励为-231.235
# 更新old网络
# 第191轮训练用时12.944秒，平均累积奖励为-237.694
# 第192轮训练用时12.872秒，平均累积奖励为-237.223
# 更新old网络
# 第193轮训练用时12.839秒，平均累积奖励为-240.193
# 第194轮训练用时12.869秒，平均累积奖励为-237.914
# 更新old网络
# 第195轮训练用时12.922秒，平均累积奖励为-236.323
# 第196轮训练用时12.859秒，平均累积奖励为-233.118
# 更新old网络
# 第197轮训练用时13.055秒，平均累积奖励为-234.161
# 第198轮训练用时12.897秒，平均累积奖励为-233.421
# 更新old网络
# 第199轮训练用时12.836秒，平均累积奖励为-228.142
# 第200轮训练用时12.984秒，平均累积奖励为-235.365
# 更新old网络
# 第201轮训练用时12.925秒，平均累积奖励为-234.259
# 第202轮训练用时12.781秒，平均累积奖励为-240.491
# 更新old网络
# 第203轮训练用时12.838秒，平均累积奖励为-232.745
# 第204轮训练用时12.931秒，平均累积奖励为-234.191
# 更新old网络
# 第205轮训练用时12.819秒，平均累积奖励为-227.946
# 第206轮训练用时12.849秒，平均累积奖励为-232.475
# 更新old网络
# 第207轮训练用时12.860秒，平均累积奖励为-229.540
# 第208轮训练用时12.891秒，平均累积奖励为-232.696
# 更新old网络
# 第209轮训练用时12.834秒，平均累积奖励为-237.609
# 第210轮训练用时12.812秒，平均累积奖励为-231.179
# 更新old网络
# 第211轮训练用时13.061秒，平均累积奖励为-230.023
# 第212轮训练用时12.851秒，平均累积奖励为-232.071
# 更新old网络
# 第213轮训练用时12.831秒，平均累积奖励为-227.803
# 第214轮训练用时12.879秒，平均累积奖励为-232.835
# 更新old网络
# 第215轮训练用时12.792秒，平均累积奖励为-232.910
# 第216轮训练用时12.900秒，平均累积奖励为-234.355
# 更新old网络
# 第217轮训练用时12.879秒，平均累积奖励为-231.160
# 第218轮训练用时12.864秒，平均累积奖励为-231.501
# 更新old网络
# 第219轮训练用时12.868秒，平均累积奖励为-235.008
# 第220轮训练用时13.021秒，平均累积奖励为-234.479
# 更新old网络
# 第221轮训练用时12.934秒，平均累积奖励为-229.069
# 第222轮训练用时12.860秒，平均累积奖励为-224.101
# 最大期望奖励更新为-224.101，保存一次模型
# 更新old网络
# 第223轮训练用时13.028秒，平均累积奖励为-231.677
# 第224轮训练用时12.982秒，平均累积奖励为-236.519
# 更新old网络
# 第225轮训练用时13.042秒，平均累积奖励为-234.383
# 第226轮训练用时12.923秒，平均累积奖励为-228.512
# 更新old网络
# 第227轮训练用时12.976秒，平均累积奖励为-228.482
# 第228轮训练用时12.934秒，平均累积奖励为-228.081
# 更新old网络
# 第229轮训练用时12.842秒，平均累积奖励为-228.215
# 第230轮训练用时12.838秒，平均累积奖励为-235.036
# 更新old网络
# 第231轮训练用时12.895秒，平均累积奖励为-230.836
# 第232轮训练用时13.127秒，平均累积奖励为-230.278
# 更新old网络
# 第233轮训练用时13.159秒，平均累积奖励为-232.767
# 第234轮训练用时12.821秒，平均累积奖励为-230.242
# 更新old网络
# 第235轮训练用时13.086秒，平均累积奖励为-223.394
# 最大期望奖励更新为-223.394，保存一次模型
# 第236轮训练用时13.222秒，平均累积奖励为-225.776
# 更新old网络
# 第237轮训练用时12.966秒，平均累积奖励为-235.169
# 第238轮训练用时12.820秒，平均累积奖励为-230.614
# 更新old网络
# 第239轮训练用时12.869秒，平均累积奖励为-233.605
# 第240轮训练用时12.944秒，平均累积奖励为-228.430
# 更新old网络
# 第241轮训练用时12.970秒，平均累积奖励为-228.440
# 第242轮训练用时12.858秒，平均累积奖励为-229.638
# 更新old网络
# 第243轮训练用时12.969秒，平均累积奖励为-231.779
# 第244轮训练用时12.959秒，平均累积奖励为-235.766
# 更新old网络
# 第245轮训练用时12.891秒，平均累积奖励为-229.572
# 第246轮训练用时12.915秒，平均累积奖励为-227.665
# 更新old网络
# 第247轮训练用时13.054秒，平均累积奖励为-227.347
# 第248轮训练用时12.943秒，平均累积奖励为-233.609
# 更新old网络
# 第249轮训练用时13.008秒，平均累积奖励为-235.636
# 第250轮训练用时13.072秒，平均累积奖励为-222.367
# 最大期望奖励更新为-222.367，保存一次模型
# 更新old网络
# 第251轮训练用时12.927秒，平均累积奖励为-227.688
# 第252轮训练用时12.884秒，平均累积奖励为-229.309
# 更新old网络
# 第253轮训练用时12.922秒，平均累积奖励为-234.328
# 第254轮训练用时12.994秒，平均累积奖励为-229.182
# 更新old网络
# 第255轮训练用时13.045秒，平均累积奖励为-227.712
# 第256轮训练用时13.157秒，平均累积奖励为-226.951
# 更新old网络
# 第257轮训练用时13.031秒，平均累积奖励为-231.994
# 第258轮训练用时13.018秒，平均累积奖励为-234.913
# 更新old网络
# 第259轮训练用时12.861秒，平均累积奖励为-230.182
# 第260轮训练用时12.818秒，平均累积奖励为-232.164
# 更新old网络
# 第261轮训练用时12.796秒，平均累积奖励为-231.496
# 第262轮训练用时13.095秒，平均累积奖励为-233.744
# 更新old网络
# 第263轮训练用时12.872秒，平均累积奖励为-235.476
# 第264轮训练用时12.690秒，平均累积奖励为-230.259
# 更新old网络
# 第265轮训练用时12.861秒，平均累积奖励为-239.633
# 第266轮训练用时12.974秒，平均累积奖励为-231.755
# 更新old网络
# 第267轮训练用时12.886秒，平均累积奖励为-233.883
# 第268轮训练用时12.818秒，平均累积奖励为-234.773
# 更新old网络
# 第269轮训练用时12.887秒，平均累积奖励为-234.139
# 第270轮训练用时12.909秒，平均累积奖励为-235.007
# 更新old网络
# 第271轮训练用时12.970秒，平均累积奖励为-238.515
# 第272轮训练用时12.910秒，平均累积奖励为-238.765
# 更新old网络
# 第273轮训练用时13.047秒，平均累积奖励为-236.507
# 第274轮训练用时12.879秒，平均累积奖励为-237.048
# 更新old网络
# 第275轮训练用时12.993秒，平均累积奖励为-232.812
# 第276轮训练用时12.951秒，平均累积奖励为-240.710
# 更新old网络
# 第277轮训练用时13.011秒，平均累积奖励为-238.781
# 第278轮训练用时13.022秒，平均累积奖励为-237.473
# 更新old网络
# 第279轮训练用时12.936秒，平均累积奖励为-239.476
# 第280轮训练用时12.895秒，平均累积奖励为-239.560
# 更新old网络
# 第281轮训练用时12.914秒，平均累积奖励为-242.676
# 第282轮训练用时12.799秒，平均累积奖励为-242.823
# 更新old网络
# 第283轮训练用时12.759秒，平均累积奖励为-243.549
# 第284轮训练用时12.959秒，平均累积奖励为-243.925
# 更新old网络
# 第285轮训练用时12.839秒，平均累积奖励为-245.575
# 第286轮训练用时12.917秒，平均累积奖励为-243.714
# 更新old网络
# 第287轮训练用时12.896秒，平均累积奖励为-241.028
# 第288轮训练用时13.043秒，平均累积奖励为-244.468
# 更新old网络
# 第289轮训练用时12.818秒，平均累积奖励为-246.314
# 第290轮训练用时12.813秒，平均累积奖励为-242.382
# 更新old网络
# 第291轮训练用时12.882秒，平均累积奖励为-247.620
# 第292轮训练用时12.824秒，平均累积奖励为-247.225
# 更新old网络
# 第293轮训练用时12.870秒，平均累积奖励为-242.866
# 第294轮训练用时12.852秒，平均累积奖励为-252.164
# 更新old网络
# 第295轮训练用时12.848秒，平均累积奖励为-247.017
# 第296轮训练用时12.917秒，平均累积奖励为-247.318
# 更新old网络
# 第297轮训练用时12.862秒，平均累积奖励为-250.176
# 第298轮训练用时12.779秒，平均累积奖励为-248.579
# 更新old网络
# 第299轮训练用时12.912秒，平均累积奖励为-249.555
# 第300轮训练用时12.939秒，平均累积奖励为-246.838
# 更新old网络
# 第301轮训练用时12.899秒，平均累积奖励为-255.847
# 第302轮训练用时13.023秒，平均累积奖励为-262.848
# 更新old网络
# 第303轮训练用时12.809秒，平均累积奖励为-252.379
# 第304轮训练用时12.867秒，平均累积奖励为-255.650
# 更新old网络
# 第305轮训练用时13.111秒，平均累积奖励为-258.199
# 第306轮训练用时12.849秒，平均累积奖励为-257.116
# 更新old网络
# 第307轮训练用时12.807秒，平均累积奖励为-253.497
# 第308轮训练用时12.867秒，平均累积奖励为-254.973
# 更新old网络
# 第309轮训练用时12.864秒，平均累积奖励为-255.986
# 第310轮训练用时12.833秒，平均累积奖励为-264.315
# 更新old网络
# 第311轮训练用时12.751秒，平均累积奖励为-258.932
# 第312轮训练用时12.840秒，平均累积奖励为-260.388
# 更新old网络
# 第313轮训练用时12.826秒，平均累积奖励为-261.496
# 第314轮训练用时12.950秒，平均累积奖励为-262.237
# 更新old网络
# 第315轮训练用时12.756秒，平均累积奖励为-257.835
# 第316轮训练用时12.747秒，平均累积奖励为-259.891
# 更新old网络
# 第317轮训练用时12.966秒，平均累积奖励为-257.278
# 第318轮训练用时12.935秒，平均累积奖励为-254.276
# 更新old网络
# 第319轮训练用时12.909秒，平均累积奖励为-261.422
# 第320轮训练用时12.887秒，平均累积奖励为-255.368
# 更新old网络
# 第321轮训练用时12.970秒，平均累积奖励为-255.846
# 第322轮训练用时13.105秒，平均累积奖励为-260.017
# 更新old网络
# 第323轮训练用时12.891秒，平均累积奖励为-255.500
# 第324轮训练用时12.904秒，平均累积奖励为-252.631
# 更新old网络
# 第325轮训练用时13.151秒，平均累积奖励为-251.103
# 第326轮训练用时12.990秒，平均累积奖励为-254.505
# 更新old网络
# 第327轮训练用时12.906秒，平均累积奖励为-256.804
# 第328轮训练用时12.966秒，平均累积奖励为-251.766
# 更新old网络
# 第329轮训练用时12.995秒，平均累积奖励为-249.292
# 第330轮训练用时13.028秒，平均累积奖励为-246.878
# 更新old网络
# 第331轮训练用时13.286秒，平均累积奖励为-246.531
# 第332轮训练用时12.904秒，平均累积奖励为-246.250
# 更新old网络
# 第333轮训练用时13.055秒，平均累积奖励为-242.713
# 第334轮训练用时13.010秒，平均累积奖励为-251.570
# 更新old网络
# 第335轮训练用时12.896秒，平均累积奖励为-247.031
# 第336轮训练用时12.990秒，平均累积奖励为-242.801
# 更新old网络
# 第337轮训练用时12.985秒，平均累积奖励为-245.848
# 第338轮训练用时12.984秒，平均累积奖励为-243.554
# 更新old网络
# 第339轮训练用时13.101秒，平均累积奖励为-235.547
# 第340轮训练用时13.038秒，平均累积奖励为-245.226
# 更新old网络
# 第341轮训练用时12.933秒，平均累积奖励为-239.734
# 第342轮训练用时13.051秒，平均累积奖励为-242.532
# 更新old网络
# 第343轮训练用时12.907秒，平均累积奖励为-243.097
# 第344轮训练用时12.993秒，平均累积奖励为-248.304
# 更新old网络
# 第345轮训练用时12.748秒，平均累积奖励为-236.272
# 第346轮训练用时12.808秒，平均累积奖励为-246.030
# 更新old网络
# 第347轮训练用时12.789秒，平均累积奖励为-239.082
# 第348轮训练用时12.782秒，平均累积奖励为-246.387
# 更新old网络
# 第349轮训练用时12.776秒，平均累积奖励为-243.920
# 第350轮训练用时12.856秒，平均累积奖励为-238.608
# 更新old网络
# 第351轮训练用时12.786秒，平均累积奖励为-236.524
# 第352轮训练用时12.771秒，平均累积奖励为-244.669
# 更新old网络
# 第353轮训练用时12.762秒，平均累积奖励为-238.460
# 第354轮训练用时12.820秒，平均累积奖励为-237.776
# 更新old网络
# 第355轮训练用时12.763秒，平均累积奖励为-241.093
# 第356轮训练用时12.885秒，平均累积奖励为-237.544
# 更新old网络
# 第357轮训练用时12.695秒，平均累积奖励为-236.523
# 第358轮训练用时12.739秒，平均累积奖励为-235.390
# 更新old网络
# 第359轮训练用时12.811秒，平均累积奖励为-243.065
# 第360轮训练用时12.710秒，平均累积奖励为-239.636
# 更新old网络
# 第361轮训练用时12.769秒，平均累积奖励为-241.265
# 第362轮训练用时12.833秒，平均累积奖励为-235.413
# 更新old网络
# 第363轮训练用时12.757秒，平均累积奖励为-237.709
# 第364轮训练用时12.866秒，平均累积奖励为-236.968
# 更新old网络
# 第365轮训练用时12.845秒，平均累积奖励为-235.904
# 第366轮训练用时12.893秒，平均累积奖励为-237.228
# 更新old网络
# 第367轮训练用时12.737秒，平均累积奖励为-229.280
# 第368轮训练用时12.839秒，平均累积奖励为-233.369
# 更新old网络
# 第369轮训练用时12.851秒，平均累积奖励为-235.964
# 第370轮训练用时12.832秒，平均累积奖励为-238.278
# 更新old网络
# 第371轮训练用时12.896秒，平均累积奖励为-239.663
# 第372轮训练用时12.917秒，平均累积奖励为-231.710
# 更新old网络
# 第373轮训练用时12.746秒，平均累积奖励为-234.388
# 第374轮训练用时12.767秒，平均累积奖励为-239.239
# 更新old网络
# 第375轮训练用时12.780秒，平均累积奖励为-240.886
# 第376轮训练用时12.932秒，平均累积奖励为-241.834
# 更新old网络
# 第377轮训练用时12.876秒，平均累积奖励为-238.879
# 第378轮训练用时12.942秒，平均累积奖励为-233.376
# 更新old网络
# 第379轮训练用时12.938秒，平均累积奖励为-234.003
# 第380轮训练用时12.751秒，平均累积奖励为-231.842
# 更新old网络
# 第381轮训练用时12.864秒，平均累积奖励为-235.181
# 第382轮训练用时12.918秒，平均累积奖励为-235.438
# 更新old网络
# 第383轮训练用时12.833秒，平均累积奖励为-235.258
# 第384轮训练用时12.725秒，平均累积奖励为-230.157
# 更新old网络
# 第385轮训练用时12.847秒，平均累积奖励为-231.023
# 第386轮训练用时12.806秒，平均累积奖励为-236.378
# 更新old网络
# 第387轮训练用时12.803秒，平均累积奖励为-228.700
# 第388轮训练用时12.737秒，平均累积奖励为-238.886
# 更新old网络
# 第389轮训练用时12.885秒，平均累积奖励为-230.638
# 第390轮训练用时12.866秒，平均累积奖励为-227.763
# 更新old网络
# 第391轮训练用时12.864秒，平均累积奖励为-233.791
# 第392轮训练用时12.712秒，平均累积奖励为-228.372
# 更新old网络
# 第393轮训练用时12.828秒，平均累积奖励为-230.542
# 第394轮训练用时12.824秒，平均累积奖励为-231.505
# 更新old网络
# 第395轮训练用时12.968秒，平均累积奖励为-233.514
# 第396轮训练用时12.883秒，平均累积奖励为-235.034
# 更新old网络
# 第397轮训练用时12.860秒，平均累积奖励为-232.580
# 第398轮训练用时12.889秒，平均累积奖励为-239.112
# 更新old网络
# 第399轮训练用时12.755秒，平均累积奖励为-239.006
# 第400轮训练用时12.794秒，平均累积奖励为-236.006
# 更新old网络
# 第401轮训练用时13.030秒，平均累积奖励为-236.343
# 第402轮训练用时12.805秒，平均累积奖励为-232.033
# 更新old网络
# 第403轮训练用时12.740秒，平均累积奖励为-234.400
# 第404轮训练用时12.844秒，平均累积奖励为-237.333
# 更新old网络
# 第405轮训练用时12.884秒，平均累积奖励为-236.227
# 第406轮训练用时12.947秒，平均累积奖励为-233.496
# 更新old网络
# 第407轮训练用时12.766秒，平均累积奖励为-231.110
# 第408轮训练用时12.877秒，平均累积奖励为-237.965
# 更新old网络
# 第409轮训练用时12.878秒，平均累积奖励为-235.552
# 第410轮训练用时12.757秒，平均累积奖励为-237.917
# 更新old网络
# 第411轮训练用时12.812秒，平均累积奖励为-242.760
# 第412轮训练用时12.803秒，平均累积奖励为-241.126
# 更新old网络
# 第413轮训练用时12.852秒，平均累积奖励为-241.209
# 第414轮训练用时12.844秒，平均累积奖励为-248.017
# 更新old网络
# 第415轮训练用时12.864秒，平均累积奖励为-241.590
# 第416轮训练用时12.856秒，平均累积奖励为-250.221
# 更新old网络
# 第417轮训练用时12.946秒，平均累积奖励为-256.602
# 第418轮训练用时13.098秒，平均累积奖励为-254.111
# 更新old网络
# 第419轮训练用时12.918秒，平均累积奖励为-249.290
# 第420轮训练用时12.972秒，平均累积奖励为-253.904
# 更新old网络
# 第421轮训练用时12.754秒，平均累积奖励为-252.968
# 第422轮训练用时12.822秒，平均累积奖励为-260.408
# 更新old网络
# 第423轮训练用时12.796秒，平均累积奖励为-253.318
# 第424轮训练用时12.931秒，平均累积奖励为-251.048
# 更新old网络
# 第425轮训练用时12.848秒，平均累积奖励为-258.045
# 第426轮训练用时12.837秒，平均累积奖励为-256.181
# 更新old网络
# 第427轮训练用时12.918秒，平均累积奖励为-257.492
# 第428轮训练用时12.977秒，平均累积奖励为-253.300
# 更新old网络
# 第429轮训练用时12.805秒，平均累积奖励为-254.076
# 第430轮训练用时12.843秒，平均累积奖励为-249.622
# 更新old网络
# 第431轮训练用时12.795秒，平均累积奖励为-254.602
# 第432轮训练用时12.780秒，平均累积奖励为-249.529
# 更新old网络
# 第433轮训练用时12.802秒，平均累积奖励为-253.380
# 第434轮训练用时12.872秒，平均累积奖励为-247.674
# 更新old网络
# 第435轮训练用时12.862秒，平均累积奖励为-247.912
# 第436轮训练用时12.914秒，平均累积奖励为-257.107
# 更新old网络
# 第437轮训练用时12.958秒，平均累积奖励为-258.143
# 第438轮训练用时12.927秒，平均累积奖励为-250.673
# 更新old网络
# 第439轮训练用时12.850秒，平均累积奖励为-251.171
# 第440轮训练用时12.781秒，平均累积奖励为-256.674
# 更新old网络
# 第441轮训练用时12.791秒，平均累积奖励为-251.299
# 第442轮训练用时12.777秒，平均累积奖励为-247.351
# 更新old网络
# 第443轮训练用时12.852秒，平均累积奖励为-252.775
# 第444轮训练用时12.851秒，平均累积奖励为-241.967
# 更新old网络
# 第445轮训练用时12.767秒，平均累积奖励为-244.042
# 第446轮训练用时12.844秒，平均累积奖励为-246.522
# 更新old网络
# 第447轮训练用时12.792秒，平均累积奖励为-248.846
# 第448轮训练用时12.847秒，平均累积奖励为-251.305
# 更新old网络
# 第449轮训练用时12.893秒，平均累积奖励为-252.173
# 第450轮训练用时12.921秒，平均累积奖励为-252.764
# 更新old网络
# 第451轮训练用时12.878秒，平均累积奖励为-243.505
# 第452轮训练用时12.962秒，平均累积奖励为-246.508
# 更新old网络
# 第453轮训练用时12.877秒，平均累积奖励为-242.329
# 第454轮训练用时12.794秒，平均累积奖励为-246.150
# 更新old网络
# 第455轮训练用时12.903秒，平均累积奖励为-245.034
# 第456轮训练用时12.828秒，平均累积奖励为-250.116
# 更新old网络
# 第457轮训练用时12.796秒，平均累积奖励为-249.922
# 第458轮训练用时12.873秒，平均累积奖励为-242.036
# 更新old网络
# 第459轮训练用时12.858秒，平均累积奖励为-249.251
# 第460轮训练用时12.925秒，平均累积奖励为-244.103
# 更新old网络
# 第461轮训练用时12.728秒，平均累积奖励为-239.871
# 第462轮训练用时12.788秒，平均累积奖励为-237.832
# 更新old网络
# 第463轮训练用时12.798秒，平均累积奖励为-237.868
# 第464轮训练用时12.843秒，平均累积奖励为-240.828
# 更新old网络
# 第465轮训练用时12.781秒，平均累积奖励为-236.217
# 第466轮训练用时12.803秒，平均累积奖励为-240.409
# 更新old网络
# 第467轮训练用时12.733秒，平均累积奖励为-240.848
# 第468轮训练用时12.915秒，平均累积奖励为-237.444
# 更新old网络
# 第469轮训练用时12.709秒，平均累积奖励为-238.311
# 第470轮训练用时12.971秒，平均累积奖励为-233.452
# 更新old网络
# 第471轮训练用时12.794秒，平均累积奖励为-238.085
# 第472轮训练用时12.962秒，平均累积奖励为-237.998
# 更新old网络
# 第473轮训练用时12.852秒，平均累积奖励为-234.684
# 第474轮训练用时12.869秒，平均累积奖励为-239.018
# 更新old网络
# 第475轮训练用时12.905秒，平均累积奖励为-233.239
# 第476轮训练用时12.857秒，平均累积奖励为-234.855
# 更新old网络
# 第477轮训练用时12.808秒，平均累积奖励为-232.007
# 第478轮训练用时12.919秒，平均累积奖励为-237.647
# 更新old网络
# 第479轮训练用时12.871秒，平均累积奖励为-229.910
# 第480轮训练用时12.782秒，平均累积奖励为-233.763
# 更新old网络
# 第481轮训练用时12.917秒，平均累积奖励为-232.490
# 第482轮训练用时12.872秒，平均累积奖励为-232.239
# 更新old网络
# 第483轮训练用时12.807秒，平均累积奖励为-234.126
# 第484轮训练用时12.865秒，平均累积奖励为-227.411
# 更新old网络
# 第485轮训练用时12.856秒，平均累积奖励为-232.667
# 第486轮训练用时12.744秒，平均累积奖励为-231.787
# 更新old网络
# 第487轮训练用时12.825秒，平均累积奖励为-230.920
# 第488轮训练用时12.773秒，平均累积奖励为-230.914
# 更新old网络
# 第489轮训练用时13.011秒，平均累积奖励为-231.329
# 第490轮训练用时12.994秒，平均累积奖励为-227.335
# 更新old网络
# 第491轮训练用时12.829秒，平均累积奖励为-232.043
# 第492轮训练用时12.912秒，平均累积奖励为-228.096
# 更新old网络
# 第493轮训练用时12.854秒，平均累积奖励为-227.419
# 第494轮训练用时12.847秒，平均累积奖励为-228.816
# 更新old网络
# 第495轮训练用时12.996秒，平均累积奖励为-228.335
# 第496轮训练用时12.746秒，平均累积奖励为-225.901
# 更新old网络
# 第497轮训练用时12.882秒，平均累积奖励为-229.432
# 第498轮训练用时12.819秒，平均累积奖励为-227.300
# 更新old网络
# 第499轮训练用时12.875秒，平均累积奖励为-229.260
# 第500轮训练用时12.852秒，平均累积奖励为-223.428
# 更新old网络
# 第501轮训练用时12.907秒，平均累积奖励为-226.106
# 第502轮训练用时12.959秒，平均累积奖励为-225.445
# 更新old网络
# 第503轮训练用时12.950秒，平均累积奖励为-225.927
# 第504轮训练用时12.846秒，平均累积奖励为-222.197
# 最大期望奖励更新为-222.197，保存一次模型
# 更新old网络
# 第505轮训练用时12.818秒，平均累积奖励为-223.402
# 第506轮训练用时12.911秒，平均累积奖励为-225.629
# 更新old网络
# 第507轮训练用时12.982秒，平均累积奖励为-225.651
# 第508轮训练用时12.851秒，平均累积奖励为-226.859
# 更新old网络
# 第509轮训练用时12.971秒，平均累积奖励为-227.715
# 第510轮训练用时12.880秒，平均累积奖励为-229.244
# 更新old网络
# 第511轮训练用时12.898秒，平均累积奖励为-223.802
# 第512轮训练用时13.173秒，平均累积奖励为-223.623
# 更新old网络
# 第513轮训练用时12.832秒，平均累积奖励为-222.460
# 第514轮训练用时12.915秒，平均累积奖励为-226.562
# 更新old网络
# 第515轮训练用时12.898秒，平均累积奖励为-229.403
# 第516轮训练用时13.027秒，平均累积奖励为-224.749
# 更新old网络
# 第517轮训练用时12.858秒，平均累积奖励为-228.310
# 第518轮训练用时12.900秒，平均累积奖励为-220.542
# 最大期望奖励更新为-220.542，保存一次模型
# 更新old网络
# 第519轮训练用时12.856秒，平均累积奖励为-221.614
# 第520轮训练用时13.049秒，平均累积奖励为-217.977
# 最大期望奖励更新为-217.977，保存一次模型
# 更新old网络
# 第521轮训练用时12.883秒，平均累积奖励为-223.204
# 第522轮训练用时12.865秒，平均累积奖励为-220.795
# 更新old网络
# 第523轮训练用时12.875秒，平均累积奖励为-228.067
# 第524轮训练用时13.096秒，平均累积奖励为-223.995
# 更新old网络
# 第525轮训练用时12.848秒，平均累积奖励为-222.896
# 第526轮训练用时12.771秒，平均累积奖励为-223.530
# 更新old网络
# 第527轮训练用时12.859秒，平均累积奖励为-227.059
# 第528轮训练用时12.812秒，平均累积奖励为-220.637
# 更新old网络
# 第529轮训练用时12.828秒，平均累积奖励为-222.771
# 第530轮训练用时12.921秒，平均累积奖励为-228.847
# 更新old网络
# 第531轮训练用时12.837秒，平均累积奖励为-225.388
# 第532轮训练用时12.817秒，平均累积奖励为-225.501
# 更新old网络
# 第533轮训练用时12.914秒，平均累积奖励为-225.356
# 第534轮训练用时13.004秒，平均累积奖励为-219.055
# 更新old网络
# 第535轮训练用时12.765秒，平均累积奖励为-224.494
# 第536轮训练用时12.909秒，平均累积奖励为-219.553
# 更新old网络
# 第537轮训练用时12.883秒，平均累积奖励为-216.133
# 最大期望奖励更新为-216.133，保存一次模型
# 第538轮训练用时12.828秒，平均累积奖励为-225.765
# 更新old网络
# 第539轮训练用时12.736秒，平均累积奖励为-220.531
# 第540轮训练用时12.882秒，平均累积奖励为-222.101
# 更新old网络
# 第541轮训练用时12.874秒，平均累积奖励为-220.940
# 第542轮训练用时12.763秒，平均累积奖励为-224.146
# 更新old网络
# 第543轮训练用时12.723秒，平均累积奖励为-219.673
# 第544轮训练用时13.017秒，平均累积奖励为-220.860
# 更新old网络
# 第545轮训练用时12.896秒，平均累积奖励为-227.492
# 第546轮训练用时12.822秒，平均累积奖励为-215.243
# 最大期望奖励更新为-215.243，保存一次模型
# 更新old网络
# 第547轮训练用时12.886秒，平均累积奖励为-216.136
# 第548轮训练用时13.012秒，平均累积奖励为-219.231
# 更新old网络
# 第549轮训练用时12.895秒，平均累积奖励为-218.356
# 第550轮训练用时12.848秒，平均累积奖励为-221.298
# 更新old网络
# 第551轮训练用时12.954秒，平均累积奖励为-218.369
# 第552轮训练用时12.814秒，平均累积奖励为-224.603
# 更新old网络
# 第553轮训练用时12.864秒，平均累积奖励为-219.479
# 第554轮训练用时12.883秒，平均累积奖励为-224.842
# 更新old网络
# 第555轮训练用时12.959秒，平均累积奖励为-215.791
# 第556轮训练用时12.909秒，平均累积奖励为-222.195
# 更新old网络
# 第557轮训练用时12.832秒，平均累积奖励为-219.344
# 第558轮训练用时12.916秒，平均累积奖励为-211.907
# 最大期望奖励更新为-211.907，保存一次模型
# 更新old网络
# 第559轮训练用时12.845秒，平均累积奖励为-226.444
# 第560轮训练用时12.792秒，平均累积奖励为-224.381
# 更新old网络
# 第561轮训练用时12.900秒，平均累积奖励为-225.681
# 第562轮训练用时12.906秒，平均累积奖励为-224.251
# 更新old网络
# 第563轮训练用时12.915秒，平均累积奖励为-221.612
# 第564轮训练用时12.938秒，平均累积奖励为-217.573
# 更新old网络
# 第565轮训练用时13.070秒，平均累积奖励为-220.421
# 第566轮训练用时13.025秒，平均累积奖励为-217.989
# 更新old网络
# 第567轮训练用时13.175秒，平均累积奖励为-225.512
# 第568轮训练用时13.243秒，平均累积奖励为-223.812
# 更新old网络
# 第569轮训练用时13.083秒，平均累积奖励为-220.648
# 第570轮训练用时12.925秒，平均累积奖励为-218.641
# 更新old网络
# 第571轮训练用时12.940秒，平均累积奖励为-222.137
# 第572轮训练用时12.908秒，平均累积奖励为-219.265
# 更新old网络
# 第573轮训练用时12.950秒，平均累积奖励为-221.110
# 第574轮训练用时13.078秒，平均累积奖励为-223.444
# 更新old网络
# 第575轮训练用时12.918秒，平均累积奖励为-221.062
# 第576轮训练用时13.021秒，平均累积奖励为-218.891
# 更新old网络
# 第577轮训练用时12.863秒，平均累积奖励为-223.788
# 第578轮训练用时12.921秒，平均累积奖励为-222.533
# 更新old网络
# 第579轮训练用时13.025秒，平均累积奖励为-222.402
# 第580轮训练用时12.900秒，平均累积奖励为-215.570
# 更新old网络
# 第581轮训练用时12.949秒，平均累积奖励为-222.400
# 第582轮训练用时13.103秒，平均累积奖励为-221.999
# 更新old网络
# 第583轮训练用时13.032秒，平均累积奖励为-216.686
# 第584轮训练用时12.893秒，平均累积奖励为-218.527
# 更新old网络
# 第585轮训练用时13.066秒，平均累积奖励为-216.137
# 第586轮训练用时12.805秒，平均累积奖励为-217.917
# 更新old网络
# 第587轮训练用时12.965秒，平均累积奖励为-219.490
# 第588轮训练用时12.965秒，平均累积奖励为-215.037
# 更新old网络
# 第589轮训练用时12.940秒，平均累积奖励为-214.414
# 第590轮训练用时12.939秒，平均累积奖励为-218.988
# 更新old网络
# 第591轮训练用时12.942秒，平均累积奖励为-223.581
# 第592轮训练用时13.004秒，平均累积奖励为-217.857
# 更新old网络
# 第593轮训练用时12.990秒，平均累积奖励为-217.737
# 第594轮训练用时12.999秒，平均累积奖励为-219.912
# 更新old网络
# 第595轮训练用时12.804秒，平均累积奖励为-223.664
# 第596轮训练用时12.938秒，平均累积奖励为-215.658
# 更新old网络
# 第597轮训练用时12.835秒，平均累积奖励为-223.877
# 第598轮训练用时12.975秒，平均累积奖励为-218.708
# 更新old网络
# 第599轮训练用时12.952秒，平均累积奖励为-214.905
# 第600轮训练用时13.034秒，平均累积奖励为-215.385
# 更新old网络
# 第601轮训练用时13.047秒，平均累积奖励为-219.670
# 第602轮训练用时13.014秒，平均累积奖励为-220.259
# 更新old网络
# 第603轮训练用时13.003秒，平均累积奖励为-220.755
# 第604轮训练用时13.037秒，平均累积奖励为-221.310
# 更新old网络
# 第605轮训练用时12.993秒，平均累积奖励为-224.486
# 第606轮训练用时12.922秒，平均累积奖励为-216.526
# 更新old网络
# 第607轮训练用时13.037秒，平均累积奖励为-219.123
# 第608轮训练用时12.989秒，平均累积奖励为-220.571
# 更新old网络
# 第609轮训练用时13.040秒，平均累积奖励为-222.669
# 第610轮训练用时13.165秒，平均累积奖励为-213.672
# 更新old网络
# 第611轮训练用时12.961秒，平均累积奖励为-213.397
# 第612轮训练用时12.951秒，平均累积奖励为-215.432
# 更新old网络
# 第613轮训练用时13.000秒，平均累积奖励为-216.638
# 第614轮训练用时12.974秒，平均累积奖励为-219.544
# 更新old网络
# 第615轮训练用时12.965秒，平均累积奖励为-211.646
# 最大期望奖励更新为-211.646，保存一次模型
# 第616轮训练用时12.955秒，平均累积奖励为-220.719
# 更新old网络
# 第617轮训练用时13.008秒，平均累积奖励为-216.605
# 第618轮训练用时12.964秒，平均累积奖励为-223.440
# 更新old网络
# 第619轮训练用时13.123秒，平均累积奖励为-216.078
# 第620轮训练用时12.980秒，平均累积奖励为-220.262
# 更新old网络
# 第621轮训练用时12.988秒，平均累积奖励为-210.242
# 最大期望奖励更新为-210.242，保存一次模型
# 第622轮训练用时12.985秒，平均累积奖励为-214.837
# 更新old网络
# 第623轮训练用时12.887秒，平均累积奖励为-216.895
# 第624轮训练用时12.883秒，平均累积奖励为-214.916
# 更新old网络
# 第625轮训练用时13.025秒，平均累积奖励为-212.732
# 第626轮训练用时13.046秒，平均累积奖励为-217.082
# 更新old网络
# 第627轮训练用时12.904秒，平均累积奖励为-219.083
# 第628轮训练用时12.977秒，平均累积奖励为-219.378
# 更新old网络
# 第629轮训练用时13.009秒，平均累积奖励为-220.076
# 第630轮训练用时12.947秒，平均累积奖励为-214.261
# 更新old网络
# 第631轮训练用时12.958秒，平均累积奖励为-213.889
# 第632轮训练用时13.006秒，平均累积奖励为-219.843
# 更新old网络
# 第633轮训练用时13.002秒，平均累积奖励为-220.880
# 第634轮训练用时12.944秒，平均累积奖励为-220.663
# 更新old网络
# 第635轮训练用时13.163秒，平均累积奖励为-213.992
# 第636轮训练用时12.978秒，平均累积奖励为-220.975
# 更新old网络
# 第637轮训练用时12.941秒，平均累积奖励为-214.629
# 第638轮训练用时12.971秒，平均累积奖励为-217.242
# 更新old网络
# 第639轮训练用时12.831秒，平均累积奖励为-221.197
# 第640轮训练用时13.024秒，平均累积奖励为-218.099
# 更新old网络
# 第641轮训练用时12.826秒，平均累积奖励为-219.671
# 第642轮训练用时12.956秒，平均累积奖励为-218.821
# 更新old网络
# 第643轮训练用时12.909秒，平均累积奖励为-219.258
# 第644轮训练用时12.924秒，平均累积奖励为-221.076
# 更新old网络
# 第645轮训练用时12.733秒，平均累积奖励为-221.423
# 第646轮训练用时12.854秒，平均累积奖励为-221.616
# 更新old网络
# 第647轮训练用时13.012秒，平均累积奖励为-222.833
# 第648轮训练用时12.749秒，平均累积奖励为-228.028
# 更新old网络
# 第649轮训练用时12.921秒，平均累积奖励为-216.245
# 第650轮训练用时12.907秒，平均累积奖励为-227.180
# 更新old网络
# 第651轮训练用时13.039秒，平均累积奖励为-233.039
# 第652轮训练用时13.066秒，平均累积奖励为-226.815
# 更新old网络
# 第653轮训练用时13.056秒，平均累积奖励为-225.553
# 第654轮训练用时12.916秒，平均累积奖励为-229.583
# 更新old网络
# 第655轮训练用时12.991秒，平均累积奖励为-228.193
# 第656轮训练用时13.089秒，平均累积奖励为-232.065
# 更新old网络
# 第657轮训练用时13.006秒，平均累积奖励为-226.192
# 第658轮训练用时12.978秒，平均累积奖励为-230.873
# 更新old网络
# 第659轮训练用时13.088秒，平均累积奖励为-230.635
# 第660轮训练用时12.989秒，平均累积奖励为-222.777
# 更新old网络
# 第661轮训练用时13.025秒，平均累积奖励为-228.675
# 第662轮训练用时13.008秒，平均累积奖励为-223.127
# 更新old网络
# 第663轮训练用时13.116秒，平均累积奖励为-230.491
# 第664轮训练用时12.854秒，平均累积奖励为-225.876
# 更新old网络
# 第665轮训练用时12.926秒，平均累积奖励为-225.935
# 第666轮训练用时12.924秒，平均累积奖励为-222.552
# 更新old网络
# 第667轮训练用时12.985秒，平均累积奖励为-221.643
# 第668轮训练用时13.095秒，平均累积奖励为-226.619
# 更新old网络
# 第669轮训练用时13.035秒，平均累积奖励为-225.801
# 第670轮训练用时12.908秒，平均累积奖励为-229.016
# 更新old网络
# 第671轮训练用时13.184秒，平均累积奖励为-227.127
# 第672轮训练用时13.009秒，平均累积奖励为-226.644
# 更新old网络
# 第673轮训练用时12.899秒，平均累积奖励为-225.169
# 第674轮训练用时12.912秒，平均累积奖励为-223.949
# 更新old网络
# 第675轮训练用时13.002秒，平均累积奖励为-224.599
# 第676轮训练用时12.901秒，平均累积奖励为-227.965
# 更新old网络
# 第677轮训练用时12.873秒，平均累积奖励为-226.282
# 第678轮训练用时12.887秒，平均累积奖励为-224.100
# 更新old网络
# 第679轮训练用时12.941秒，平均累积奖励为-228.185
# 第680轮训练用时12.904秒，平均累积奖励为-230.480
# 更新old网络
# 第681轮训练用时12.983秒，平均累积奖励为-224.238
# 第682轮训练用时12.840秒，平均累积奖励为-228.127
# 更新old网络
# 第683轮训练用时12.911秒，平均累积奖励为-232.948
# 第684轮训练用时13.021秒，平均累积奖励为-226.518
# 更新old网络
# 第685轮训练用时12.971秒，平均累积奖励为-226.557
# 第686轮训练用时13.074秒，平均累积奖励为-229.348
# 更新old网络
# 第687轮训练用时12.841秒，平均累积奖励为-224.461
# 第688轮训练用时13.092秒，平均累积奖励为-229.302
# 更新old网络
# 第689轮训练用时12.930秒，平均累积奖励为-226.528
# 第690轮训练用时12.909秒，平均累积奖励为-228.927
# 更新old网络
# 第691轮训练用时12.921秒，平均累积奖励为-223.541
# 第692轮训练用时12.810秒，平均累积奖励为-225.127
# 更新old网络
# 第693轮训练用时12.889秒，平均累积奖励为-221.729
# 第694轮训练用时12.807秒，平均累积奖励为-220.493
# 更新old网络
# 第695轮训练用时12.839秒，平均累积奖励为-219.738
# 第696轮训练用时12.907秒，平均累积奖励为-217.534
# 更新old网络
# 第697轮训练用时12.950秒，平均累积奖励为-215.335
# 第698轮训练用时12.819秒，平均累积奖励为-220.276
# 更新old网络
# 第699轮训练用时12.880秒，平均累积奖励为-217.171
# 第700轮训练用时12.978秒，平均累积奖励为-221.172
# 更新old网络
# 第701轮训练用时12.871秒，平均累积奖励为-217.320
# 第702轮训练用时12.930秒，平均累积奖励为-221.709
# 更新old网络
# 第703轮训练用时12.865秒，平均累积奖励为-211.578
# 第704轮训练用时12.966秒，平均累积奖励为-218.267
# 更新old网络
# 第705轮训练用时13.016秒，平均累积奖励为-216.502
# 第706轮训练用时12.936秒，平均累积奖励为-217.157
# 更新old网络
# 第707轮训练用时12.888秒，平均累积奖励为-215.474
# 第708轮训练用时12.987秒，平均累积奖励为-207.896
# 最大期望奖励更新为-207.896，保存一次模型
# 更新old网络
# 第709轮训练用时12.802秒，平均累积奖励为-210.497
# 第710轮训练用时12.926秒，平均累积奖励为-213.141
# 更新old网络
# 第711轮训练用时12.912秒，平均累积奖励为-216.236
# 第712轮训练用时12.995秒，平均累积奖励为-207.378
# 最大期望奖励更新为-207.378，保存一次模型
# 更新old网络
# 第713轮训练用时13.097秒，平均累积奖励为-211.188
# 第714轮训练用时13.208秒，平均累积奖励为-216.975
# 更新old网络
# 第715轮训练用时13.041秒，平均累积奖励为-211.133
# 第716轮训练用时12.822秒，平均累积奖励为-214.362
# 更新old网络
# 第717轮训练用时12.871秒，平均累积奖励为-210.254
# 第718轮训练用时12.975秒，平均累积奖励为-214.769
# 更新old网络
# 第719轮训练用时12.912秒，平均累积奖励为-212.912
# 第720轮训练用时12.781秒，平均累积奖励为-206.185
# 最大期望奖励更新为-206.185，保存一次模型
# 更新old网络
# 第721轮训练用时12.990秒，平均累积奖励为-211.075
# 第722轮训练用时12.932秒，平均累积奖励为-214.111
# 更新old网络
# 第723轮训练用时12.866秒，平均累积奖励为-207.506
# 第724轮训练用时12.964秒，平均累积奖励为-212.887
# 更新old网络
# 第725轮训练用时12.882秒，平均累积奖励为-208.261
# 第726轮训练用时12.815秒，平均累积奖励为-211.641
# 更新old网络
# 第727轮训练用时12.931秒，平均累积奖励为-213.226
# 第728轮训练用时13.024秒，平均累积奖励为-209.374
# 更新old网络
# 第729轮训练用时12.765秒，平均累积奖励为-215.068
# 第730轮训练用时12.972秒，平均累积奖励为-209.065
# 更新old网络
# 第731轮训练用时12.993秒，平均累积奖励为-209.895
# 第732轮训练用时12.925秒，平均累积奖励为-209.068
# 更新old网络
# 第733轮训练用时12.829秒，平均累积奖励为-207.743
# 第734轮训练用时12.889秒，平均累积奖励为-209.167
# 更新old网络
# 第735轮训练用时12.992秒，平均累积奖励为-208.656
# 第736轮训练用时13.003秒，平均累积奖励为-209.280
# 更新old网络
# 第737轮训练用时12.931秒，平均累积奖励为-209.323
# 第738轮训练用时12.920秒，平均累积奖励为-206.603
# 更新old网络
# 第739轮训练用时12.919秒，平均累积奖励为-215.090
# 第740轮训练用时13.009秒，平均累积奖励为-212.506
# 更新old网络
# 第741轮训练用时12.981秒，平均累积奖励为-207.369
# 第742轮训练用时12.898秒，平均累积奖励为-211.216
# 更新old网络
# 第743轮训练用时12.815秒，平均累积奖励为-205.889
# 最大期望奖励更新为-205.889，保存一次模型
# 第744轮训练用时12.921秒，平均累积奖励为-212.984
# 更新old网络
# 第745轮训练用时12.794秒，平均累积奖励为-210.538
# 第746轮训练用时12.863秒，平均累积奖励为-211.496
# 更新old网络
# 第747轮训练用时12.925秒，平均累积奖励为-215.883
# 第748轮训练用时13.157秒，平均累积奖励为-214.511
# 更新old网络
# 第749轮训练用时13.048秒，平均累积奖励为-213.584
# 第750轮训练用时12.956秒，平均累积奖励为-209.159
# 更新old网络
# 第751轮训练用时12.850秒，平均累积奖励为-212.627
# 第752轮训练用时12.963秒，平均累积奖励为-211.605
# 更新old网络
# 第753轮训练用时12.901秒，平均累积奖励为-215.067
# 第754轮训练用时12.921秒，平均累积奖励为-211.720
# 更新old网络
# 第755轮训练用时12.907秒，平均累积奖励为-212.563
# 第756轮训练用时13.031秒，平均累积奖励为-212.330
# 更新old网络
# 第757轮训练用时12.930秒，平均累积奖励为-212.680
# 第758轮训练用时12.867秒，平均累积奖励为-213.438
# 更新old网络
# 第759轮训练用时13.016秒，平均累积奖励为-211.420
# 第760轮训练用时12.883秒，平均累积奖励为-215.105
# 更新old网络
# 第761轮训练用时12.879秒，平均累积奖励为-214.085
# 第762轮训练用时12.817秒，平均累积奖励为-208.124
# 更新old网络
# 第763轮训练用时13.097秒，平均累积奖励为-215.998
# 第764轮训练用时13.315秒，平均累积奖励为-213.634
# 更新old网络
# 第765轮训练用时12.916秒，平均累积奖励为-207.523
# 第766轮训练用时12.933秒，平均累积奖励为-211.678
# 更新old网络
# 第767轮训练用时12.958秒，平均累积奖励为-211.516
# 第768轮训练用时12.939秒，平均累积奖励为-214.686
# 更新old网络
# 第769轮训练用时12.942秒，平均累积奖励为-211.045
# 第770轮训练用时12.895秒，平均累积奖励为-211.237
# 更新old网络
# 第771轮训练用时12.987秒，平均累积奖励为-209.545
# 第772轮训练用时12.951秒，平均累积奖励为-212.526
# 更新old网络
# 第773轮训练用时12.944秒，平均累积奖励为-214.090
# 第774轮训练用时12.869秒，平均累积奖励为-212.303
# 更新old网络
# 第775轮训练用时13.062秒，平均累积奖励为-210.318
# 第776轮训练用时13.027秒，平均累积奖励为-214.928
# 更新old网络
# 第777轮训练用时12.974秒，平均累积奖励为-210.281
# 第778轮训练用时12.975秒，平均累积奖励为-213.809
# 更新old网络
# 第779轮训练用时12.959秒，平均累积奖励为-215.312
# 第780轮训练用时12.951秒，平均累积奖励为-213.635
# 更新old网络
# 第781轮训练用时13.076秒，平均累积奖励为-206.928
# 第782轮训练用时13.049秒，平均累积奖励为-221.059
# 更新old网络
# 第783轮训练用时13.005秒，平均累积奖励为-213.385
# 第784轮训练用时12.905秒，平均累积奖励为-213.980
# 更新old网络
# 第785轮训练用时13.250秒，平均累积奖励为-213.433
# 第786轮训练用时12.982秒，平均累积奖励为-213.252
# 更新old网络
# 第787轮训练用时12.992秒，平均累积奖励为-209.375
# 第788轮训练用时13.017秒，平均累积奖励为-211.833
# 更新old网络
# 第789轮训练用时12.874秒，平均累积奖励为-206.308
# 第790轮训练用时13.161秒，平均累积奖励为-209.574
# 更新old网络
# 第791轮训练用时13.209秒，平均累积奖励为-207.242
# 第792轮训练用时13.203秒，平均累积奖励为-211.881
# 更新old网络
# 第793轮训练用时13.230秒，平均累积奖励为-215.025
# 第794轮训练用时12.835秒，平均累积奖励为-212.979
# 更新old网络
# 第795轮训练用时13.030秒，平均累积奖励为-212.301
# 第796轮训练用时12.992秒，平均累积奖励为-209.214
# 更新old网络
# 第797轮训练用时12.993秒，平均累积奖励为-211.357
# 第798轮训练用时13.078秒，平均累积奖励为-214.631
# 更新old网络
# 第799轮训练用时13.006秒，平均累积奖励为-215.967
# 第800轮训练用时12.863秒，平均累积奖励为-212.631
# 更新old网络
# 第801轮训练用时13.121秒，平均累积奖励为-214.458
# 第802轮训练用时13.003秒，平均累积奖励为-217.482
# 更新old网络
# 第803轮训练用时12.927秒，平均累积奖励为-214.222
# 第804轮训练用时12.945秒，平均累积奖励为-218.343
# 更新old网络
# 第805轮训练用时12.975秒，平均累积奖励为-214.973
# 第806轮训练用时13.000秒，平均累积奖励为-214.674
# 更新old网络
# 第807轮训练用时13.057秒，平均累积奖励为-215.633
# 第808轮训练用时12.975秒，平均累积奖励为-216.467
# 更新old网络
# 第809轮训练用时12.963秒，平均累积奖励为-215.220
# 第810轮训练用时12.887秒，平均累积奖励为-209.935
# 更新old网络
# 第811轮训练用时13.194秒，平均累积奖励为-216.269
# 第812轮训练用时13.025秒，平均累积奖励为-215.251
# 更新old网络
# 第813轮训练用时12.905秒，平均累积奖励为-211.967
# 第814轮训练用时12.943秒，平均累积奖励为-215.542
# 更新old网络
# 第815轮训练用时13.128秒，平均累积奖励为-209.393
# 第816轮训练用时13.058秒，平均累积奖励为-212.422
# 更新old网络
# 第817轮训练用时12.812秒，平均累积奖励为-214.961
# 第818轮训练用时13.017秒，平均累积奖励为-211.853
# 更新old网络
# 第819轮训练用时12.960秒，平均累积奖励为-208.991
# 第820轮训练用时12.931秒，平均累积奖励为-214.053
# 更新old网络
# 第821轮训练用时12.863秒，平均累积奖励为-213.166
# 第822轮训练用时12.795秒，平均累积奖励为-215.295
# 更新old网络
# 第823轮训练用时13.020秒，平均累积奖励为-212.369
# 第824轮训练用时12.792秒，平均累积奖励为-217.639
# 更新old网络
# 第825轮训练用时12.859秒，平均累积奖励为-216.807
# 第826轮训练用时12.853秒，平均累积奖励为-210.767
# 更新old网络
# 第827轮训练用时12.877秒，平均累积奖励为-209.842
# 第828轮训练用时13.006秒，平均累积奖励为-216.717
# 更新old网络
# 第829轮训练用时12.914秒，平均累积奖励为-216.071
# 第830轮训练用时12.892秒，平均累积奖励为-214.345
# 更新old网络
# 第831轮训练用时12.909秒，平均累积奖励为-210.175
# 第832轮训练用时12.858秒，平均累积奖励为-216.595
# 更新old网络
# 第833轮训练用时13.108秒，平均累积奖励为-216.289
# 第834轮训练用时13.087秒，平均累积奖励为-213.183
# 更新old网络
# 第835轮训练用时13.023秒，平均累积奖励为-208.107
# 第836轮训练用时12.882秒，平均累积奖励为-217.450
# 更新old网络
# 第837轮训练用时13.015秒，平均累积奖励为-216.893
# 第838轮训练用时12.965秒，平均累积奖励为-214.085
# 更新old网络
# 第839轮训练用时12.980秒，平均累积奖励为-216.273
# 第840轮训练用时12.838秒，平均累积奖励为-218.690
# 更新old网络
# 第841轮训练用时12.878秒，平均累积奖励为-217.832
# 第842轮训练用时12.931秒，平均累积奖励为-214.706
# 更新old网络
# 第843轮训练用时13.026秒，平均累积奖励为-212.413
# 第844轮训练用时13.017秒，平均累积奖励为-213.746
# 更新old网络
# 第845轮训练用时13.012秒，平均累积奖励为-212.678
# 第846轮训练用时12.922秒，平均累积奖励为-215.313
# 更新old网络
# 第847轮训练用时12.911秒，平均累积奖励为-211.018
# 第848轮训练用时12.998秒，平均累积奖励为-209.653
# 更新old网络
# 第849轮训练用时13.127秒，平均累积奖励为-216.791
# 第850轮训练用时12.951秒，平均累积奖励为-214.024
# 更新old网络
# 第851轮训练用时13.009秒，平均累积奖励为-214.218
# 第852轮训练用时12.933秒，平均累积奖励为-214.273
# 更新old网络
# 第853轮训练用时12.992秒，平均累积奖励为-212.583
# 第854轮训练用时13.029秒，平均累积奖励为-212.360
# 更新old网络
# 第855轮训练用时13.019秒，平均累积奖励为-216.233
# 第856轮训练用时12.967秒，平均累积奖励为-210.057
# 更新old网络
# 第857轮训练用时13.012秒，平均累积奖励为-212.849
# 第858轮训练用时13.134秒，平均累积奖励为-210.943
# 更新old网络
# 第859轮训练用时12.901秒，平均累积奖励为-215.179
# 第860轮训练用时12.886秒，平均累积奖励为-210.803
# 更新old网络
# 第861轮训练用时12.952秒，平均累积奖励为-212.470
# 第862轮训练用时12.894秒，平均累积奖励为-214.310
# 更新old网络
# 第863轮训练用时13.029秒，平均累积奖励为-211.776
# 第864轮训练用时12.923秒，平均累积奖励为-213.447
# 更新old网络
# 第865轮训练用时13.022秒，平均累积奖励为-214.193
# 第866轮训练用时12.945秒，平均累积奖励为-213.925
# 更新old网络
# 第867轮训练用时12.902秒，平均累积奖励为-212.019
# 第868轮训练用时13.019秒，平均累积奖励为-210.693
# 更新old网络
# 第869轮训练用时13.016秒，平均累积奖励为-207.182
# 第870轮训练用时12.902秒，平均累积奖励为-209.651
# 更新old网络
# 第871轮训练用时13.002秒，平均累积奖励为-208.130
# 第872轮训练用时12.772秒，平均累积奖励为-210.726
# 更新old网络
# 第873轮训练用时12.726秒，平均累积奖励为-206.741
# 第874轮训练用时12.894秒，平均累积奖励为-207.084
# 更新old网络
# 第875轮训练用时12.895秒，平均累积奖励为-211.228
# 第876轮训练用时13.003秒，平均累积奖励为-209.099
# 更新old网络
# 第877轮训练用时12.970秒，平均累积奖励为-211.558
# 第878轮训练用时12.881秒，平均累积奖励为-212.194
# 更新old网络
# 第879轮训练用时13.200秒，平均累积奖励为-213.024
# 第880轮训练用时12.848秒，平均累积奖励为-213.134
# 更新old网络
# 第881轮训练用时12.945秒，平均累积奖励为-210.792
# 第882轮训练用时13.066秒，平均累积奖励为-213.273
# 更新old网络
# 第883轮训练用时13.001秒，平均累积奖励为-207.483
# 第884轮训练用时12.948秒，平均累积奖励为-210.629
# 更新old网络
# 第885轮训练用时13.064秒，平均累积奖励为-209.278
# 第886轮训练用时12.925秒，平均累积奖励为-214.156
# 更新old网络
# 第887轮训练用时12.923秒，平均累积奖励为-211.257
# 第888轮训练用时13.003秒，平均累积奖励为-206.643
# 更新old网络
# 第889轮训练用时12.929秒，平均累积奖励为-206.623
# 第890轮训练用时12.970秒，平均累积奖励为-205.340
# 最大期望奖励更新为-205.340，保存一次模型
# 更新old网络
# 第891轮训练用时12.876秒，平均累积奖励为-206.089
# 第892轮训练用时12.920秒，平均累积奖励为-209.477
# 更新old网络
# 第893轮训练用时13.006秒，平均累积奖励为-209.744
# 第894轮训练用时12.920秒，平均累积奖励为-208.540
# 更新old网络
# 第895轮训练用时13.075秒，平均累积奖励为-210.223
# 第896轮训练用时12.964秒，平均累积奖励为-211.628
# 更新old网络
# 第897轮训练用时12.893秒，平均累积奖励为-211.281
# 第898轮训练用时12.964秒，平均累积奖励为-214.699
# 更新old网络
# 第899轮训练用时12.939秒，平均累积奖励为-208.459
# 第900轮训练用时13.116秒，平均累积奖励为-214.377
# 更新old网络
# 第901轮训练用时12.847秒，平均累积奖励为-210.092
# 第902轮训练用时12.919秒，平均累积奖励为-210.982
# 更新old网络
# 第903轮训练用时13.056秒，平均累积奖励为-213.586
# 第904轮训练用时13.011秒，平均累积奖励为-205.301
# 最大期望奖励更新为-205.301，保存一次模型
# 更新old网络
# 第905轮训练用时12.961秒，平均累积奖励为-207.262
# 第906轮训练用时12.834秒，平均累积奖励为-211.523
# 更新old网络
# 第907轮训练用时12.998秒，平均累积奖励为-208.009
# 第908轮训练用时13.042秒，平均累积奖励为-214.276
# 更新old网络
# 第909轮训练用时12.931秒，平均累积奖励为-212.674
# 第910轮训练用时12.828秒，平均累积奖励为-210.861
# 更新old网络
# 第911轮训练用时12.837秒，平均累积奖励为-217.613
# 第912轮训练用时12.863秒，平均累积奖励为-208.522
# 更新old网络
# 第913轮训练用时12.994秒，平均累积奖励为-213.034
# 第914轮训练用时12.919秒，平均累积奖励为-214.601
# 更新old网络
# 第915轮训练用时12.948秒，平均累积奖励为-211.439
# 第916轮训练用时12.881秒，平均累积奖励为-214.678
# 更新old网络
# 第917轮训练用时12.946秒，平均累积奖励为-215.150
# 第918轮训练用时13.192秒，平均累积奖励为-211.844
# 更新old网络
# 第919轮训练用时13.034秒，平均累积奖励为-213.673
# 第920轮训练用时12.904秒，平均累积奖励为-213.331
# 更新old网络
# 第921轮训练用时13.093秒，平均累积奖励为-215.340
# 第922轮训练用时12.927秒，平均累积奖励为-212.399
# 更新old网络
# 第923轮训练用时13.065秒，平均累积奖励为-209.052
# 第924轮训练用时13.030秒，平均累积奖励为-210.375
# 更新old网络
# 第925轮训练用时13.027秒，平均累积奖励为-218.992
# 第926轮训练用时12.875秒，平均累积奖励为-211.673
# 更新old网络
# 第927轮训练用时12.882秒，平均累积奖励为-215.278
# 第928轮训练用时12.836秒，平均累积奖励为-215.170
# 更新old网络
# 第929轮训练用时13.056秒，平均累积奖励为-212.867
# 第930轮训练用时13.013秒，平均累积奖励为-213.914
# 更新old网络
# 第931轮训练用时12.858秒，平均累积奖励为-215.808
# 第932轮训练用时12.931秒，平均累积奖励为-214.558
# 更新old网络
# 第933轮训练用时12.972秒，平均累积奖励为-214.746
# 第934轮训练用时13.035秒，平均累积奖励为-214.749
# 更新old网络
# 第935轮训练用时12.957秒，平均累积奖励为-216.279
# 第936轮训练用时12.752秒，平均累积奖励为-214.530
# 更新old网络
# 第937轮训练用时12.946秒，平均累积奖励为-210.630
# 第938轮训练用时12.935秒，平均累积奖励为-217.624
# 更新old网络
# 第939轮训练用时12.935秒，平均累积奖励为-217.445
# 第940轮训练用时12.969秒，平均累积奖励为-223.503
# 更新old网络
# 第941轮训练用时12.897秒，平均累积奖励为-214.767
# 第942轮训练用时12.860秒，平均累积奖励为-221.154
# 更新old网络
# 第943轮训练用时12.908秒，平均累积奖励为-210.840
# 第944轮训练用时12.881秒，平均累积奖励为-225.141
# 更新old网络
# 第945轮训练用时12.873秒，平均累积奖励为-221.044
# 第946轮训练用时12.976秒，平均累积奖励为-219.901
# 更新old网络
# 第947轮训练用时12.889秒，平均累积奖励为-229.688
# 第948轮训练用时13.004秒，平均累积奖励为-227.570
# 更新old网络
# 第949轮训练用时13.363秒，平均累积奖励为-225.424
# 第950轮训练用时13.072秒，平均累积奖励为-229.849
# 更新old网络
# 第951轮训练用时13.075秒，平均累积奖励为-228.866
# 第952轮训练用时12.974秒，平均累积奖励为-225.984
# 更新old网络
# 第953轮训练用时12.842秒，平均累积奖励为-226.375
# 第954轮训练用时13.007秒，平均累积奖励为-228.709
# 更新old网络
# 第955轮训练用时12.953秒，平均累积奖励为-222.716
# 第956轮训练用时12.935秒，平均累积奖励为-224.061
# 更新old网络
# 第957轮训练用时12.753秒，平均累积奖励为-220.299
# 第958轮训练用时12.892秒，平均累积奖励为-228.108
# 更新old网络
# 第959轮训练用时13.007秒，平均累积奖励为-221.551
# 第960轮训练用时12.896秒，平均累积奖励为-222.613
# 更新old网络
# 第961轮训练用时13.011秒，平均累积奖励为-221.665
# 第962轮训练用时12.832秒，平均累积奖励为-223.532
# 更新old网络
# 第963轮训练用时12.868秒，平均累积奖励为-225.834
# 第964轮训练用时12.923秒，平均累积奖励为-222.374
# 更新old网络
# 第965轮训练用时12.933秒，平均累积奖励为-228.061
# 第966轮训练用时12.883秒，平均累积奖励为-224.428
# 更新old网络
# 第967轮训练用时13.014秒，平均累积奖励为-225.088
# 第968轮训练用时13.064秒，平均累积奖励为-225.029
# 更新old网络
# 第969轮训练用时13.023秒，平均累积奖励为-222.785
# 第970轮训练用时12.897秒，平均累积奖励为-229.093
# 更新old网络
# 第971轮训练用时12.913秒，平均累积奖励为-229.790
# 第972轮训练用时12.934秒，平均累积奖励为-222.644
# 更新old网络
# 第973轮训练用时12.892秒，平均累积奖励为-227.833
# 第974轮训练用时12.967秒，平均累积奖励为-223.194
# 更新old网络
# 第975轮训练用时13.081秒，平均累积奖励为-222.958
# 第976轮训练用时12.960秒，平均累积奖励为-225.243
# 更新old网络
# 第977轮训练用时12.836秒，平均累积奖励为-223.446
# 第978轮训练用时13.216秒，平均累积奖励为-219.775
# 更新old网络
# 第979轮训练用时13.169秒，平均累积奖励为-218.687
# 第980轮训练用时12.872秒，平均累积奖励为-225.266
# 更新old网络
# 第981轮训练用时13.123秒，平均累积奖励为-219.872
# 第982轮训练用时12.701秒，平均累积奖励为-219.908
# 更新old网络
# 第983轮训练用时12.906秒，平均累积奖励为-221.176
# 第984轮训练用时13.011秒，平均累积奖励为-219.948
# 更新old网络
# 第985轮训练用时12.901秒，平均累积奖励为-219.930
# 第986轮训练用时12.986秒，平均累积奖励为-222.336
# 更新old网络
# 第987轮训练用时12.947秒，平均累积奖励为-215.604
# 第988轮训练用时12.972秒，平均累积奖励为-215.644
# 更新old网络
# 第989轮训练用时13.022秒，平均累积奖励为-220.261
# 第990轮训练用时12.897秒，平均累积奖励为-220.968
# 更新old网络
# 第991轮训练用时13.087秒，平均累积奖励为-219.516
# 第992轮训练用时13.197秒，平均累积奖励为-224.150
# 更新old网络
# 第993轮训练用时13.148秒，平均累积奖励为-213.531
# 第994轮训练用时12.960秒，平均累积奖励为-222.976
# 更新old网络
# 第995轮训练用时12.961秒，平均累积奖励为-216.183
# 第996轮训练用时12.945秒，平均累积奖励为-215.366
# 更新old网络
# 第997轮训练用时12.984秒，平均累积奖励为-219.048
# 第998轮训练用时12.896秒，平均累积奖励为-218.506
# 更新old网络
# 第999轮训练用时12.934秒，平均累积奖励为-215.453
# 第1000轮训练用时12.882秒，平均累积奖励为-218.114
# 更新old网络
# 第1001轮训练用时13.062秒，平均累积奖励为-214.037
# 第1002轮训练用时13.018秒，平均累积奖励为-218.450
# 更新old网络
# 第1003轮训练用时12.757秒，平均累积奖励为-214.943
# 第1004轮训练用时12.882秒，平均累积奖励为-216.612
# 更新old网络
# 第1005轮训练用时13.004秒，平均累积奖励为-211.746
# 第1006轮训练用时12.966秒，平均累积奖励为-213.814
# 更新old网络
# 第1007轮训练用时13.031秒，平均累积奖励为-213.576
# 第1008轮训练用时12.886秒，平均累积奖励为-214.368
# 更新old网络
# 第1009轮训练用时12.996秒，平均累积奖励为-213.664
# 第1010轮训练用时12.905秒，平均累积奖励为-213.063
# 更新old网络
# 第1011轮训练用时13.359秒，平均累积奖励为-209.853
# 第1012轮训练用时12.952秒，平均累积奖励为-211.310
# 更新old网络
# 第1013轮训练用时13.211秒，平均累积奖励为-212.177
# 第1014轮训练用时13.013秒，平均累积奖励为-215.040
# 更新old网络
# 第1015轮训练用时12.994秒，平均累积奖励为-215.532
# 第1016轮训练用时13.043秒，平均累积奖励为-209.979
# 更新old网络
# 第1017轮训练用时13.069秒，平均累积奖励为-211.987
# 第1018轮训练用时13.014秒，平均累积奖励为-213.080
# 更新old网络
# 第1019轮训练用时13.066秒，平均累积奖励为-208.010
# 第1020轮训练用时12.891秒，平均累积奖励为-218.112
# 更新old网络
# 第1021轮训练用时12.870秒，平均累积奖励为-210.131
# 第1022轮训练用时13.149秒，平均累积奖励为-206.202
# 更新old网络
# 第1023轮训练用时12.891秒，平均累积奖励为-208.284
# 第1024轮训练用时13.061秒，平均累积奖励为-206.157
# 更新old网络
# 第1025轮训练用时12.886秒，平均累积奖励为-202.747
# 最大期望奖励更新为-202.747，保存一次模型
# 第1026轮训练用时13.083秒，平均累积奖励为-212.283
# 更新old网络
# 第1027轮训练用时12.981秒，平均累积奖励为-209.397
# 第1028轮训练用时12.958秒，平均累积奖励为-208.741
# 更新old网络
# 第1029轮训练用时13.145秒，平均累积奖励为-206.458
# 第1030轮训练用时12.990秒，平均累积奖励为-213.790
# 更新old网络
# 第1031轮训练用时13.018秒，平均累积奖励为-214.323
# 第1032轮训练用时12.890秒，平均累积奖励为-209.303
# 更新old网络
# 第1033轮训练用时12.982秒，平均累积奖励为-208.173
# 第1034轮训练用时12.908秒，平均累积奖励为-204.496
# 更新old网络
# 第1035轮训练用时12.866秒，平均累积奖励为-205.653
# 第1036轮训练用时12.951秒，平均累积奖励为-213.950
# 更新old网络
# 第1037轮训练用时13.018秒，平均累积奖励为-210.946
# 第1038轮训练用时12.979秒，平均累积奖励为-213.485
# 更新old网络
# 第1039轮训练用时12.971秒，平均累积奖励为-210.259
# 第1040轮训练用时13.031秒，平均累积奖励为-211.650
# 更新old网络
# 第1041轮训练用时12.909秒，平均累积奖励为-209.453
# 第1042轮训练用时12.973秒，平均累积奖励为-212.253
# 更新old网络
# 第1043轮训练用时12.963秒，平均累积奖励为-208.249
# 第1044轮训练用时12.951秒，平均累积奖励为-211.568
# 更新old网络
# 第1045轮训练用时12.834秒，平均累积奖励为-210.493
# 第1046轮训练用时12.808秒，平均累积奖励为-214.325
# 更新old网络
# 第1047轮训练用时12.906秒，平均累积奖励为-212.687
# 第1048轮训练用时12.882秒，平均累积奖励为-212.629
# 更新old网络
# 第1049轮训练用时12.753秒，平均累积奖励为-213.058
# 第1050轮训练用时12.848秒，平均累积奖励为-206.622
# 更新old网络
# 第1051轮训练用时13.110秒，平均累积奖励为-210.262
# 第1052轮训练用时13.079秒，平均累积奖励为-211.119
# 更新old网络
# 第1053轮训练用时12.965秒，平均累积奖励为-208.816
# 第1054轮训练用时13.100秒，平均累积奖励为-216.742
# 更新old网络
# 第1055轮训练用时13.255秒，平均累积奖励为-211.197
# 第1056轮训练用时13.046秒，平均累积奖励为-209.827
# 更新old网络
# 第1057轮训练用时13.032秒，平均累积奖励为-210.680
# 第1058轮训练用时13.069秒，平均累积奖励为-213.542
# 更新old网络
# 第1059轮训练用时13.021秒，平均累积奖励为-209.993
# 第1060轮训练用时13.164秒，平均累积奖励为-205.854
# 更新old网络
# 第1061轮训练用时12.878秒，平均累积奖励为-215.965
# 第1062轮训练用时12.947秒，平均累积奖励为-212.169
# 更新old网络
# 第1063轮训练用时12.956秒，平均累积奖励为-216.171
# 第1064轮训练用时12.880秒，平均累积奖励为-210.479
# 更新old网络
# 第1065轮训练用时12.921秒，平均累积奖励为-210.523
# 第1066轮训练用时12.856秒，平均累积奖励为-210.584
# 更新old网络
# 第1067轮训练用时12.867秒，平均累积奖励为-208.827
# 第1068轮训练用时13.121秒，平均累积奖励为-213.552
# 更新old网络
# 第1069轮训练用时12.953秒，平均累积奖励为-204.207
# 第1070轮训练用时13.022秒，平均累积奖励为-210.704
# 更新old网络
# 第1071轮训练用时12.932秒，平均累积奖励为-211.940
# 第1072轮训练用时13.002秒，平均累积奖励为-207.960
# 更新old网络
# 第1073轮训练用时13.128秒，平均累积奖励为-210.031
# 第1074轮训练用时12.939秒，平均累积奖励为-212.784
# 更新old网络
# 第1075轮训练用时12.967秒，平均累积奖励为-208.256
# 第1076轮训练用时12.942秒，平均累积奖励为-212.560
# 更新old网络
# 第1077轮训练用时13.110秒，平均累积奖励为-215.143
# 第1078轮训练用时12.973秒，平均累积奖励为-212.565
# 更新old网络
# 第1079轮训练用时12.875秒，平均累积奖励为-211.300
# 第1080轮训练用时12.878秒，平均累积奖励为-212.049
# 更新old网络
# 第1081轮训练用时13.010秒，平均累积奖励为-204.134
# 第1082轮训练用时12.993秒，平均累积奖励为-216.442
# 更新old网络
# 第1083轮训练用时13.018秒，平均累积奖励为-211.909
# 第1084轮训练用时12.989秒，平均累积奖励为-214.095
# 更新old网络
# 第1085轮训练用时13.141秒，平均累积奖励为-209.251
# 第1086轮训练用时13.216秒，平均累积奖励为-207.435
# 更新old网络
# 第1087轮训练用时12.849秒，平均累积奖励为-209.252
# 第1088轮训练用时12.983秒，平均累积奖励为-212.701
# 更新old网络
# 第1089轮训练用时13.187秒，平均累积奖励为-211.013
# 第1090轮训练用时12.927秒，平均累积奖励为-209.727
# 更新old网络
# 第1091轮训练用时12.869秒，平均累积奖励为-215.095
# 第1092轮训练用时13.082秒，平均累积奖励为-213.658
# 更新old网络
# 第1093轮训练用时12.853秒，平均累积奖励为-213.499
# 第1094轮训练用时12.982秒，平均累积奖励为-209.500
# 更新old网络
# 第1095轮训练用时13.177秒，平均累积奖励为-217.501
# 第1096轮训练用时12.996秒，平均累积奖励为-215.312
# 更新old网络
# 第1097轮训练用时12.970秒，平均累积奖励为-209.411
# 第1098轮训练用时12.895秒，平均累积奖励为-208.523
# 更新old网络
# 第1099轮训练用时13.081秒，平均累积奖励为-209.043
# 第1100轮训练用时13.019秒，平均累积奖励为-211.251
# 更新old网络
# 第1101轮训练用时12.923秒，平均累积奖励为-218.109
# 第1102轮训练用时13.152秒，平均累积奖励为-213.313
# 更新old网络
# 第1103轮训练用时13.047秒，平均累积奖励为-212.000
# 第1104轮训练用时13.050秒，平均累积奖励为-216.625
# 更新old网络
# 第1105轮训练用时12.980秒，平均累积奖励为-213.156
# 第1106轮训练用时12.931秒，平均累积奖励为-213.982
# 更新old网络
# 第1107轮训练用时13.215秒，平均累积奖励为-216.429
# 第1108轮训练用时12.951秒，平均累积奖励为-211.910
# 更新old网络
# 第1109轮训练用时12.966秒，平均累积奖励为-213.302
# 第1110轮训练用时12.875秒，平均累积奖励为-218.842
# 更新old网络
# 第1111轮训练用时13.119秒，平均累积奖励为-214.540
# 第1112轮训练用时12.879秒，平均累积奖励为-215.842
# 更新old网络
# 第1113轮训练用时13.093秒，平均累积奖励为-213.571
# 第1114轮训练用时13.029秒，平均累积奖励为-213.627
# 更新old网络
# 第1115轮训练用时13.022秒，平均累积奖励为-214.351
# 第1116轮训练用时12.999秒，平均累积奖励为-223.979
# 更新old网络
# 第1117轮训练用时12.965秒，平均累积奖励为-216.104
# 第1118轮训练用时13.108秒，平均累积奖励为-217.369
# 更新old网络
# 第1119轮训练用时13.043秒，平均累积奖励为-217.973
# 第1120轮训练用时13.083秒，平均累积奖励为-214.659
# 更新old网络
# 第1121轮训练用时12.969秒，平均累积奖励为-211.673
# 第1122轮训练用时13.003秒，平均累积奖励为-213.792
# 更新old网络
# 第1123轮训练用时12.971秒，平均累积奖励为-211.540
# 第1124轮训练用时12.918秒，平均累积奖励为-213.390
# 更新old网络
# 第1125轮训练用时12.968秒，平均累积奖励为-216.002
# 第1126轮训练用时13.095秒，平均累积奖励为-212.700
# 更新old网络
# 第1127轮训练用时13.038秒，平均累积奖励为-210.801
# 第1128轮训练用时13.055秒，平均累积奖励为-216.555
# 更新old网络
# 第1129轮训练用时13.024秒，平均累积奖励为-212.465
# 第1130轮训练用时13.133秒，平均累积奖励为-213.081
# 更新old网络
# 第1131轮训练用时13.059秒，平均累积奖励为-213.938
# 第1132轮训练用时13.134秒，平均累积奖励为-213.769
# 更新old网络
# 第1133轮训练用时13.019秒，平均累积奖励为-214.721
# 第1134轮训练用时13.000秒，平均累积奖励为-213.794
# 更新old网络
# 第1135轮训练用时13.053秒，平均累积奖励为-215.828
# 第1136轮训练用时12.951秒，平均累积奖励为-216.196
# 更新old网络
# 第1137轮训练用时13.030秒，平均累积奖励为-210.638
# 第1138轮训练用时13.008秒，平均累积奖励为-214.692
# 更新old网络
# 第1139轮训练用时12.803秒，平均累积奖励为-216.102
# 第1140轮训练用时13.054秒，平均累积奖励为-216.607
# 更新old网络
# 第1141轮训练用时13.008秒，平均累积奖励为-215.435
# 第1142轮训练用时13.063秒，平均累积奖励为-213.317
# 更新old网络
# 第1143轮训练用时12.850秒，平均累积奖励为-218.214
# 第1144轮训练用时13.053秒，平均累积奖励为-213.075
# 更新old网络
# 第1145轮训练用时13.348秒，平均累积奖励为-214.478
# 第1146轮训练用时13.148秒，平均累积奖励为-216.561
# 更新old网络
# 第1147轮训练用时12.936秒，平均累积奖励为-214.007
# 第1148轮训练用时12.988秒，平均累积奖励为-215.400
# 更新old网络
# 第1149轮训练用时13.185秒，平均累积奖励为-210.790
# 第1150轮训练用时13.057秒，平均累积奖励为-212.537
# 更新old网络
# 第1151轮训练用时12.984秒，平均累积奖励为-215.118
# 第1152轮训练用时12.991秒，平均累积奖励为-212.979
# 更新old网络
# 第1153轮训练用时12.933秒，平均累积奖励为-215.687
# 第1154轮训练用时12.964秒，平均累积奖励为-214.880
# 更新old网络
# 第1155轮训练用时13.056秒，平均累积奖励为-212.678
# 第1156轮训练用时12.935秒，平均累积奖励为-212.533
# 更新old网络
# 第1157轮训练用时12.820秒，平均累积奖励为-213.870
# 第1158轮训练用时12.982秒，平均累积奖励为-215.544
# 更新old网络
# 第1159轮训练用时13.012秒，平均累积奖励为-212.015
# 第1160轮训练用时12.962秒，平均累积奖励为-216.281
# 更新old网络
# 第1161轮训练用时13.119秒，平均累积奖励为-212.061
# 第1162轮训练用时13.033秒，平均累积奖励为-216.143
# 更新old网络
# 第1163轮训练用时12.899秒，平均累积奖励为-217.631
# 第1164轮训练用时13.058秒，平均累积奖励为-213.525
# 更新old网络
# 第1165轮训练用时12.993秒，平均累积奖励为-209.166
# 第1166轮训练用时13.147秒，平均累积奖励为-212.989
# 更新old网络
# 第1167轮训练用时12.863秒，平均累积奖励为-212.937
# 第1168轮训练用时12.951秒，平均累积奖励为-211.515
# 更新old网络
# 第1169轮训练用时13.074秒，平均累积奖励为-211.090
# 第1170轮训练用时13.087秒，平均累积奖励为-212.939
# 更新old网络
# 第1171轮训练用时13.053秒，平均累积奖励为-215.292
# 第1172轮训练用时12.852秒，平均累积奖励为-217.995
# 更新old网络
# 第1173轮训练用时13.062秒，平均累积奖励为-210.818
# 第1174轮训练用时12.968秒，平均累积奖励为-214.501
# 更新old网络
# 第1175轮训练用时13.082秒，平均累积奖励为-215.423
# 第1176轮训练用时12.867秒，平均累积奖励为-212.135
# 更新old网络
# 第1177轮训练用时13.038秒，平均累积奖励为-214.580
# 第1178轮训练用时12.942秒，平均累积奖励为-210.905
# 更新old网络
# 第1179轮训练用时12.970秒，平均累积奖励为-211.778
# 第1180轮训练用时12.894秒，平均累积奖励为-215.349
# 更新old网络
# 第1181轮训练用时13.129秒，平均累积奖励为-215.280
# 第1182轮训练用时12.845秒，平均累积奖励为-211.804
# 更新old网络
# 第1183轮训练用时13.034秒，平均累积奖励为-213.776
# 第1184轮训练用时13.032秒，平均累积奖励为-214.183
# 更新old网络
# 第1185轮训练用时12.926秒，平均累积奖励为-218.031
# 第1186轮训练用时12.959秒，平均累积奖励为-211.309
# 更新old网络
# 第1187轮训练用时12.979秒，平均累积奖励为-211.334
# 第1188轮训练用时12.829秒，平均累积奖励为-214.634
# 更新old网络
# 第1189轮训练用时12.912秒，平均累积奖励为-214.182
# 第1190轮训练用时12.929秒，平均累积奖励为-211.974
# 更新old网络
# 第1191轮训练用时13.075秒，平均累积奖励为-211.922
# 第1192轮训练用时13.027秒，平均累积奖励为-215.702
# 更新old网络
# 第1193轮训练用时12.821秒，平均累积奖励为-216.587
# 第1194轮训练用时12.922秒，平均累积奖励为-213.239
# 更新old网络
# 第1195轮训练用时12.990秒，平均累积奖励为-211.865
# 第1196轮训练用时12.969秒，平均累积奖励为-213.905
# 更新old网络
# 第1197轮训练用时13.013秒，平均累积奖励为-213.976
# 第1198轮训练用时12.860秒，平均累积奖励为-211.400
# 更新old网络
# 第1199轮训练用时12.884秒，平均累积奖励为-215.447
# 第1200轮训练用时12.895秒，平均累积奖励为-213.980
# 更新old网络
# 第1201轮训练用时12.957秒，平均累积奖励为-211.448
# 第1202轮训练用时13.071秒，平均累积奖励为-214.052
# 更新old网络
# 第1203轮训练用时12.951秒，平均累积奖励为-214.529
# 第1204轮训练用时12.799秒，平均累积奖励为-213.955
# 更新old网络
# 第1205轮训练用时12.999秒，平均累积奖励为-215.923
# 第1206轮训练用时12.953秒，平均累积奖励为-212.901
# 更新old网络
# 第1207轮训练用时13.125秒，平均累积奖励为-214.023
# 第1208轮训练用时12.966秒，平均累积奖励为-218.783
# 更新old网络
# 第1209轮训练用时12.903秒，平均累积奖励为-213.404
# 第1210轮训练用时12.937秒，平均累积奖励为-213.019
# 更新old网络
# 第1211轮训练用时12.935秒，平均累积奖励为-217.757
# 第1212轮训练用时12.799秒，平均累积奖励为-214.121
# 更新old网络
# 第1213轮训练用时12.913秒，平均累积奖励为-215.997
# 第1214轮训练用时12.891秒，平均累积奖励为-218.564
# 更新old网络
# 第1215轮训练用时12.902秒，平均累积奖励为-214.082
# 第1216轮训练用时12.795秒，平均累积奖励为-212.749
# 更新old网络
# 第1217轮训练用时12.946秒，平均累积奖励为-218.452
# 第1218轮训练用时12.981秒，平均累积奖励为-213.300
# 更新old网络
# 第1219轮训练用时12.928秒，平均累积奖励为-216.137
# 第1220轮训练用时13.007秒，平均累积奖励为-214.492
# 更新old网络
# 第1221轮训练用时12.983秒，平均累积奖励为-215.230
# 第1222轮训练用时12.842秒，平均累积奖励为-208.880
# 更新old网络
# 第1223轮训练用时12.835秒，平均累积奖励为-212.644
# 第1224轮训练用时13.109秒，平均累积奖励为-211.343
# 更新old网络
# 第1225轮训练用时13.063秒，平均累积奖励为-214.799
# 第1226轮训练用时12.978秒，平均累积奖励为-213.103
# 更新old网络
# 第1227轮训练用时12.912秒，平均累积奖励为-214.497
# 第1228轮训练用时13.023秒，平均累积奖励为-215.366
# 更新old网络
# 第1229轮训练用时13.021秒，平均累积奖励为-214.541
# 第1230轮训练用时12.873秒，平均累积奖励为-209.800
# 更新old网络
# 第1231轮训练用时12.822秒，平均累积奖励为-212.190
# 第1232轮训练用时12.976秒，平均累积奖励为-217.025
# 更新old网络
# 第1233轮训练用时13.190秒，平均累积奖励为-218.283
# 第1234轮训练用时12.947秒，平均累积奖励为-214.000
# 更新old网络
# 第1235轮训练用时12.937秒，平均累积奖励为-214.791
# 第1236轮训练用时12.876秒，平均累积奖励为-217.346
# 更新old网络
# 第1237轮训练用时12.902秒，平均累积奖励为-215.723
# 第1238轮训练用时13.154秒，平均累积奖励为-212.986
# 更新old网络
# 第1239轮训练用时12.966秒，平均累积奖励为-214.068
# 第1240轮训练用时12.819秒，平均累积奖励为-217.695
# 更新old网络
# 第1241轮训练用时12.875秒，平均累积奖励为-217.675
# 第1242轮训练用时12.910秒，平均累积奖励为-217.128
# 更新old网络
# 第1243轮训练用时12.945秒，平均累积奖励为-213.480
# 第1244轮训练用时13.091秒，平均累积奖励为-216.798
# 更新old网络
# 第1245轮训练用时12.953秒，平均累积奖励为-219.369
# 第1246轮训练用时13.048秒，平均累积奖励为-213.565
# 更新old网络
# 第1247轮训练用时13.040秒，平均累积奖励为-216.242
# 第1248轮训练用时13.108秒，平均累积奖励为-214.599
# 更新old网络
# 第1249轮训练用时13.041秒，平均累积奖励为-214.844
# 第1250轮训练用时13.015秒，平均累积奖励为-217.885
# 更新old网络
# 第1251轮训练用时12.940秒，平均累积奖励为-218.672
# 第1252轮训练用时12.818秒，平均累积奖励为-214.851
# 更新old网络
# 第1253轮训练用时12.829秒，平均累积奖励为-214.968
# 第1254轮训练用时12.952秒，平均累积奖励为-215.330
# 更新old网络
# 第1255轮训练用时12.965秒，平均累积奖励为-211.619
# 第1256轮训练用时12.855秒，平均累积奖励为-219.105
# 更新old网络
# 第1257轮训练用时12.870秒，平均累积奖励为-215.263
# 第1258轮训练用时13.170秒，平均累积奖励为-217.698
# 更新old网络
# 第1259轮训练用时12.907秒，平均累积奖励为-218.569
# 第1260轮训练用时12.950秒，平均累积奖励为-218.864
# 更新old网络
# ...
# 第2580轮训练用时13.267秒，平均累积奖励为-218.161
# 更新old网络
# 第2581轮训练用时13.117秒，平均累积奖励为-220.408
# 第2582轮训练用时13.117秒，平均累积奖励为-218.414
# 更新old网络
# 第2583轮训练用时13.238秒，平均累积奖励为-221.619
# 第2584轮训练用时13.111秒，平均累积奖励为-217.474
# 更新old网络
# 第2585轮训练用时13.228秒，平均累积奖励为-220.198
# 第2586轮训练用时13.220秒，平均累积奖励为-219.761
# 更新old网络
# 第2587轮训练用时13.060秒，平均累积奖励为-219.322
# 第2588轮训练用时13.210秒，平均累积奖励为-221.943
# 更新old网络
# 第2589轮训练用时13.215秒，平均累积奖励为-223.311
# 第2590轮训练用时13.050秒，平均累积奖励为-217.050
# 更新old网络
# 第2591轮训练用时12.952秒，平均累积奖励为-217.617
# 第2592轮训练用时13.156秒，平均累积奖励为-218.601
# 更新old网络
# 第2593轮训练用时13.083秒，平均累积奖励为-221.044
# 第2594轮训练用时13.023秒，平均累积奖励为-220.305
# 更新old网络
# 第2595轮训练用时13.126秒，平均累积奖励为-215.450
# 第2596轮训练用时13.036秒，平均累积奖励为-218.376
# 更新old网络
# 第2597轮训练用时12.951秒，平均累积奖励为-220.924
# 第2598轮训练用时13.060秒，平均累积奖励为-220.670
# 更新old网络
# 第2599轮训练用时12.935秒，平均累积奖励为-218.352
# 第2600轮训练用时13.047秒，平均累积奖励为-223.923
# 更新old网络
# 第2601轮训练用时12.983秒，平均累积奖励为-222.725
# 第2602轮训练用时13.030秒，平均累积奖励为-215.052
# 更新old网络
# 第2603轮训练用时12.960秒，平均累积奖励为-219.064
# 第2604轮训练用时13.108秒，平均累积奖励为-223.451
# 更新old网络
# 第2605轮训练用时12.948秒，平均累积奖励为-219.210
# 第2606轮训练用时12.925秒，平均累积奖励为-221.365
# 更新old网络
# 第2607轮训练用时13.013秒，平均累积奖励为-224.413
# 第2608轮训练用时12.930秒，平均累积奖励为-219.749
# 更新old网络
# 第2609轮训练用时12.948秒，平均累积奖励为-219.523
# 第2610轮训练用时12.923秒，平均累积奖励为-224.227
# 更新old网络
# 第2611轮训练用时13.029秒，平均累积奖励为-220.814
# 第2612轮训练用时13.118秒，平均累积奖励为-219.202
# 更新old网络
# 第2613轮训练用时13.107秒，平均累积奖励为-220.716
# 第2614轮训练用时12.992秒，平均累积奖励为-220.205
# 更新old网络
# 第2615轮训练用时13.037秒，平均累积奖励为-217.467
# 第2616轮训练用时12.941秒，平均累积奖励为-219.568
# 更新old网络
# 第2617轮训练用时12.855秒，平均累积奖励为-220.246
# 第2618轮训练用时13.051秒，平均累积奖励为-221.127
# 更新old网络
# 第2619轮训练用时12.980秒，平均累积奖励为-221.367
# 第2620轮训练用时13.113秒，平均累积奖励为-218.986
# 更新old网络
# 第2621轮训练用时12.986秒，平均累积奖励为-217.978
# 第2622轮训练用时13.048秒，平均累积奖励为-222.609
# 更新old网络
# 第2623轮训练用时12.990秒，平均累积奖励为-215.894
# 第2624轮训练用时13.094秒，平均累积奖励为-223.109
# 更新old网络
# 第2625轮训练用时12.994秒，平均累积奖励为-221.560
# 第2626轮训练用时12.968秒，平均累积奖励为-222.605
# 更新old网络
# 第2627轮训练用时13.034秒，平均累积奖励为-220.692
# 第2628轮训练用时13.002秒，平均累积奖励为-221.906
# 更新old网络
# 第2629轮训练用时13.187秒，平均累积奖励为-220.931
# 第2630轮训练用时12.989秒，平均累积奖励为-224.220
# 更新old网络
# 第2631轮训练用时13.020秒，平均累积奖励为-225.995
# 第2632轮训练用时12.975秒，平均累积奖励为-223.396
# 更新old网络
# 第2633轮训练用时13.026秒，平均累积奖励为-224.302
# 第2634轮训练用时13.017秒，平均累积奖励为-223.461
# 更新old网络
# 第2635轮训练用时13.054秒，平均累积奖励为-224.897
# 第2636轮训练用时13.041秒，平均累积奖励为-224.579
# 更新old网络
# 第2637轮训练用时12.998秒，平均累积奖励为-226.295
# 第2638轮训练用时12.988秒，平均累积奖励为-222.630
# 更新old网络
# 第2639轮训练用时12.937秒，平均累积奖励为-220.711
# 第2640轮训练用时13.009秒，平均累积奖励为-226.545
# 更新old网络
# 第2641轮训练用时13.018秒，平均累积奖励为-223.549
# 第2642轮训练用时13.150秒，平均累积奖励为-223.067
# 更新old网络
# 第2643轮训练用时13.022秒，平均累积奖励为-219.111
# 第2644轮训练用时13.055秒，平均累积奖励为-222.459
# 更新old网络
# 第2645轮训练用时13.001秒，平均累积奖励为-222.065
# 第2646轮训练用时12.971秒，平均累积奖励为-220.570
# 更新old网络
# 第2647轮训练用时13.065秒，平均累积奖励为-220.412
# 第2648轮训练用时13.015秒，平均累积奖励为-220.181
# 更新old网络
# 第2649轮训练用时12.941秒，平均累积奖励为-223.233
# 第2650轮训练用时13.053秒，平均累积奖励为-223.714
# 更新old网络
# 第2651轮训练用时12.974秒，平均累积奖励为-222.580
# 第2652轮训练用时13.067秒，平均累积奖励为-224.152
# 更新old网络
# 第2653轮训练用时13.017秒，平均累积奖励为-219.961
# 第2654轮训练用时12.950秒，平均累积奖励为-222.479
# 更新old网络
# 第2655轮训练用时12.934秒，平均累积奖励为-221.550
# 第2656轮训练用时12.976秒，平均累积奖励为-227.742
# 更新old网络
# 第2657轮训练用时13.005秒，平均累积奖励为-221.225
# 第2658轮训练用时12.990秒，平均累积奖励为-222.744
# 更新old网络
# 第2659轮训练用时12.847秒，平均累积奖励为-221.953
# 第2660轮训练用时12.976秒，平均累积奖励为-222.964
# 更新old网络
# 第2661轮训练用时12.924秒，平均累积奖励为-224.008
# 第2662轮训练用时12.931秒，平均累积奖励为-221.210
# 更新old网络
# 第2663轮训练用时12.898秒，平均累积奖励为-222.294
# 第2664轮训练用时12.892秒，平均累积奖励为-219.628
# 更新old网络
# 第2665轮训练用时13.030秒，平均累积奖励为-219.451
# 第2666轮训练用时12.892秒，平均累积奖励为-221.367
# 更新old网络
# 第2667轮训练用时13.139秒，平均累积奖励为-226.647
# 第2668轮训练用时12.926秒，平均累积奖励为-222.685
# 更新old网络
# 第2669轮训练用时12.919秒，平均累积奖励为-220.915
# 第2670轮训练用时12.980秒，平均累积奖励为-221.104
# 更新old网络
# 第2671轮训练用时13.011秒，平均累积奖励为-219.964
# 第2672轮训练用时12.973秒，平均累积奖励为-220.036
# 更新old网络
# 第2673轮训练用时13.087秒，平均累积奖励为-222.988
# 第2674轮训练用时13.125秒，平均累积奖励为-220.515
# 更新old网络
# 第2675轮训练用时12.992秒，平均累积奖励为-225.013
# 第2676轮训练用时12.999秒，平均累积奖励为-219.500
# 更新old网络
# 第2677轮训练用时13.107秒，平均累积奖励为-219.890
# 第2678轮训练用时13.061秒，平均累积奖励为-222.218
# 更新old网络
# 第2679轮训练用时13.019秒，平均累积奖励为-224.122
# 第2680轮训练用时13.013秒，平均累积奖励为-221.806
# 更新old网络
# 第2681轮训练用时13.018秒，平均累积奖励为-224.327
# 第2682轮训练用时13.199秒，平均累积奖励为-223.313
# 更新old网络
# 第2683轮训练用时13.088秒，平均累积奖励为-217.083
# 第2684轮训练用时13.044秒，平均累积奖励为-220.166
# 更新old网络
# 第2685轮训练用时13.078秒，平均累积奖励为-225.123
# 第2686轮训练用时12.888秒，平均累积奖励为-222.092
# 更新old网络
# 第2687轮训练用时12.908秒，平均累积奖励为-221.042
# 第2688轮训练用时13.130秒，平均累积奖励为-222.325
# 更新old网络
# 第2689轮训练用时12.893秒，平均累积奖励为-223.081
# 第2690轮训练用时13.106秒，平均累积奖励为-228.623
# 更新old网络
# 第2691轮训练用时13.025秒，平均累积奖励为-225.158
# 第2692轮训练用时12.945秒，平均累积奖励为-223.992
# 更新old网络
# 第2693轮训练用时12.957秒，平均累积奖励为-224.121
# 第2694轮训练用时13.014秒，平均累积奖励为-224.209
# 更新old网络
# 第2695轮训练用时12.993秒，平均累积奖励为-221.106
# 第2696轮训练用时12.954秒，平均累积奖励为-220.423
# 更新old网络
# 第2697轮训练用时12.902秒，平均累积奖励为-223.735
# 第2698轮训练用时12.899秒，平均累积奖励为-221.237
# 更新old网络
# 第2699轮训练用时13.041秒，平均累积奖励为-217.908
# 第2700轮训练用时12.951秒，平均累积奖励为-220.877
# 更新old网络
# 第2701轮训练用时12.960秒，平均累积奖励为-222.965
# 第2702轮训练用时13.012秒，平均累积奖励为-225.935
# 更新old网络
# 第2703轮训练用时13.089秒，平均累积奖励为-222.414
# 第2704轮训练用时13.077秒，平均累积奖励为-222.943
# 更新old网络
# 第2705轮训练用时12.939秒，平均累积奖励为-220.716
# 第2706轮训练用时13.011秒，平均累积奖励为-225.272
# 更新old网络
# 第2707轮训练用时13.035秒，平均累积奖励为-221.172
# 第2708轮训练用时13.036秒，平均累积奖励为-218.625
# 更新old网络
# 第2709轮训练用时13.071秒，平均累积奖励为-222.224
# 第2710轮训练用时13.072秒，平均累积奖励为-224.262
# 更新old网络
# 第2711轮训练用时13.146秒，平均累积奖励为-218.356
# 第2712轮训练用时12.980秒，平均累积奖励为-219.754
# 更新old网络
# 第2713轮训练用时12.995秒，平均累积奖励为-218.788
# 第2714轮训练用时12.896秒，平均累积奖励为-220.618
# 更新old网络
# 第2715轮训练用时12.934秒，平均累积奖励为-215.170
# 第2716轮训练用时13.053秒，平均累积奖励为-219.180
# 更新old网络
# 第2717轮训练用时13.066秒，平均累积奖励为-224.665
# 第2718轮训练用时12.991秒，平均累积奖励为-225.289
# 更新old网络
# 第2719轮训练用时13.022秒，平均累积奖励为-221.941
# 第2720轮训练用时12.867秒，平均累积奖励为-222.213
# 更新old网络
# 第2721轮训练用时12.950秒，平均累积奖励为-225.002
# 第2722轮训练用时12.852秒，平均累积奖励为-220.653
# 更新old网络
# 第2723轮训练用时12.934秒，平均累积奖励为-218.906
# 第2724轮训练用时12.959秒，平均累积奖励为-219.987
# 更新old网络
# 第2725轮训练用时12.893秒，平均累积奖励为-225.085
# 第2726轮训练用时12.978秒，平均累积奖励为-217.933
# 更新old网络
# 第2727轮训练用时13.076秒，平均累积奖励为-219.456
# 第2728轮训练用时13.045秒，平均累积奖励为-216.505
# 更新old网络
# 第2729轮训练用时13.037秒，平均累积奖励为-220.359
# 第2730轮训练用时12.897秒，平均累积奖励为-223.158
# 更新old网络
# 第2731轮训练用时12.829秒，平均累积奖励为-222.214
# 第2732轮训练用时13.012秒，平均累积奖励为-216.600
# 更新old网络
# 第2733轮训练用时12.993秒，平均累积奖励为-222.749
# 第2734轮训练用时12.912秒，平均累积奖励为-220.053
# 更新old网络
# 第2735轮训练用时12.943秒，平均累积奖励为-218.548
# 第2736轮训练用时12.954秒，平均累积奖励为-219.375
# 更新old网络
# 第2737轮训练用时12.885秒，平均累积奖励为-220.812
# 第2738轮训练用时12.998秒，平均累积奖励为-220.152
# 更新old网络
# 第2739轮训练用时12.892秒，平均累积奖励为-216.888
# 第2740轮训练用时13.003秒，平均累积奖励为-218.566
# 更新old网络
# 第2741轮训练用时12.979秒，平均累积奖励为-222.434
# 第2742轮训练用时12.996秒，平均累积奖励为-219.184
# 更新old网络
# 第2743轮训练用时12.984秒，平均累积奖励为-221.271
# 第2744轮训练用时12.936秒，平均累积奖励为-222.252
# 更新old网络
# 第2745轮训练用时13.032秒，平均累积奖励为-217.455
# 第2746轮训练用时12.852秒，平均累积奖励为-223.850
# 更新old网络
# 第2747轮训练用时12.996秒，平均累积奖励为-214.874
# 第2748轮训练用时12.994秒，平均累积奖励为-214.205
# 更新old网络
# 第2749轮训练用时12.944秒，平均累积奖励为-219.361
# 第2750轮训练用时13.049秒，平均累积奖励为-219.117
# 更新old网络
# 第2751轮训练用时12.973秒，平均累积奖励为-220.695
# 第2752轮训练用时13.034秒，平均累积奖励为-222.774
# 更新old网络
# 第2753轮训练用时12.912秒，平均累积奖励为-222.308
# 第2754轮训练用时13.065秒，平均累积奖励为-223.523
# 更新old网络
# 第2755轮训练用时13.161秒，平均累积奖励为-219.430
# 第2756轮训练用时13.001秒，平均累积奖励为-218.167
# 更新old网络
# 第2757轮训练用时13.204秒，平均累积奖励为-217.084
# 第2758轮训练用时12.940秒，平均累积奖励为-221.487
# 更新old网络
# 第2759轮训练用时12.922秒，平均累积奖励为-221.614
# 第2760轮训练用时12.930秒，平均累积奖励为-221.114
# 更新old网络
# 第2761轮训练用时13.015秒，平均累积奖励为-215.689
# 第2762轮训练用时13.063秒，平均累积奖励为-219.008
# 更新old网络
# 第2763轮训练用时12.970秒，平均累积奖励为-218.584
# 第2764轮训练用时12.963秒，平均累积奖励为-220.870
# 更新old网络
# 第2765轮训练用时12.992秒，平均累积奖励为-217.850
# 第2766轮训练用时13.049秒，平均累积奖励为-219.742
# 更新old网络
# 第2767轮训练用时12.911秒，平均累积奖励为-220.876
# 第2768轮训练用时13.040秒，平均累积奖励为-217.916
# 更新old网络
# 第2769轮训练用时13.067秒，平均累积奖励为-215.387
# 第2770轮训练用时13.011秒，平均累积奖励为-219.410
# 更新old网络
# 第2771轮训练用时12.998秒，平均累积奖励为-223.220
# 第2772轮训练用时12.950秒，平均累积奖励为-216.886
# 更新old网络
# 第2773轮训练用时13.038秒，平均累积奖励为-218.109
# 第2774轮训练用时13.080秒，平均累积奖励为-223.735
# 更新old网络
# 第2775轮训练用时12.985秒，平均累积奖励为-217.000
# 第2776轮训练用时12.982秒，平均累积奖励为-217.538
# 更新old网络
# 第2777轮训练用时13.002秒，平均累积奖励为-217.570
# 第2778轮训练用时12.978秒，平均累积奖励为-221.110
# 更新old网络
# 第2779轮训练用时12.957秒，平均累积奖励为-220.960
# 第2780轮训练用时12.884秒，平均累积奖励为-217.656
# 更新old网络
# 第2781轮训练用时13.063秒，平均累积奖励为-222.223
# 第2782轮训练用时12.966秒，平均累积奖励为-221.765
# 更新old网络
# 第2783轮训练用时13.052秒，平均累积奖励为-216.375
# 第2784轮训练用时13.148秒，平均累积奖励为-220.534
# 更新old网络
# 第2785轮训练用时13.144秒，平均累积奖励为-219.387
# 第2786轮训练用时13.005秒，平均累积奖励为-219.307
# 更新old网络
# 第2787轮训练用时13.075秒，平均累积奖励为-219.612
# 第2788轮训练用时13.063秒，平均累积奖励为-218.347
# 更新old网络
# 第2789轮训练用时13.050秒，平均累积奖励为-218.582
# 第2790轮训练用时12.862秒，平均累积奖励为-223.773
# 更新old网络
# 第2791轮训练用时13.090秒，平均累积奖励为-222.651
# 第2792轮训练用时13.054秒，平均累积奖励为-222.063
# 更新old网络
# 第2793轮训练用时12.985秒，平均累积奖励为-220.549
# 第2794轮训练用时13.062秒，平均累积奖励为-220.661
# 更新old网络
# 第2795轮训练用时13.016秒，平均累积奖励为-219.909
# 第2796轮训练用时12.989秒，平均累积奖励为-214.548
# 更新old网络
# 第2797轮训练用时12.981秒，平均累积奖励为-216.708
# 第2798轮训练用时12.966秒，平均累积奖励为-220.043
# 更新old网络
# 第2799轮训练用时13.016秒，平均累积奖励为-221.266
# 第2800轮训练用时12.927秒，平均累积奖励为-224.312
# 更新old网络
# 第2801轮训练用时13.032秒，平均累积奖励为-220.207
# 第2802轮训练用时12.942秒，平均累积奖励为-217.233
# 更新old网络
# 第2803轮训练用时12.868秒，平均累积奖励为-214.799
# 第2804轮训练用时13.025秒，平均累积奖励为-226.132
# 更新old网络
# 第2805轮训练用时13.086秒，平均累积奖励为-220.132
# 第2806轮训练用时13.077秒，平均累积奖励为-221.031
# 更新old网络
# 第2807轮训练用时12.905秒，平均累积奖励为-221.634
# 第2808轮训练用时13.091秒，平均累积奖励为-220.663
# 更新old网络
# 第2809轮训练用时12.976秒，平均累积奖励为-221.646
# 第2810轮训练用时13.001秒，平均累积奖励为-218.274
# 更新old网络
# 第2811轮训练用时12.902秒，平均累积奖励为-223.231
# 第2812轮训练用时12.993秒，平均累积奖励为-219.517
# 更新old网络
# 第2813轮训练用时12.966秒，平均累积奖励为-222.282
# 第2814轮训练用时12.966秒，平均累积奖励为-221.103
# 更新old网络
# 第2815轮训练用时13.015秒，平均累积奖励为-220.634
# 第2816轮训练用时13.120秒，平均累积奖励为-223.954
# 更新old网络
# 第2817轮训练用时12.956秒，平均累积奖励为-221.062
# 第2818轮训练用时12.992秒，平均累积奖励为-219.810
# 更新old网络
# 第2819轮训练用时13.121秒，平均累积奖励为-223.876
# 第2820轮训练用时13.034秒，平均累积奖励为-214.899
# 更新old网络
# 第2821轮训练用时13.022秒，平均累积奖励为-218.147
# 第2822轮训练用时13.097秒，平均累积奖励为-219.600
# 更新old网络
# 第2823轮训练用时13.026秒，平均累积奖励为-219.834
# 第2824轮训练用时12.857秒，平均累积奖励为-218.440
# 更新old网络
# 第2825轮训练用时13.100秒，平均累积奖励为-217.602
# 第2826轮训练用时13.007秒，平均累积奖励为-221.120
# 更新old网络
# 第2827轮训练用时12.931秒，平均累积奖励为-217.950
# 第2828轮训练用时12.975秒，平均累积奖励为-218.009
# 更新old网络
# 第2829轮训练用时12.953秒，平均累积奖励为-222.351
# 第2830轮训练用时12.942秒，平均累积奖励为-219.422
# 更新old网络
# 第2831轮训练用时12.984秒，平均累积奖励为-214.995
# 第2832轮训练用时12.985秒，平均累积奖励为-215.894
# 更新old网络
# 第2833轮训练用时12.992秒，平均累积奖励为-221.936
# 第2834轮训练用时12.901秒，平均累积奖励为-217.151
# 更新old网络
# 第2835轮训练用时13.046秒，平均累积奖励为-220.430
# 第2836轮训练用时12.877秒，平均累积奖励为-219.809
# 更新old网络
# 第2837轮训练用时13.056秒，平均累积奖励为-216.314
# 第2838轮训练用时13.016秒，平均累积奖励为-219.611
# 更新old网络
# 第2839轮训练用时13.022秒，平均累积奖励为-220.634
# 第2840轮训练用时12.966秒，平均累积奖励为-215.923
# 更新old网络
# 第2841轮训练用时13.022秒，平均累积奖励为-212.671
# 第2842轮训练用时12.997秒，平均累积奖励为-220.986
# 更新old网络
# 第2843轮训练用时13.019秒，平均累积奖励为-219.758
# 第2844轮训练用时12.975秒，平均累积奖励为-217.171
# 更新old网络
# 第2845轮训练用时12.987秒，平均累积奖励为-213.449
# 第2846轮训练用时13.051秒，平均累积奖励为-218.638
# 更新old网络
# 第2847轮训练用时13.027秒，平均累积奖励为-216.973
# 第2848轮训练用时13.042秒，平均累积奖励为-219.505
# 更新old网络
# 第2849轮训练用时12.972秒，平均累积奖励为-218.646
# 第2850轮训练用时12.972秒，平均累积奖励为-219.305
# 更新old网络
# 第2851轮训练用时12.975秒，平均累积奖励为-212.097
# 第2852轮训练用时13.045秒，平均累积奖励为-215.229
# 更新old网络
# 第2853轮训练用时13.073秒，平均累积奖励为-217.792
# 第2854轮训练用时12.931秒，平均累积奖励为-216.886
# 更新old网络
# 第2855轮训练用时12.879秒，平均累积奖励为-214.095
# 第2856轮训练用时12.992秒，平均累积奖励为-215.758
# 更新old网络
# 第2857轮训练用时12.982秒，平均累积奖励为-215.631
# 第2858轮训练用时12.966秒，平均累积奖励为-212.998
# 更新old网络
# 第2859轮训练用时13.023秒，平均累积奖励为-213.019
# 第2860轮训练用时12.923秒，平均累积奖励为-211.844
# 更新old网络
# 第2861轮训练用时13.027秒，平均累积奖励为-212.921
# 第2862轮训练用时13.031秒，平均累积奖励为-216.037
# 更新old网络
# 第2863轮训练用时12.916秒，平均累积奖励为-214.782
# 第2864轮训练用时12.872秒，平均累积奖励为-211.018
# 更新old网络
# 第2865轮训练用时12.950秒，平均累积奖励为-210.147
# 第2866轮训练用时12.961秒，平均累积奖励为-215.024
# 更新old网络
# 第2867轮训练用时12.968秒，平均累积奖励为-213.579
# 第2868轮训练用时12.930秒，平均累积奖励为-213.694
# 更新old网络
# 第2869轮训练用时12.972秒，平均累积奖励为-213.622
# 第2870轮训练用时13.006秒，平均累积奖励为-215.840
# 更新old网络
# 第2871轮训练用时12.927秒，平均累积奖励为-213.493
# 第2872轮训练用时13.031秒，平均累积奖励为-214.174
# 更新old网络
# 第2873轮训练用时13.052秒，平均累积奖励为-215.932
# 第2874轮训练用时13.019秒，平均累积奖励为-210.699
# 更新old网络
# 第2875轮训练用时13.079秒，平均累积奖励为-216.651
# 第2876轮训练用时12.975秒，平均累积奖励为-208.861
# 更新old网络
# 第2877轮训练用时12.993秒，平均累积奖励为-208.515
# 第2878轮训练用时12.884秒，平均累积奖励为-214.361
# 更新old网络
# 第2879轮训练用时13.054秒，平均累积奖励为-211.501
# 第2880轮训练用时12.992秒，平均累积奖励为-212.633
# 更新old网络
# 第2881轮训练用时13.006秒，平均累积奖励为-215.560
# 第2882轮训练用时13.017秒，平均累积奖励为-215.667
# 更新old网络
# 第2883轮训练用时13.004秒，平均累积奖励为-211.510
# 第2884轮训练用时12.979秒，平均累积奖励为-216.448
# 更新old网络
# 第2885轮训练用时12.975秒，平均累积奖励为-212.485
# 第2886轮训练用时12.885秒，平均累积奖励为-212.295
# 更新old网络
# 第2887轮训练用时13.181秒，平均累积奖励为-209.775
# 第2888轮训练用时12.980秒，平均累积奖励为-217.993
# 更新old网络
# 第2889轮训练用时12.937秒，平均累积奖励为-215.959
# 第2890轮训练用时12.976秒，平均累积奖励为-210.036
# 更新old网络
# 第2891轮训练用时13.047秒，平均累积奖励为-215.386
# 第2892轮训练用时13.046秒，平均累积奖励为-211.728
# 更新old网络
# 第2893轮训练用时13.082秒，平均累积奖励为-214.824
# 第2894轮训练用时12.923秒，平均累积奖励为-214.081
# 更新old网络
# 第2895轮训练用时12.947秒，平均累积奖励为-214.901
# 第2896轮训练用时13.032秒，平均累积奖励为-215.056
# 更新old网络
# 第2897轮训练用时13.039秒，平均累积奖励为-214.106
# 第2898轮训练用时12.967秒，平均累积奖励为-216.227
# 更新old网络
# 第2899轮训练用时13.001秒，平均累积奖励为-213.224
# 第2900轮训练用时13.031秒，平均累积奖励为-212.333
# 更新old网络
# 第2901轮训练用时13.027秒，平均累积奖励为-213.163
# 第2902轮训练用时12.787秒，平均累积奖励为-215.994
# 更新old网络
# 第2903轮训练用时12.921秒，平均累积奖励为-211.948
# 第2904轮训练用时13.104秒，平均累积奖励为-212.102
# 更新old网络
# 第2905轮训练用时12.838秒，平均累积奖励为-213.980
# 第2906轮训练用时13.146秒，平均累积奖励为-214.754
# 更新old网络
# 第2907轮训练用时12.876秒，平均累积奖励为-207.399
# 第2908轮训练用时12.976秒，平均累积奖励为-215.832
# 更新old网络
# 第2909轮训练用时12.948秒，平均累积奖励为-215.835
# 第2910轮训练用时12.924秒，平均累积奖励为-206.222
# 更新old网络
# 第2911轮训练用时12.916秒，平均累积奖励为-214.532
# 第2912轮训练用时12.995秒，平均累积奖励为-213.480
# 更新old网络
# 第2913轮训练用时13.119秒，平均累积奖励为-212.006
# 第2914轮训练用时13.069秒，平均累积奖励为-212.532
# 更新old网络
# 第2915轮训练用时13.087秒，平均累积奖励为-215.790
# 第2916轮训练用时13.020秒，平均累积奖励为-214.170
# 更新old网络
# 第2917轮训练用时12.967秒，平均累积奖励为-218.083
# 第2918轮训练用时13.020秒，平均累积奖励为-217.249
# 更新old网络
# 第2919轮训练用时13.075秒，平均累积奖励为-213.332
# 第2920轮训练用时12.992秒，平均累积奖励为-211.995
# 更新old网络
# 第2921轮训练用时12.969秒，平均累积奖励为-211.184
# 第2922轮训练用时12.963秒，平均累积奖励为-211.616
# 更新old网络
# 第2923轮训练用时12.992秒，平均累积奖励为-209.947
# 第2924轮训练用时13.052秒，平均累积奖励为-216.268
# 更新old网络
# 第2925轮训练用时13.001秒，平均累积奖励为-210.961
# 第2926轮训练用时12.969秒，平均累积奖励为-213.149
# 更新old网络
# 第2927轮训练用时12.972秒，平均累积奖励为-216.541
# 第2928轮训练用时13.045秒，平均累积奖励为-213.048
# 更新old网络
# 第2929轮训练用时13.050秒，平均累积奖励为-210.314
# 第2930轮训练用时13.066秒，平均累积奖励为-214.097
# 更新old网络
# 第2931轮训练用时13.015秒，平均累积奖励为-213.358
# 第2932轮训练用时12.918秒，平均累积奖励为-213.688
# 更新old网络
# 第2933轮训练用时13.026秒，平均累积奖励为-213.735
# 第2934轮训练用时12.995秒，平均累积奖励为-218.037
# 更新old网络
# 第2935轮训练用时13.179秒，平均累积奖励为-215.151
# 第2936轮训练用时13.031秒，平均累积奖励为-214.382
# 更新old网络
# 第2937轮训练用时12.947秒，平均累积奖励为-213.289
# 第2938轮训练用时13.033秒，平均累积奖励为-215.488
# 更新old网络
# 第2939轮训练用时12.944秒，平均累积奖励为-212.817
# 第2940轮训练用时12.922秒，平均累积奖励为-217.635
# 更新old网络
# 第2941轮训练用时13.008秒，平均累积奖励为-213.855
# 第2942轮训练用时13.052秒，平均累积奖励为-211.666
# 更新old网络
# 第2943轮训练用时12.942秒，平均累积奖励为-215.453
# 第2944轮训练用时12.996秒，平均累积奖励为-210.337
# 更新old网络
# 第2945轮训练用时13.037秒，平均累积奖励为-211.823
# 第2946轮训练用时12.984秒，平均累积奖励为-214.063
# 更新old网络
# 第2947轮训练用时12.966秒，平均累积奖励为-209.260
# 第2948轮训练用时13.032秒，平均累积奖励为-213.379
# 更新old网络
# 第2949轮训练用时13.086秒，平均累积奖励为-209.473
# 第2950轮训练用时12.957秒，平均累积奖励为-208.089
# 更新old网络
# 第2951轮训练用时13.033秒，平均累积奖励为-214.926
# 第2952轮训练用时13.027秒，平均累积奖励为-213.007
# 更新old网络
# 第2953轮训练用时13.007秒，平均累积奖励为-213.209
# 第2954轮训练用时13.035秒，平均累积奖励为-212.301
# 更新old网络
# 第2955轮训练用时13.034秒，平均累积奖励为-216.684
# 第2956轮训练用时12.950秒，平均累积奖励为-217.594
# 更新old网络
# 第2957轮训练用时13.089秒，平均累积奖励为-210.988
# 第2958轮训练用时13.082秒，平均累积奖励为-212.889
# 更新old网络
# 第2959轮训练用时13.141秒，平均累积奖励为-215.943
# 第2960轮训练用时13.117秒，平均累积奖励为-214.560
# 更新old网络
# 第2961轮训练用时13.005秒，平均累积奖励为-212.184
# 第2962轮训练用时13.053秒，平均累积奖励为-215.566
# 更新old网络
# 第2963轮训练用时12.987秒，平均累积奖励为-214.045
# 第2964轮训练用时13.135秒，平均累积奖励为-213.597
# 更新old网络
# 第2965轮训练用时13.024秒，平均累积奖励为-214.419
# 第2966轮训练用时13.033秒，平均累积奖励为-214.696
# 更新old网络
# 第2967轮训练用时13.074秒，平均累积奖励为-210.145
# 第2968轮训练用时13.037秒，平均累积奖励为-216.640
# 更新old网络
# 第2969轮训练用时12.998秒，平均累积奖励为-213.340
# 第2970轮训练用时12.978秒，平均累积奖励为-210.951
# 更新old网络
# 第2971轮训练用时13.079秒，平均累积奖励为-211.424
# 第2972轮训练用时13.000秒，平均累积奖励为-215.417
# 更新old网络
# 第2973轮训练用时13.093秒，平均累积奖励为-215.970
# 第2974轮训练用时13.047秒，平均累积奖励为-213.480
# 更新old网络
# 第2975轮训练用时13.118秒，平均累积奖励为-213.880
# 第2976轮训练用时13.020秒，平均累积奖励为-214.448
# 更新old网络
# 第2977轮训练用时13.069秒，平均累积奖励为-208.290
# 第2978轮训练用时12.991秒，平均累积奖励为-213.323
# 更新old网络
# 第2979轮训练用时13.052秒，平均累积奖励为-214.213
# 第2980轮训练用时13.058秒，平均累积奖励为-216.491
# 更新old网络
# 第2981轮训练用时13.054秒，平均累积奖励为-215.204
# 第2982轮训练用时13.103秒，平均累积奖励为-211.811
# 更新old网络
# 第2983轮训练用时13.232秒，平均累积奖励为-210.341
# 第2984轮训练用时13.037秒，平均累积奖励为-214.286
# 更新old网络
# 第2985轮训练用时13.025秒，平均累积奖励为-209.107
# 第2986轮训练用时13.005秒，平均累积奖励为-210.918
# 更新old网络
# 第2987轮训练用时13.011秒，平均累积奖励为-212.637
# 第2988轮训练用时13.106秒，平均累积奖励为-209.878
# 更新old网络
# 第2989轮训练用时13.126秒，平均累积奖励为-211.639
# 第2990轮训练用时13.059秒，平均累积奖励为-211.098
# 更新old网络
# 第2991轮训练用时13.186秒，平均累积奖励为-212.324
# 第2992轮训练用时13.113秒，平均累积奖励为-212.287
# 更新old网络
# 第2993轮训练用时13.015秒，平均累积奖励为-213.467
# 第2994轮训练用时13.080秒，平均累积奖励为-215.468
# 更新old网络
# 第2995轮训练用时13.001秒，平均累积奖励为-209.714
# 第2996轮训练用时13.033秒，平均累积奖励为-212.349
# 更新old网络
# 第2997轮训练用时13.136秒，平均累积奖励为-214.650
# 第2998轮训练用时13.074秒，平均累积奖励为-214.143
# 更新old网络
# 第2999轮训练用时13.017秒，平均累积奖励为-210.637
# 第3000轮训练用时13.137秒，平均累积奖励为-217.870

# %%
fig = plt.figure(figsize = (12,6))
x = range(len(bss_ep_updaterewards))
ep_rewards_arr = bss_ep_updaterewards
plt.plot(x,ep_rewards_arr)
plt.show()

# %%
torch.save(meta_drl.bss_agent.state_dict(),f=r'D:\sjtu\EV_DRL\BSS_OPERATION_Emergence\data\savemodel\policymodel\PPO_SCALE10_singleact_metamodelV1type4.pth')

# %%
ep_rewards_pd = pd.DataFrame(bss_ep_updaterewards)
pdpath = r'D:\sjtu\EV_DRL\BSS_OPERATION_Emergence\data\实验数据\训练数据\PPO_SCALE10_singleact_metamodeltype4_trainreturn0707.csv'
ep_rewards_pd.to_csv(pdpath,header=['return'],index=None)

# %%
def test(step,gamemanager:BE.GameManager,rewardF,opt, model=None,showmessage = True,savepic = False):
    gamemanager.Initial( reinitial= True)
    print('仿真开始')
    #gamemanager.Message()
    request_reserve_list = []
    request_engs= []
    request_Gengs = []
    request_PVengs= []
    cplan_list = []
    
    wait_nums = []
    ava_bs = []
    gprices = []
    
    rew_list = []
    rcosts = []
    rqueues = []
    rwasts = []



    cplan_probs = []



    readybT1s =[]
    readybT2s = []
    cplans = []

    rewards = 0
    gamestep = 0
    for i in range(step):
        gamestep += 1
        csta,ccost = StateTensor(gamemanager)

        #BSS决策过程
        reserve_act,prob1 = opt.charger_num / 2,  None
        if  model != None:
            reserve_act,prob1 =  model.select_action(csta)
            #energy_req = energy_act.cpu().item()*er_factor if type_e else int(energy_act.cpu().item())
            reserve_act = prob1.argmax().cpu().item()
            #pv_rat = pv_act.cpu().item()
            
        # print(csta)
        # print(prob1)
        # print(prob2)
        # print(reserve_act,cplan_act)


        
        gamemanager.Update(reserve_act,0,emergencefactor,showmessage)
        request_engs.append(gamemanager.stage_used_energy)
        
        nsta,ncost = StateTensor(gamemanager)

        print(ncost)

        rew,rcost,rqueue,rwast =rewardF(ncost,opt)

        wait_num = gamemanager.bss_queuelength
        wait_nums.append(wait_num)

        gprices.append(gamemanager.ps.price)
        

        avab = gamemanager.ava_bnum#可获得的电池数
        ava_bs.append(avab)

        request_reserve_list.append(reserve_act)

        rew_list.append(rew.cpu().item())
        rcosts.append(rcost.cpu().item())
        rqueues.append(rqueue.cpu().item())
        rwasts.append(rwast.cpu().item())



        rewards += rew

        readybT1s.append(gamemanager.bss.BT1_readdy_num)
        readybT2s.append(gamemanager.bss.BT2_readdy_num)


        if showmessage:
            gamemanager.Message()

    #print(request_energy_list)

    def plotax(axsi,x,y,names):
        lines = []
        for i in y:
            li, = axsi.plot(x, i)
            lines.append(li)
        axsi.legend(lines,names)

    fig,axs = plt.subplots(6,1,figsize=(12,3*6))

    x = range(gamestep)
    plotax(axs[0],x,[request_reserve_list],['request_reserve'])
    # axs[0].plot(x,request_energy_list)
    # axs[0].plot(x,pvenergies)
    plotax(axs[1],x,[wait_nums,ava_bs],['wait_nums','ava_bs'])
    # axs[1].plot(x,wait_nums)
    # axs[1].plot(x,ava_bs)

    plotax(axs[2],x,[gprices],['gprices'])
    # axs[2].plot(x,gprices)
    # axs[2].plot(x,pvprices)

    plotax(axs[3],x,[request_engs],['eng','Geng','pveng'])
    #axs[3].plot(x, [min(i,200) for i in pveng])
    

    #axs[4].plot(x, maxpvs)#pv_probs)#pv_list)

    plotax(axs[4],x,[readybT1s,readybT2s],['readybT1s','readybT2s'])
    # axs[5].plot(x, readybT1s)#pv_probs)#pv_list)
    # axs[5].plot(x, readybT2s)#pv_probs)#pv_list)
    # axs[5].plot(x, cplans)
    
    #plotax(axs[6],x,[rew_list],['rew_list'])
    plotax(axs[5],x,[rcosts,rqueues,rwasts],['rcost','rqueue','rwast'])
    axs[5].plot(x,rew_list)
        
    if savepic:
        path = os.path.join(opt.dirpath,'a2csimulation'+opt.t1+'.png')
        plt.savefig(path)

    plt.show()
    return rew_list

# %%
emergencefactor = 0.5

# %%
rews =test(400,gamemanager=GM,rewardF=rewardtype1_detail,opt= OPTIONS,
                     model=meta_drl,showmessage=True,savepic=False)
sum(rews)

# %%
torch.save(bss_drl.bss_agent.state_dict(),f=r'D:\sjtu\EV_DRL\BSS_OPERATION_Emergence\data\savemodel\policymodel\PPO_emgfactor050v1_SCALE10_singleact.pth')
